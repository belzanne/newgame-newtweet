# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
import tweepy
import os
from dotenv import load_dotenv
import tempfile
from datetime import datetime
import pytz
from deep_translator import GoogleTranslator
from langdetect import detect, LangDetectException
import html
import pandas as pd
from duckduckgo_search import DDGS
import re
from Levenshtein import ratio

# Charger les variables d'environnement
load_dotenv()

# Configuration
GITHUB_REPO = 'steampage-creation-date'
DB_FILE_PATH = 'steam_games.db'
TIMESTAMP_FILE = 'timestamp_last_tweet.txt'
PARIS_TZ = pytz.timezone('Europe/Paris')

# Initialiser le traducteur
translator = GoogleTranslator(source='auto', target='en')

def read_last_timestamp():
    try:
        with open(TIMESTAMP_FILE, 'r') as f:
            return int(f.read().strip())
    except FileNotFoundError:
        return 0

def write_last_timestamp(timestamp):
    with open(TIMESTAMP_FILE, 'w') as f:
        f.write(str(timestamp))

def download_db(url, local_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    print(f"Échec du téléchargement de la base de données. Code de statut: {response.status_code}")
    return False

def connect_to_db(db_path):
    return sqlite3.connect(db_path)

def check_new_entries(conn, last_timestamp):
    cursor = conn.cursor()
    cursor.execute("""
        SELECT steam_game_id, first_seen
        FROM games 
        WHERE first_seen > ?
        ORDER BY first_seen ASC
    """, (last_timestamp,))
    return cursor.fetchall()

def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(steam_game_id)]['success']:
            return data[str(steam_game_id)]['data']
    return None

def filter_game(game_data):
    if game_data['type'] != 'game' or game_data.get('dlc', False):
        return False
    content_descriptors = game_data.get('content_descriptors', {}).get('ids', [])
    if 3 in content_descriptors:
        return False
    
    # Vérifier si l'anglais est supporté
    supported_languages = game_data.get('supported_languages', '').lower()
    if 'english' not in supported_languages:
        return False
    
    # Vérifier si le jeu est payant
    if game_data.get('is_free', True):
        return False
    
    return True

def get_twitter_client():
    client = tweepy.Client(
        consumer_key=os.getenv('TWITTER_CONSUMER_KEY'),
        consumer_secret=os.getenv('TWITTER_CONSUMER_SECRET'),
        access_token=os.getenv('TWITTER_ACCESS_TOKEN'),
        access_token_secret=os.getenv('TWITTER_ACCESS_TOKEN_SECRET')
    )
    return client

def get_game_tags_and_check_ai(app_id):
    try:
        url = f"https://store.steampowered.com/app/{app_id}/"
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Vérifier la présence de contenu généré par IA
            ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
            if ai_disclosure:
                print(f"Contenu AI détecté pour le jeu {app_id}")
                return None, None  # Le jeu utilise du contenu généré par IA
            
            # Récupérer les tags
            tag_elements = soup.find_all('a', class_='app_tag')
            tags = [tag.text.strip() for tag in tag_elements]
            return tags[:4], 'scraped'  # Retourne seulement les 4 premiers tags
    except Exception as e:
        print(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
    
    return None, None

def translate_to_english(text):
    try:
        # Détection de la langue
        lang = detect(text)
        if lang != 'en':
            translated = translator.translate(text)
            return translated
        return text
    except LangDetectException:
        print(f"Impossible de détecter la langue pour le texte: {text}")
        return text
    except Exception as e:
        print(f"Erreur lors de la traduction : {e}")
        return text

def clean_text(text):
    # Décode les entités HTML
    decoded_text = html.unescape(text)
    # Supprime les sauts de ligne et les espaces multiples
    cleaned_text = ' '.join(decoded_text.split())
    return cleaned_text

def search_duckduckgo(query, max_results=5):
    results = DDGS().text(
        keywords=query,
        region='wt-wt',
        safesearch='off',
        timelimit='7d',
        max_results=max_results
    )
    return pd.DataFrame(list(results))

def is_twitter_link(url):
    return 'twitter.com' in url.lower()

def is_game_related(text):
    game_keywords = {
        'en': ['game', 'video game', 'developer', 'studio', 'gaming'],
        'fr': ['jeu', 'jeu vidéo', 'développeur', 'studio', 'gaming'],
        'es': ['juego', 'videojuego', 'desarrollador', 'estudio', 'gaming'],
        'de': ['spiel', 'videospiel', 'entwickler', 'studio', 'gaming'],
        'it': ['gioco', 'videogioco', 'sviluppatore', 'studio', 'gaming'],
        'ja': ['ゲーム', 'ビデオゲーム', '開発者', 'スタジオ', 'ゲーミング'],
    }
    
    try:
        lang = detect(text)
        if lang not in game_keywords:
            text = translator.translate(text, dest='en')
            lang = 'en'
        return any(keyword.lower() in text.lower() for keyword in game_keywords[lang])
    except:
        return False

def extract_twitter_handle(url):
    match = re.search(r'twitter\.com/(\w+)', url)
    if match:
        return '@' + match.group(1)
    return None

def name_similarity(name1, name2):
    return ratio(name1.lower(), name2.lower())

def get_game_studio_twitter(studio_name):
    search_query = f"{studio_name} twitter"
    results_df = search_duckduckgo(search_query)
    
    for index, row in results_df.iterrows():
        if is_twitter_link(row['href']):
            handle = extract_twitter_handle(row['href'])
            if handle and is_game_related(row['body']):
                # Vérifier la similarité du nom
                similarity = name_similarity(studio_name, handle[1:])  # Ignorer le '@'
                if similarity >= 0.9:
                    return handle
    
    return studio_name  # Retourne le nom du studio si aucun compte Twitter pertinent n'est trouvé

def format_tweet_message(game_data, tags, first_seen, tags_source):
    try:
        name = clean_text(game_data['name'])
        developers = game_data.get('developers', [])
        developer_handles = []
        for dev in developers:
            handle = get_game_studio_twitter(dev)
            developer_handles.append(handle)
        developers_str = ", ".join(developer_handles)
        
        description = clean_text(translate_to_english(game_data.get('short_description', '')))
        app_id = game_data['steam_appid']
        release_date = game_data.get('release_date', {}).get('date', 'TBA')
        
        # Formater la date
        date = datetime.fromtimestamp(first_seen, PARIS_TZ).strftime("%m-%d-%y")
        
        # Formater les tags
        tags_str = ", ".join(clean_text(tag) for tag in tags) if tags else "No tags available"
        
        # Construire le lien Steam
        steam_link = f"https://store.steampowered.com/app/{app_id}"
        
        # Construire le tweet avec le nouveau format
        tweet = f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 {description}\n{steam_link}"
        
        # Vérifier et ajuster la longueur du tweet si nécessaire
        if len(tweet) > 280:
            available_space = 280 - len(f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 ...\n{steam_link}")
            truncated_description = description[:available_space] + "..."
            tweet = f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 {truncated_description}\n{steam_link}"
        
        return tweet
    except KeyError as e:
        print(f"Erreur lors du formatage du tweet: Clé manquante - {e}")
        return None
    except Exception as e:
        print(f"Erreur inattendue lors du formatage du tweet: {e}")
        return None

def send_tweet(message):
    client = get_twitter_client()
    try:
        response = client.create_tweet(text=message)
        return response.data['id']
    except Exception as e:
        print(f"Erreur lors de la création du tweet: {e}")
        return None

def main():
    db_url = f"https://raw.githubusercontent.com/{os.getenv('GITHUB_USERNAME')}/{GITHUB_REPO}/main/{DB_FILE_PATH}"
    last_timestamp = read_last_timestamp()
    new_last_timestamp = last_timestamp

    total_games = 0
    published_games = 0

    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if download_db(db_url, temp_db.name):
            conn = connect_to_db(temp_db.name)
            new_entries = check_new_entries(conn, last_timestamp)
            
            for steam_game_id, first_seen in new_entries:
                total_games += 1
                print(f"Nouveau jeu trouvé : Steam ID: {steam_game_id}, First Seen: {first_seen}")
                game_data = get_game_details(steam_game_id)
                if game_data and filter_game(game_data):
                    tags, tags_source = get_game_tags_and_check_ai(steam_game_id)
                    if tags is None:
                        print(f"Le jeu avec Steam ID {steam_game_id} utilise du contenu généré par IA ou n'a pas pu être scrapé.")
                        continue
                    message = format_tweet_message(game_data, tags, first_seen, tags_source)
                    if message:
                        tweet_id = send_tweet(message)
                        if tweet_id:
                            print(f"Tweet publié pour {game_data['name']} (ID: {tweet_id})")
                            new_last_timestamp = max(new_last_timestamp, first_seen)
                            published_games += 1
                        else:
                            print(f"Échec de la publication du tweet pour {game_data['name']}")
                    else:
                        print(f"Échec du formatage du tweet pour {game_data['name']}")
                else:
                    print(f"Le jeu avec Steam ID {steam_game_id} ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.")
            
            conn.close()
        else:
            print("Échec du téléchargement de la base de données")
    
    os.unlink(temp_db.name)  # Supprime le fichier temporaire

    if new_last_timestamp > last_timestamp:
        write_last_timestamp(new_last_timestamp)
        print(f"Timestamp mis à jour : {new_last_timestamp}")

    print(f"\nRésumé : {published_games} jeux publiés sur {total_games} jeux traités au total.")

if __name__ == "__main__":
    main()
# Out:
# Nouveau jeu trouvé : Steam ID: 3035140, First Seen: 1721865589
# Contenu AI détecté pour le jeu 3035140
# Le jeu avec Steam ID 3035140 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Nouveau jeu trouvé : Steam ID: 3101700, First Seen: 1721865589
# Contenu AI détecté pour le jeu 3101700
# Le jeu avec Steam ID 3101700 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Nouveau jeu trouvé : Steam ID: 3113480, First Seen: 1721865589
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 303
#     300     print(f"\nRésumé : {published_games} jeux publiés sur {total_games} jeux traités au total.")
#     302 if __name__ == "__main__":
# --> 303     main()
#
# Cell In[13], line 272, in main()
#     270 game_data = get_game_details(steam_game_id)
#     271 if game_data and filter_game(game_data):
# --> 272     tags, tags_source = get_game_tags_and_check_ai(steam_game_id)
#     273     if tags is None:
#     274         print(f"Le jeu avec Steam ID {steam_game_id} utilise du contenu généré par IA ou n'a pas pu être scrapé.")
#
# Cell In[13], line 107, in get_game_tags_and_check_ai(app_id)
#     102 url = f"https://store.steampowered.com/app/{app_id}/"
#     103 headers = {
#     104     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
#     105 }
# --> 107 response = requests.get(url, headers=headers)
#     109 if response.status_code == 200:
#     110     soup = BeautifulSoup(response.text, 'html.parser')
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
import os
from dotenv import load_dotenv
import tempfile
from datetime import datetime
import pytz
from deep_translator import GoogleTranslator
from langdetect import detect, LangDetectException
import html
import pandas as pd
from duckduckgo_search import DDGS
import re
from Levenshtein import ratio

# Charger les variables d'environnement
load_dotenv()

# Configuration
GITHUB_REPO = 'steampage-creation-date'
DB_FILE_PATH = 'steam_games.db'
SIMULATION_TIMESTAMP = 1721951972
PARIS_TZ = pytz.timezone('Europe/Paris')
SIMULATED_TWEETS_FILE = 'simulated_tweets.txt'

# Initialiser le traducteur
translator = GoogleTranslator(source='auto', target='en')

def read_last_timestamp():
    try:
        with open(TIMESTAMP_FILE, 'r') as f:
            return int(f.read().strip())
    except FileNotFoundError:
        return 0

def write_last_timestamp(timestamp):
    with open(TIMESTAMP_FILE, 'w') as f:
        f.write(str(timestamp))

def download_db(url, local_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    print(f"Échec du téléchargement de la base de données. Code de statut: {response.status_code}")
    return False

def connect_to_db(db_path):
    return sqlite3.connect(db_path)

def check_new_entries(conn, last_timestamp):
    cursor = conn.cursor()
    cursor.execute("""
        SELECT steam_game_id, first_seen
        FROM games 
        WHERE first_seen > ?
        ORDER BY first_seen ASC
    """, (last_timestamp,))
    return cursor.fetchall()

def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(steam_game_id)]['success']:
            return data[str(steam_game_id)]['data']
    return None

def filter_game(game_data):
    if game_data['type'] != 'game' or game_data.get('dlc', False):
        return False
    content_descriptors = game_data.get('content_descriptors', {}).get('ids', [])
    if 3 in content_descriptors:
        return False
    
    supported_languages = game_data.get('supported_languages', '').lower()
    if 'english' not in supported_languages:
        return False
    
    if game_data.get('is_free', True):
        return False
    
    return True

def get_game_tags_and_check_ai(app_id):
    try:
        url = f"https://store.steampowered.com/app/{app_id}/"
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            
            ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
            if ai_disclosure:
                print(f"Contenu AI détecté pour le jeu {app_id}")
                return None, None
            
            tag_elements = soup.find_all('a', class_='app_tag')
            tags = [tag.text.strip() for tag in tag_elements]
            return tags[:4], 'scraped'
    except Exception as e:
        print(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
    
    return None, None

def translate_to_english(text):
    try:
        lang = detect(text)
        if lang != 'en':
            translated = translator.translate(text)
            return translated
        return text
    except LangDetectException:
        print(f"Impossible de détecter la langue pour le texte: {text}")
        return text
    except Exception as e:
        print(f"Erreur lors de la traduction : {e}")
        return text

def clean_text(text):
    decoded_text = html.unescape(text)
    cleaned_text = ' '.join(decoded_text.split())
    return cleaned_text

def search_duckduckgo(query, max_results=5):
    results = DDGS().text(
        keywords=query,
        region='wt-wt',
        safesearch='off',
        timelimit='7d',
        max_results=max_results
    )
    return pd.DataFrame(list(results))

def is_twitter_link(url):
    return 'twitter.com' in url.lower()

def is_game_related(text):
    game_keywords = {
        'en': ['game', 'video game', 'developer', 'studio', 'gaming'],
        'fr': ['jeu', 'jeu vidéo', 'développeur', 'studio', 'gaming'],
        'es': ['juego', 'videojuego', 'desarrollador', 'estudio', 'gaming'],
        'de': ['spiel', 'videospiel', 'entwickler', 'studio', 'gaming'],
        'it': ['gioco', 'videogioco', 'sviluppatore', 'studio', 'gaming'],
        'ja': ['ゲーム', 'ビデオゲーム', '開発者', 'スタジオ', 'ゲーミング'],
    }
    
    try:
        lang = detect(text)
        if lang not in game_keywords:
            text = translator.translate(text, dest='en')
            lang = 'en'
        return any(keyword.lower() in text.lower() for keyword in game_keywords[lang])
    except:
        return False

def extract_twitter_handle(url):
    match = re.search(r'twitter\.com/(\w+)', url)
    if match:
        return '@' + match.group(1)
    return None

def name_similarity(name1, name2):
    return ratio(name1.lower(), name2.lower())

def get_game_studio_twitter(studio_name):
    search_query = f"{studio_name} twitter"
    results_df = search_duckduckgo(search_query)
    
    for index, row in results_df.iterrows():
        if is_twitter_link(row['href']):
            handle = extract_twitter_handle(row['href'])
            if handle and is_game_related(row['body']):
                similarity = name_similarity(studio_name, handle[1:])
                if similarity >= 0.9:
                    return handle
    
    return studio_name

def format_tweet_message(game_data, tags, first_seen, tags_source):
    try:
        name = clean_text(game_data['name'])
        developers = game_data.get('developers', [])
        developer_handles = []
        for dev in developers:
            handle = get_game_studio_twitter(dev)
            developer_handles.append(handle)
        developers_str = ", ".join(developer_handles)
        
        description = clean_text(translate_to_english(game_data.get('short_description', '')))
        app_id = game_data['steam_appid']
        release_date = game_data.get('release_date', {}).get('date', 'TBA')
        
        date = datetime.fromtimestamp(first_seen, PARIS_TZ).strftime("%m-%d-%y")
        
        tags_str = ", ".join(clean_text(tag) for tag in tags) if tags else "No tags available"
        
        steam_link = f"https://store.steampowered.com/app/{app_id}"
        
        tweet = f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 {description}\n{steam_link}"
        
        if len(tweet) > 280:
            available_space = 280 - len(f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 ...\n{steam_link}")
            truncated_description = description[:available_space] + "..."
            tweet = f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 {truncated_description}\n{steam_link}"
        
        return tweet
    except KeyError as e:
        print(f"Erreur lors du formatage du tweet: Clé manquante - {e}")
        return None
    except Exception as e:
        print(f"Erreur inattendue lors du formatage du tweet: {e}")
        return None

def simulate_and_store_tweet(game_data, tags, first_seen, tags_source):
    message = format_tweet_message(game_data, tags, first_seen, tags_source)
    if message:
        with open(SIMULATED_TWEETS_FILE, 'a', encoding='utf-8') as f:
            f.write(f"Tweet simulé pour {game_data['name']} (Steam ID: {game_data['steam_appid']}):\n")
            f.write(message)
            f.write("\n\n" + "-"*50 + "\n\n")
        return True
    return False

def main():
    db_url = f"https://raw.githubusercontent.com/{os.getenv('GITHUB_USERNAME')}/{GITHUB_REPO}/main/{DB_FILE_PATH}"

    total_games = 0
    simulated_tweets = 0

    open(SIMULATED_TWEETS_FILE, 'w').close()

    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if download_db(db_url, temp_db.name):
            conn = connect_to_db(temp_db.name)
            cursor = conn.cursor()
            cursor.execute("""
                SELECT steam_game_id, first_seen
                FROM games 
                WHERE first_seen = ?
                ORDER BY first_seen ASC
            """, (SIMULATION_TIMESTAMP,))
            new_entries = cursor.fetchall()
            
            for steam_game_id, first_seen in new_entries:
                total_games += 1
                print(f"Simulation pour le jeu : Steam ID: {steam_game_id}, First Seen: {first_seen}")
                game_data = get_game_details(steam_game_id)
                if game_data and filter_game(game_data):
                    tags, tags_source = get_game_tags_and_check_ai(steam_game_id)
                    if tags is None:
                        print(f"Le jeu avec Steam ID {steam_game_id} utilise du contenu généré par IA ou n'a pas pu être scrapé.")
                        continue
                    if simulate_and_store_tweet(game_data, tags, first_seen, tags_source):
                        simulated_tweets += 1
                        print(f"Tweet simulé pour {game_data['name']}")
                    else:
                        print(f"Échec de la simulation du tweet pour {game_data['name']}")
                else:
                    print(f"Le jeu avec Steam ID {steam_game_id} ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.")
            
            conn.close()
        else:
            print("Échec du téléchargement de la base de données")
    
    os.unlink(temp_db.name)

    print(f"\nRésumé : {simulated_tweets} tweets simulés sur {total_games} jeux traités au total.")
    print(f"Les tweets simulés ont été stockés dans {SIMULATED_TWEETS_FILE}")

if __name__ == "__main__":
    main()
# Out:
# Simulation pour le jeu : Steam ID: 3125760, First Seen: 1721951972
# Tweet simulé pour Ruins of Dawnseeker
# Simulation pour le jeu : Steam ID: 3112450, First Seen: 1721951972
# Tweet simulé pour Ciclico
# Simulation pour le jeu : Steam ID: 3127810, First Seen: 1721951972
# Le jeu avec Steam ID 3127810 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3078660, First Seen: 1721951972
# Le jeu avec Steam ID 3078660 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2980870, First Seen: 1721951972
# Tweet simulé pour The Mage Slayer
# Simulation pour le jeu : Steam ID: 3108870, First Seen: 1721951972
# Le jeu avec Steam ID 3108870 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3077640, First Seen: 1721951972
# Tweet simulé pour MIGHTREYA
# Simulation pour le jeu : Steam ID: 3080200, First Seen: 1721951972
# Le jeu avec Steam ID 3080200 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3122190, First Seen: 1721951972
# Le jeu avec Steam ID 3122190 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3014160, First Seen: 1721951972
# Le jeu avec Steam ID 3014160 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3106840, First Seen: 1721951972
# Le jeu avec Steam ID 3106840 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3113500, First Seen: 1721951972
# Tweet simulé pour KILL KILL KILL KILL
# Simulation pour le jeu : Steam ID: 3118620, First Seen: 1721951972
# Tweet simulé pour AERO BATTLE ROYALE
# Simulation pour le jeu : Steam ID: 3127840, First Seen: 1721951972
# Le jeu avec Steam ID 3127840 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3109410, First Seen: 1721951972
# Contenu AI détecté pour le jeu 3109410
# Le jeu avec Steam ID 3109410 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Simulation pour le jeu : Steam ID: 2072610, First Seen: 1721951972
# Le jeu avec Steam ID 2072610 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3107380, First Seen: 1721951972
# Le jeu avec Steam ID 3107380 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3114040, First Seen: 1721951972
# Tweet simulé pour Lights In The Sky
# Simulation pour le jeu : Steam ID: 2847290, First Seen: 1721951972
# Tweet simulé pour The Maze
# Simulation pour le jeu : Steam ID: 2982460, First Seen: 1721951972
# Le jeu avec Steam ID 2982460 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2646590, First Seen: 1721951972
# Le jeu avec Steam ID 2646590 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3116100, First Seen: 1721951972
# Contenu AI détecté pour le jeu 3116100
# Le jeu avec Steam ID 3116100 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Simulation pour le jeu : Steam ID: 3097670, First Seen: 1721951972
# Le jeu avec Steam ID 3097670 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 1402440, First Seen: 1721951972
# Tweet simulé pour TIME TO GO HOME
# Simulation pour le jeu : Steam ID: 2520650, First Seen: 1721951972
# Tweet simulé pour Esoterica Order
# Simulation pour le jeu : Steam ID: 3122250, First Seen: 1721951972
# Le jeu avec Steam ID 3122250 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3091020, First Seen: 1721951972
# Le jeu avec Steam ID 3091020 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 
ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3095880, First Seen: 1721951972
# Le jeu avec Steam ID 3095880 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3116360, First Seen: 1721951972
# Le jeu avec Steam ID 3116360 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3126600, First Seen: 1721951972
# Le jeu avec Steam ID 3126600 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3084620, First Seen: 1721951972
# Le jeu avec Steam ID 3084620 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3128140, First Seen: 1721951972
# Le jeu avec Steam ID 3128140 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3072850, First Seen: 1721951972
# Le jeu avec Steam ID 3072850 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3120980, First Seen: 1721951972
# Tweet simulé pour Stargazer
# Simulation pour le jeu : Steam ID: 2378070, First Seen: 1721951972
# Le jeu avec Steam ID 2378070 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378071, First Seen: 1721951972
# Le jeu avec Steam ID 2378071 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378072, First Seen: 1721951972
# Le jeu avec Steam ID 2378072 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378073, First Seen: 1721951972
# Le jeu avec Steam ID 2378073 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3104600, First Seen: 1721951972
# Tweet simulé pour Intrana
# Simulation pour le jeu : Steam ID: 2378075, First Seen: 1721951972
# Le jeu avec Steam ID 2378075 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378076, First Seen: 1721951972
# Le jeu avec Steam ID 2378076 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378077, First Seen: 1721951972
# Le jeu avec Steam ID 2378077 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378078, First Seen: 1721951972
# Le jeu avec Steam ID 2378078 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3065180, First Seen: 1721951972
# Tweet simulé pour Dolls: The Hunt
# Simulation pour le jeu : Steam ID: 2378080, First Seen: 1721951972
# Le jeu avec Steam ID 2378080 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378081, First Seen: 1721951972
# Le jeu avec Steam ID 2378081 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378082, First Seen: 1721951972
# Le jeu avec Steam ID 2378082 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2378083, First Seen: 1721951972
# Le jeu avec Steam ID 2378083 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3035490, First Seen: 1721951972
# Tweet simulé pour N3Rally
# Simulation pour le jeu : Steam ID: 3104100, First Seen: 1721951972
# Tweet simulé pour DeathStairwell99F
# Simulation pour le jeu : Steam ID: 3122530, First Seen: 1721951972
# Le jeu avec Steam ID 3122530 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3127650, First Seen: 1721951972
# Tweet simulé pour NO STRANGERS
# Simulation pour le jeu : Steam ID: 3049320, First Seen: 1721951972
# Tweet simulé pour Medieval Marathon: A Quest for Gold
# Simulation pour le jeu : Steam ID: 3115370, First Seen: 1721951972
# Tweet simulé pour Cool Cucumber Cricket Manager
# Simulation pour le jeu : Steam ID: 2912110, First Seen: 1721951972
# Le jeu avec Steam ID 2912110 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2983790, First Seen: 1721951972
# Tweet simulé pour Country Tales 2: New Frontiers Collector's Edition
# Simulation pour le jeu : Steam ID: 3105140, First Seen: 1721951972
# Tweet simulé pour Cybernated
# Simulation pour le jeu : Steam ID: 2689920, First Seen: 1721951972
# Tweet simulé pour WarSpawn
# Simulation pour le jeu : Steam ID: 3125120, First Seen: 1721951972
# Tweet simulé pour Rodland of Pipes
# Simulation pour le jeu : Steam ID: 3101570, First Seen: 1721951972
# Le jeu avec Steam ID 3101570 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3044740, First Seen: 1721951972
# Le jeu avec Steam ID 3044740 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3088260, First Seen: 1721951972
# Le jeu avec Steam ID 3088260 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3121030, First Seen: 1721951972
# Tweet simulé pour Kick Them All
# Simulation pour le jeu : Steam ID: 3123080, First Seen: 1721951972
# Tweet simulé pour Alien Weapon Test Grounds
# Simulation pour le jeu : Steam ID: 3128720, First Seen: 1721951972
# Le jeu avec Steam ID 3128720 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3119960, First Seen: 1721951972
# Contenu AI détecté pour le jeu 3119960
# Le jeu avec Steam ID 3119960 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Simulation pour le jeu : Steam ID: 3086740, First Seen: 1721951972
# Tweet simulé pour GAMING RAIDING
# Simulation pour le jeu : Steam ID: 3121560, First Seen: 1721951972
# Le jeu avec Steam ID 3121560 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3125660, First Seen: 1721951972
# Le jeu avec Steam ID 3125660 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3125150, First Seen: 1721951972
# Tweet simulé pour A Maiden's Serenade
# Simulation pour le jeu : Steam ID: 3124130, First Seen: 1721951972
# Tweet simulé pour Get Down
# Simulation pour le jeu : Steam ID: 3082660, First Seen: 1721951972
# Tweet simulé pour Akaneiro ni Somaru Saka
# Simulation pour le jeu : Steam ID: 3125670, First Seen: 1721951972
# Le jeu avec Steam ID 3125670 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2689450, First Seen: 1721951972
# Tweet simulé pour Obec
# Simulation pour le jeu : Steam ID: 3027370, First Seen: 1721951972
# Le jeu avec Steam ID 3027370 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3106220, First Seen: 1721951972
# Tweet simulé pour Abyss Survivors
# Simulation pour le jeu : Steam ID: 3108780, First Seen: 1721951972
# Tweet simulé pour Warrior Architects
# Simulation pour le jeu : Steam ID: 3128750, First Seen: 1721951972
# Le jeu avec Steam ID 3128750 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3061170, First Seen: 1721951972
# Le jeu avec Steam ID 3061170 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3094450, First Seen: 1721951972
# Tweet simulé pour Smoots Summer Games II
# Simulation pour le jeu : Steam ID: 2625470, First Seen: 1721951972
# Tweet simulé pour Moon Colony
# Simulation pour le jeu : Steam ID: 3027390, First Seen: 1721951972
# Le jeu avec Steam ID 3027390 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2934210, First Seen: 1721951972
# Tweet simulé pour Temporal Cross
# Simulation pour le jeu : Steam ID: 3120070, First Seen: 1721951972
# Tweet simulé pour Horror Storm
# Simulation pour le jeu : Steam ID: 3027400, First Seen: 1721951972
# Le jeu avec Steam ID 3027400 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3121610, First Seen: 1721951972
# Le jeu avec Steam ID 3121610 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3034060, First Seen: 1721951972
# Le jeu avec Steam ID 3034060 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3123660, First Seen: 1721951972
# Le jeu avec Steam ID 3123660 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3105230, First Seen: 1721951972
# Le jeu avec Steam ID 3105230 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3123330, First Seen: 1721951972
# Le jeu avec Steam ID 3123330 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3125200, First Seen: 1721951972
# Le jeu avec Steam ID 3125200 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3127760, First Seen: 1721951972
# Le jeu avec Steam ID 3127760 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3027410, First Seen: 1721951972
# Le jeu avec Steam ID 3027410 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2799570, First Seen: 1721951972
# Le jeu avec Steam ID 2799570 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3108820, First Seen: 1721951972
# Le jeu avec Steam ID 3108820 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3121620, First Seen: 1721951972
# Le jeu avec Steam ID 3121620 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3128270, First Seen: 1721951972
# Le jeu avec Steam ID 3128270 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3115480, First Seen: 1721951972
# Le jeu avec Steam ID 3115480 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3084250, First Seen: 1721951972
# Le jeu avec Steam ID 3084250 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2936290, First Seen: 1721951972
# Le jeu avec Steam ID 2936290 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3118060, First Seen: 1721951972
# Le jeu avec Steam ID 3118060 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3088370, First Seen: 1721951972
# Le jeu avec Steam ID 3088370 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3087860, First Seen: 1721951972
# Le jeu avec Steam ID 3087860 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 2951670, First Seen: 1721951972
# Le jeu avec Steam ID 2951670 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
# Simulation pour le jeu : Steam ID: 3115510, First Seen: 1721951972
# Le jeu avec Steam ID 3115510 ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.
#
# Résumé : 81 tweets simulés sur 212 jeux traités au total.
# Les tweets simulés ont été stockés dans simulated_tweets.txt

# %%
##test priorisation jeux sans éditeurs 

import sqlite3
import requests
from bs4 import BeautifulSoup
import tweepy
import os
from dotenv import load_dotenv
import tempfile
from datetime import datetime
import pytz
from deep_translator import GoogleTranslator
from langdetect import detect, LangDetectException
import html
import pandas as pd
from duckduckgo_search import DDGS
import re
from Levenshtein import ratio

# Charger les variables d'environnement
load_dotenv()

# Configuration
GITHUB_REPO = 'steampage-creation-date'
DB_FILE_PATH = 'steam_games.db'
TIMESTAMP_FILE = 'timestamp_last_tweet.txt'
PARIS_TZ = pytz.timezone('Europe/Paris')
MAX_TWEETS_PER_DAY = 50

# Initialiser le traducteur
translator = GoogleTranslator(source='auto', target='en')

def read_last_timestamp():
    try:
        with open(TIMESTAMP_FILE, 'r') as f:
            return int(f.read().strip())
    except FileNotFoundError:
        return 0

def write_last_timestamp(timestamp):
    with open(TIMESTAMP_FILE, 'w') as f:
        f.write(str(timestamp))

def download_db(url, local_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    print(f"Échec du téléchargement de la base de données. Code de statut: {response.status_code}")
    return False

def connect_to_db(db_path):
    return sqlite3.connect(db_path)

def check_new_entries(conn, last_timestamp):
    cursor = conn.cursor()
    cursor.execute("""
        SELECT steam_game_id, first_seen
        FROM games 
        WHERE first_seen > ?
        ORDER BY first_seen ASC
    """, (last_timestamp,))
    return cursor.fetchall()

def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(steam_game_id)]['success']:
            return data[str(steam_game_id)]['data']
    return None

def filter_game(game_data):
    if game_data['type'] != 'game' or game_data.get('dlc', False):
        return False
    content_descriptors = game_data.get('content_descriptors', {}).get('ids', [])
    if 3 in content_descriptors:
        return False
    
    # Vérifier si l'anglais est supporté
    supported_languages = game_data.get('supported_languages', '').lower()
    if 'english' not in supported_languages:
        return False
    
    # Vérifier si le jeu est payant
    if game_data.get('is_free', True):
        return False
    
    return True

def get_twitter_client():
    client = tweepy.Client(
        consumer_key=os.getenv('TWITTER_CONSUMER_KEY'),
        consumer_secret=os.getenv('TWITTER_CONSUMER_SECRET'),
        access_token=os.getenv('TWITTER_ACCESS_TOKEN'),
        access_token_secret=os.getenv('TWITTER_ACCESS_TOKEN_SECRET')
    )
    return client

def get_game_tags_and_check_ai(app_id):
    try:
        url = f"https://store.steampowered.com/app/{app_id}/"
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Vérifier la présence de contenu généré par IA
            ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
            if ai_disclosure:
                print(f"Contenu AI détecté pour le jeu {app_id}")
                return None, None  # Le jeu utilise du contenu généré par IA
            
            # Récupérer les tags
            tag_elements = soup.find_all('a', class_='app_tag')
            tags = [tag.text.strip() for tag in tag_elements]
            return tags[:4], 'scraped'  # Retourne seulement les 4 premiers tags
    except Exception as e:
        print(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
    
    return None, None

def translate_to_english(text):
    try:
        # Détection de la langue
        lang = detect(text)
        if lang != 'en':
            translated = translator.translate(text)
            return translated
        return text
    except LangDetectException:
        print(f"Impossible de détecter la langue pour le texte: {text}")
        return text
    except Exception as e:
        print(f"Erreur lors de la traduction : {e}")
        return text

def clean_text(text):
    # Décode les entités HTML
    decoded_text = html.unescape(text)
    # Supprime les sauts de ligne et les espaces multiples
    cleaned_text = ' '.join(decoded_text.split())
    return cleaned_text

def is_priority_game(game_data):
    publisher = game_data.get('publishers', [])
    developer = game_data.get('developers', [])
    return not publisher or (publisher == developer)

def search_duckduckgo(query, max_results=5):
    results = DDGS().text(
        keywords=query,
        region='wt-wt',
        safesearch='off',
        timelimit='7d',
        max_results=max_results
    )
    return pd.DataFrame(list(results))

def is_twitter_link(url):
    return 'twitter.com' in url.lower()

def is_game_related(text):
    game_keywords = {
        'en': ['game', 'video game', 'developer', 'studio', 'gaming'],
        'fr': ['jeu', 'jeu vidéo', 'développeur', 'studio', 'gaming'],
        'es': ['juego', 'videojuego', 'desarrollador', 'estudio', 'gaming'],
        'de': ['spiel', 'videospiel', 'entwickler', 'studio', 'gaming'],
        'it': ['gioco', 'videogioco', 'sviluppatore', 'studio', 'gaming'],
        'ja': ['ゲーム', 'ビデオゲーム', '開発者', 'スタジオ', 'ゲーミング'],
    }
    
    try:
        lang = detect(text)
        if lang not in game_keywords:
            text = translator.translate(text, dest='en')
            lang = 'en'
        return any(keyword.lower() in text.lower() for keyword in game_keywords[lang])
    except:
        return False

def extract_twitter_handle(url):
    match = re.search(r'twitter\.com/(\w+)', url)
    if match:
        return '@' + match.group(1)
    return None

def name_similarity(name1, name2):
    return ratio(name1.lower(), name2.lower())

def get_game_studio_twitter(studio_name):
    search_query = f"{studio_name} twitter"
    results_df = search_duckduckgo(search_query)
    
    for index, row in results_df.iterrows():
        if is_twitter_link(row['href']):
            handle = extract_twitter_handle(row['href'])
            if handle and is_game_related(row['body']):
                # Vérifier la similarité du nom
                similarity = name_similarity(studio_name, handle[1:])  # Ignorer le '@'
                if similarity >= 0.9:
                    return handle
    
    return studio_name  # Retourne le nom du studio si aucun compte Twitter pertinent n'est trouvé

def format_tweet_message(game_data, tags, first_seen, tags_source):
    try:
        name = clean_text(game_data['name'])
        developers = game_data.get('developers', [])
        developer_handles = []
        for dev in developers:
            handle = get_game_studio_twitter(dev)
            developer_handles.append(handle)
        developers_str = ", ".join(developer_handles)
        
        description = clean_text(translate_to_english(game_data.get('short_description', '')))
        app_id = game_data['steam_appid']
        release_date = game_data.get('release_date', {}).get('date', 'TBA')
        
        # Formater la date
        date = datetime.fromtimestamp(first_seen, PARIS_TZ).strftime("%m-%d-%y")
        
        # Formater les tags
        tags_str = ", ".join(clean_text(tag) for tag in tags) if tags else "No tags available"
        
        # Construire le lien Steam
        steam_link = f"https://store.steampowered.com/app/{app_id}"
        
        # Construire le tweet avec le nouveau format
        tweet = f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 {description}\n{steam_link}"
        
        # Vérifier et ajuster la longueur du tweet si nécessaire
        if len(tweet) > 280:
            available_space = 280 - len(f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 ...\n{steam_link}")
            truncated_description = description[:available_space] + "..."
            tweet = f"{date} ⏵ {name}\n🏷️ {tags_str}\n🧑‍💻 {developers_str}\n⏳ {release_date}\n📜 {truncated_description}\n{steam_link}"
        
        return tweet
    except KeyError as e:
        print(f"Erreur lors du formatage du tweet: Clé manquante - {e}")
        return None
    except Exception as e:
        print(f"Erreur inattendue lors du formatage du tweet: {e}")
        return None

def send_tweet(message):
    client = get_twitter_client()
    try:
        response = client.create_tweet(text=message)
        return response.data['id']
    except Exception as e:
        print(f"Erreur lors de la création du tweet: {e}")
        return None

def main():
    db_url = f"https://raw.githubusercontent.com/{os.getenv('GITHUB_USERNAME')}/{GITHUB_REPO}/main/{DB_FILE_PATH}"
    last_timestamp = read_last_timestamp()
    new_last_timestamp = last_timestamp

    total_games = 0
    published_games = 0
    priority_tweets = []
    non_priority_tweets = []

    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if download_db(db_url, temp_db.name):
            conn = connect_to_db(temp_db.name)
            new_entries = check_new_entries(conn, last_timestamp)
            
            for steam_game_id, first_seen in new_entries:
                total_games += 1
                print(f"Nouveau jeu trouvé : Steam ID: {steam_game_id}, First Seen: {first_seen}")
                game_data = get_game_details(steam_game_id)
                if game_data and filter_game(game_data):
                    tags, tags_source = get_game_tags_and_check_ai(steam_game_id)
                    if tags is None:
                        print(f"Le jeu avec Steam ID {steam_game_id} utilise du contenu généré par IA ou n'a pas pu être scrapé.")
                        continue
                    message = format_tweet_message(game_data, tags, first_seen, tags_source)
                    if message:
                        if is_priority_game(game_data):
                            priority_tweets.append((message, game_data, first_seen))
                        else:
                            non_priority_tweets.append((message, game_data, first_seen))
                    else:
                        print(f"Échec du formatage du tweet pour {game_data['name']}")
                else:
                    print(f"Le jeu avec Steam ID {steam_game_id} ne répond pas aux critères de tweet ou les détails n'ont pas pu être récupérés.")
            
            conn.close()
        else:
            print("Échec du téléchargement de la base de données")
    
    os.unlink(temp_db.name)  # Supprime le fichier temporaire

    # Publier les tweets prioritaires
    for message, game_data, first_seen in priority_tweets:
        if published_games >= MAX_TWEETS_PER_DAY:
            break
        tweet_id = send_tweet(message)
        if tweet_id:
            print(f"Tweet prioritaire publié pour {game_data['name']} (ID: {tweet_id})")
            new_last_timestamp = max(new_last_timestamp, first_seen)
            published_games += 1
        else:
            print(f"Échec de la publication du tweet prioritaire pour {game_data['name']}")

    # Publier les tweets non prioritaires si la limite n'est pas atteinte
    for message, game_data, first_seen in non_priority_tweets:
        if published_games >= MAX_TWEETS_PER_DAY:
            break
        tweet_id = send_tweet(message)
        if tweet_id:
            print(f"Tweet non prioritaire publié pour {game_data['name']} (ID: {tweet_id})")
            new_last_timestamp = max(new_last_timestamp, first_seen)
            published_games += 1
        else:
            print(f"Échec de la publication du tweet non prioritaire pour {game_data['name']}")

    if new_last_timestamp > last_timestamp:
        write_last_timestamp(new_last_timestamp)
        print(f"Timestamp mis à jour : {new_last_timestamp}")

    print(f"\nRésumé : {published_games} jeux publiés sur {total_games} jeux traités au total.")
    print(f"Tweets prioritaires : {len(priority_tweets)}")
    print(f"Tweets non prioritaires : {len(non_priority_tweets)}")

if __name__ == "__main__":
    main()
# Out:
# Nouveau jeu trouvé : Steam ID: 3035140, First Seen: 1721865589
# Contenu AI détecté pour le jeu 3035140
# Le jeu avec Steam ID 3035140 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Nouveau jeu trouvé : Steam ID: 3101700, First Seen: 1721865589
# Contenu AI détecté pour le jeu 3101700
# Le jeu avec Steam ID 3101700 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Nouveau jeu trouvé : Steam ID: 3113480, First Seen: 1721865589
# Contenu AI détecté pour le jeu 3113480
# Le jeu avec Steam ID 3113480 utilise du contenu généré par IA ou n'a pas pu être scrapé.
# Nouveau jeu trouvé : Steam ID: 3086860, First Seen: 1721865589
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 336
#     333     print(f"Tweets non prioritaires : {len(non_priority_tweets)}")
#     335 if __name__ == "__main__":
# --> 336     main()
#
# Cell In[18], line 286, in main()
#     284     print(f"Le jeu avec Steam ID {steam_game_id} utilise du contenu généré par IA ou n'a pas pu être scrapé.")
#     285     continue
# --> 286 message = format_tweet_message(game_data, tags, first_seen, tags_source)
#     287 if message:
#     288     if is_priority_game(game_data):
#
# Cell In[18], line 219, in format_tweet_message(game_data, tags, first_seen, tags_source)
#     217 developer_handles = []
#     218 for dev in developers:
# --> 219     handle = get_game_studio_twitter(dev)
#     220     developer_handles.append(handle)
#     221 developers_str = ", ".join(developer_handles)
#
# Cell In[18], line 200, in get_game_studio_twitter(studio_name)
#     198 def get_game_studio_twitter(studio_name):
#     199     search_query = f"{studio_name} twitter"
# --> 200     results_df = search_duckduckgo(search_query)
#     202     for index, row in results_df.iterrows():
#     203         if is_twitter_link(row['href']):
#
# Cell In[18], line 158, in search_duckduckgo(query, max_results)
#     157 def search_duckduckgo(query, max_results=5):
# --> 158     results = DDGS().text(
#     159         keywords=query,
#     160         region='wt-wt',
#     161         safesearch='off',
#     162         timelimit='7d',
#     163         max_results=max_results
#     164     )
#     165     return pd.DataFrame(list(results))
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/duckduckgo_search/duckduckgo_search.py:229, in DDGS.text(self, keywords, region, safesearch, timelimit, backend, max_results)
#     226     warnings.warn("lxml is not installed. Using backend='api'.", stacklevel=2)
#     228 if backend == "api":
# --> 229     results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#     230 elif backend == "html":
#     231     results = self._text_html(keywords, region, timelimit, max_results)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/duckduckgo_search/duckduckgo_search.py:313, in DDGS._text_api(self, keywords, region, safesearch, timelimit, max_results)
#     311     slist.extend(range(23, max_results, 50))
#     312 try:
# --> 313     for r in self._executor.map(_text_api_page, slist):
#     314         results.extend(r)
#     315 except Exception as e:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
