# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random

# Fonction pour télécharger la base de données steam_games.db
def download_db(url, local_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    print(f"Échec du téléchargement de la base de données. Code de statut: {response.status_code}")
    return False

# Fonction pour obtenir les détails d'un jeu via l'API Steam
def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(steam_game_id)]['success']:
            return data[str(steam_game_id)]['data']
    return None

# Fonction pour obtenir les informations de la page Steam d'un jeu
def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Vérifier la présence de contenu généré par IA
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        
        # Recherche de la section "AI Generated Content Disclosure"
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        # Récupérer les tags
        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except Exception as e:
        print(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
        return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                print(f"Database is locked. Retrying in {delay} seconds...")
                time.sleep(delay)
                delay *= 2  # Augmenter le délai exponentiellement
            else:
                raise


def ensure_column_exists(cursor, table_name, column_name, column_type):
    """Vérifie si une colonne existe dans la table et l'ajoute si ce n'est pas le cas."""
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        print(f"Colonne '{column_name}' ajoutée à la table {table_name}")



# Fonction principale

def update_aug_steam_games():
    # Charger le dernier game_id traité
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
    except FileNotFoundError:
        last_processed_id = 12570  # Valeur par défaut si le fichier n'existe pas

    # Télécharger steam_games.db
    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            print("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            # Connexion aux bases de données
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            # Vérifier et ajouter la colonne 'type' si nécessaire
            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            # Récupérer les 500 prochains game_ids
            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 1000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                print(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    # Préparer les données pour l'insertion
                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    # Insérer ou mettre à jour les données
                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                # Mettre à jour le dernier game_id traité
                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                # Pause pour éviter de surcharger l'API
                time.sleep(random.uniform(0.5, 1.7))

            # Commit des changements
            conn_aug.commit()
            
        except Exception as e:
            print(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    # Supprimer le fichier temporaire
    os.unlink(temp_db.name)

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# Traitement du game_id : 33280
# Traitement du game_id : 33287
# Traitement du game_id : 33288
# Traitement du game_id : 33289
# Traitement du game_id : 33290
# Traitement du game_id : 33310
# Traitement du game_id : 33320
# Traitement du game_id : 33325
# Traitement du game_id : 33326
# Traitement du game_id : 33349
# Traitement du game_id : 33359
# Traitement du game_id : 33360
# Traitement du game_id : 33361
# Traitement du game_id : 33362
# Traitement du game_id : 33370
# Traitement du game_id : 33371
# Traitement du game_id : 33390
# Traitement du game_id : 33400
# Traitement du game_id : 33420
# Traitement du game_id : 33428
# Traitement du game_id : 33435
# Traitement du game_id : 33436
# Traitement du game_id : 33446
# Traitement du game_id : 33447
# Traitement du game_id : 33448
# Traitement du game_id : 33456
# Traitement du game_id : 33457
# Traitement du game_id : 33460
# Traitement du game_id : 33500
# Traitement du game_id : 33510
# Traitement du game_id : 33520
# Traitement du game_id : 33530
# Traitement du game_id : 33540
# Traitement du game_id : 33549
# Traitement du game_id : 33550
# Traitement du game_id : 33559
# Traitement du game_id : 33560
# Traitement du game_id : 33570
# Traitement du game_id : 33580
# Traitement du game_id : 33600
# Traitement du game_id : 33610
# Traitement du game_id : 33620
# Traitement du game_id : 33630
# Traitement du game_id : 33650
# Traitement du game_id : 33660
# Traitement du game_id : 33670
# Traitement du game_id : 33680
# Traitement du game_id : 33700
# Traitement du game_id : 33710
# Traitement du game_id : 33720
# Traitement du game_id : 33730
# Traitement du game_id : 33740
# Traitement du game_id : 33750
# Traitement du game_id : 33760
# Traitement du game_id : 33770
# Traitement du game_id : 33780
# Traitement du game_id : 33790
# Traitement du game_id : 33900
# Traitement du game_id : 33905
# Traitement du game_id : 33909
# Traitement du game_id : 33910
# Traitement du game_id : 33919
# Traitement du game_id : 33920
# Traitement du game_id : 33930
# Traitement du game_id : 33934
# Traitement du game_id : 33935
# Traitement du game_id : 33936
# Traitement du game_id : 33950
# Traitement du game_id : 33960
# Traitement du game_id : 33970
# Traitement du game_id : 33980
# Traitement du game_id : 33990
# Traitement du game_id : 34000
# Traitement du game_id : 34009
# Traitement du game_id : 34010
# Traitement du game_id : 34019
# Traitement du game_id : 34030
# Traitement du game_id : 34039
# Traitement du game_id : 34049
# Traitement du game_id : 34050
# Traitement du game_id : 34110
# Traitement du game_id : 34120
# Traitement du game_id : 34170
# Traitement du game_id : 34171
# Traitement du game_id : 34172
# Traitement du game_id : 34173
# Traitement du game_id : 34174
# Traitement du game_id : 34175
# Traitement du game_id : 34176
# Traitement du game_id : 34177
# Traitement du game_id : 34178
# Traitement du game_id : 34179
# Traitement du game_id : 34184
# Traitement du game_id : 34189
# Traitement du game_id : 34190
# Traitement du game_id : 34200
# Traitement du game_id : 34220
# Traitement du game_id : 34229
# Traitement du game_id : 34250
# Traitement du game_id : 34270
# Traitement du game_id : 34272
# Traitement du game_id : 34273
# Traitement du game_id : 34274
# Traitement du game_id : 34275
# Traitement du game_id : 34276
# Traitement du game_id : 34277
# Traitement du game_id : 34278
# Traitement du game_id : 34279
# Traitement du game_id : 34280
# Traitement du game_id : 34281
# Traitement du game_id : 34282
# Traitement du game_id : 34283
# Traitement du game_id : 34284
# Traitement du game_id : 34285
# Traitement du game_id : 34286
# Traitement du game_id : 34287
# Traitement du game_id : 34288
# Traitement du game_id : 34289
# Traitement du game_id : 34310
# Traitement du game_id : 34311
# Traitement du game_id : 34312
# Traitement du game_id : 34313
# Traitement du game_id : 34314
# Traitement du game_id : 34315
# Traitement du game_id : 34316
# Traitement du game_id : 34317
# Traitement du game_id : 34318
# Traitement du game_id : 34319
# Traitement du game_id : 34330
# Traitement du game_id : 34342
# Traitement du game_id : 34343
# Traitement du game_id : 34344
# Traitement du game_id : 34345
# Traitement du game_id : 34346
# Traitement du game_id : 34347
# Traitement du game_id : 34348
# Traitement du game_id : 34350
# Traitement du game_id : 34390
# Traitement du game_id : 34400
# Traitement du game_id : 34410
# Traitement du game_id : 34420
# Traitement du game_id : 34440
# Traitement du game_id : 34450
# Traitement du game_id : 34460
# Traitement du game_id : 34470
# Traitement du game_id : 34490
# Traitement du game_id : 34491
# Traitement du game_id : 34492
# Traitement du game_id : 34493
# Traitement du game_id : 34494
# Traitement du game_id : 34495
# Traitement du game_id : 34496
# Traitement du game_id : 34497
# Traitement du game_id : 34498
# Traitement du game_id : 34500
# Traitement du game_id : 34510
# Traitement du game_id : 34600
# Traitement du game_id : 34609
# Traitement du game_id : 34610
# Traitement du game_id : 34611
# Traitement du game_id : 34612
# Traitement du game_id : 34613
# Traitement du game_id : 34614
# Traitement du game_id : 34615
# Traitement du game_id : 34616
# Traitement du game_id : 34620
# Traitement du game_id : 34630
# Traitement du game_id : 34640
# Traitement du game_id : 34650
# Traitement du game_id : 34660
# Traitement du game_id : 34670
# Traitement du game_id : 34680
# Traitement du game_id : 34800
# Traitement du game_id : 34810
# Traitement du game_id : 34820
# Traitement du game_id : 34830
# Traitement du game_id : 34841
# Traitement du game_id : 34842
# Traitement du game_id : 34850
# Traitement du game_id : 34860
# Traitement du game_id : 34870
# Traitement du game_id : 34880
# Traitement du game_id : 34900
# Traitement du game_id : 34910
# Traitement du game_id : 34920
# Traitement du game_id : 34930
# Traitement du game_id : 35000
# Traitement du game_id : 35010
# Traitement du game_id : 35019
# Traitement du game_id : 35020
# Traitement du game_id : 35030
# Traitement du game_id : 35040
# Traitement du game_id : 35050
# Traitement du game_id : 35060
# Traitement du game_id : 35070
# Traitement du game_id : 35080
# Traitement du game_id : 35081
# Traitement du game_id : 35082
# Traitement du game_id : 35083
# Traitement du game_id : 35084
# Traitement du game_id : 35085
# Traitement du game_id : 35086
# Traitement du game_id : 35087
# Traitement du game_id : 35088
# Traitement du game_id : 35089
# Traitement du game_id : 35090
# Traitement du game_id : 35091
# Traitement du game_id : 35092
# Traitement du game_id : 35093
# Traitement du game_id : 35094
# Traitement du game_id : 35095
# Traitement du game_id : 35096
# Traitement du game_id : 35097
# Traitement du game_id : 35098
# Traitement du game_id : 35099
# Traitement du game_id : 35100
# Traitement du game_id : 35101
# Traitement du game_id : 35102
# Traitement du game_id : 35103
# Traitement du game_id : 35110
# Traitement du game_id : 35130
# Traitement du game_id : 35134
# Traitement du game_id : 35135
# Traitement du game_id : 35136
# Traitement du game_id : 35137
# Traitement du game_id : 38210
# Traitement du game_id : 38220
# Traitement du game_id : 38229
# Traitement du game_id : 38230
# Traitement du game_id : 38240
# Traitement du game_id : 38400
# Traitement du game_id : 38410
# Traitement du game_id : 38420
# Traitement du game_id : 38430
# Traitement du game_id : 38440
# Traitement du game_id : 38450
# Traitement du game_id : 38460
# Traitement du game_id : 38480
# Traitement du game_id : 38490
# Traitement du game_id : 38530
# Traitement du game_id : 38600
# Traitement du game_id : 38700
# Traitement du game_id : 38710
# Traitement du game_id : 38720
# Traitement du game_id : 38730
# Traitement du game_id : 38740
# Traitement du game_id : 38743
# Traitement du game_id : 38750
# Traitement du game_id : 38800
# Traitement du game_id : 38810
# Traitement du game_id : 38820
# Traitement du game_id : 38830
# Traitement du game_id : 38900
# Traitement du game_id : 38910
# Traitement du game_id : 38920
# Traitement du game_id : 38921
# Traitement du game_id : 38922
# Traitement du game_id : 38923
# Traitement du game_id : 38924
# Traitement du game_id : 38925
# Traitement du game_id : 38926
# Traitement du game_id : 38927
# Traitement du game_id : 39000
# Traitement du game_id : 39100
# Traitement du game_id : 39110
# Traitement du game_id : 39120
# Traitement du game_id : 39122
# Traitement du game_id : 39123
# Traitement du game_id : 39124
# Traitement du game_id : 39125
# Traitement du game_id : 39126
# Traitement du game_id : 39127
# Traitement du game_id : 39128
# Traitement du game_id : 39129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 191
#     188     os.unlink(temp_db.name)
#     190 if __name__ == "__main__":
# --> 191     update_aug_steam_games()
#
# Cell In[11], line 133, in update_aug_steam_games()
#     131 game_id = game_id[0]
#     132 print(f"Traitement du game_id : {game_id}")
# --> 133 game_data = get_game_details(game_id)
#     134 if game_data:
#     135     steam_page_info = get_steam_page_info(game_id)
#
# Cell In[11], line 26, in get_game_details(steam_game_id)
#      24 def get_game_details(steam_game_id):
#      25     url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
# ---> 26     response = requests.get(url)
#      27     if response.status_code == 200:
#      28         data = response.json()
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random
import logging

# Configuration du logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def download_db(url, local_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        logging.info(f"Base de données téléchargée avec succès: {local_path}")
        return True
    except requests.RequestException as e:
        logging.error(f"Échec du téléchargement de la base de données: {e}")
        return False

def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        if data[str(steam_game_id)]['success']:
            logging.info(f"Détails récupérés pour le jeu {steam_game_id}")
            return data[str(steam_game_id)]['data']
        else:
            logging.warning(f"Pas de données pour le jeu {steam_game_id}")
    except requests.RequestException as e:
        logging.error(f"Erreur lors de la récupération des détails pour le jeu {steam_game_id}: {e}")
    except json.JSONDecodeError as e:
        logging.error(f"Erreur de décodage JSON pour le jeu {steam_game_id}: {e}")
    return None

def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        logging.info(f"Informations de la page Steam récupérées pour le jeu {app_id}")
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except requests.RequestException as e:
        logging.error(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
    except Exception as e:
        logging.error(f"Erreur inattendue lors du scraping pour le jeu {app_id}: {e}")
    return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                logging.warning(f"Base de données verrouillée. Nouvelle tentative dans {delay} secondes...")
                time.sleep(delay)
                delay *= 2
            else:
                raise

def ensure_column_exists(cursor, table_name, column_name, column_type):
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        logging.info(f"Colonne '{column_name}' ajoutée à la table {table_name}")

def update_aug_steam_games():
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
        logging.info(f"Dernier game_id traité: {last_processed_id}")
    except FileNotFoundError:
        last_processed_id = 12570
        logging.info(f"Fichier last_processed_game_id.txt non trouvé. Utilisation de la valeur par défaut: {last_processed_id}")

    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            logging.error("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 1000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                logging.info(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                time.sleep(random.uniform(0.5, 1.7))

            conn_aug.commit()
            logging.info("Mise à jour terminée avec succès")
            
        except Exception as e:
            logging.error(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    os.unlink(temp_db.name)
    logging.info("Fichier temporaire supprimé")

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# 2024-08-01 19:51:59,523 - INFO - Dernier game_id traité: 81286
# 2024-08-01 19:52:00,328 - INFO - Base de données téléchargée avec succès: /var/folders/b5/ckj362xj7ng_xqbjrqp077qh0000gn/T/tmpkwjcclmw.db
# 2024-08-01 19:52:00,333 - INFO - Traitement du game_id : 81287
# 2024-08-01 19:52:00,756 - INFO - Détails récupérés pour le jeu 81287
# 2024-08-01 19:52:01,415 - INFO - Informations de la page Steam récupérées pour le jeu 81287
# 2024-08-01 19:52:02,257 - INFO - Traitement du game_id : 81288
# 2024-08-01 19:52:02,492 - INFO - Détails récupérés pour le jeu 81288
# 2024-08-01 19:52:03,269 - INFO - Informations de la page Steam récupérées pour le jeu 81288
# 2024-08-01 19:52:04,869 - INFO - Traitement du game_id : 81289
# 2024-08-01 19:52:05,122 - INFO - Détails récupérés pour le jeu 81289
# 2024-08-01 19:52:05,875 - INFO - Informations de la page Steam récupérées pour le jeu 81289
# 2024-08-01 19:52:06,968 - INFO - Traitement du game_id : 81290
# 2024-08-01 19:52:07,184 - INFO - Détails récupérés pour le jeu 81290
# 2024-08-01 19:52:07,969 - INFO - Informations de la page Steam récupérées pour le jeu 81290
# 2024-08-01 19:52:08,638 - INFO - Traitement du game_id : 81291
# 2024-08-01 19:52:08,845 - WARNING - Pas de données pour le jeu 81291
# 2024-08-01 19:52:09,827 - INFO - Traitement du game_id : 81292
# 2024-08-01 19:52:10,081 - INFO - Détails récupérés pour le jeu 81292
# 2024-08-01 19:52:10,799 - INFO - Informations de la page Steam récupérées pour le jeu 81292
# 2024-08-01 19:52:12,233 - INFO - Traitement du game_id : 81293
# 2024-08-01 19:52:12,437 - WARNING - Pas de données pour le jeu 81293
# 2024-08-01 19:52:13,097 - INFO - Traitement du game_id : 81294
# 2024-08-01 19:52:13,346 - INFO - Détails récupérés pour le jeu 81294
# 2024-08-01 19:52:14,098 - INFO - Informations de la page Steam récupérées pour le jeu 81294
# 2024-08-01 19:52:14,655 - INFO - Traitement du game_id : 81295
# 2024-08-01 19:52:14,875 - INFO - Détails récupérés pour le jeu 81295
# 2024-08-01 19:52:15,679 - INFO - Informations de la page Steam récupérées pour le jeu 81295
# 2024-08-01 19:52:17,314 - INFO - Traitement du game_id : 81296
# 2024-08-01 19:52:17,542 - INFO - Détails récupérés pour le jeu 81296
# 2024-08-01 19:52:18,227 - INFO - Informations de la page Steam récupérées pour le jeu 81296
# 2024-08-01 19:52:19,652 - INFO - Traitement du game_id : 81297
# 2024-08-01 19:52:19,871 - WARNING - Pas de données pour le jeu 81297
# 2024-08-01 19:52:21,105 - INFO - Traitement du game_id : 81298
# 2024-08-01 19:52:21,323 - WARNING - Pas de données pour le jeu 81298
# 2024-08-01 19:52:22,981 - INFO - Traitement du game_id : 81299
# 2024-08-01 19:52:23,251 - INFO - Détails récupérés pour le jeu 81299
# 2024-08-01 19:52:23,954 - INFO - Informations de la page Steam récupérées pour le jeu 81299
# 2024-08-01 19:52:25,318 - INFO - Traitement du game_id : 81300
# 2024-08-01 19:52:25,551 - INFO - Détails récupérés pour le jeu 81300
# 2024-08-01 19:52:26,124 - INFO - Informations de la page Steam récupérées pour le jeu 81300
# 2024-08-01 19:52:27,046 - INFO - Traitement du game_id : 81301
# 2024-08-01 19:52:27,287 - INFO - Détails récupérés pour le jeu 81301
# 2024-08-01 19:52:28,032 - INFO - Informations de la page Steam récupérées pour le jeu 81301
# 2024-08-01 19:52:29,439 - INFO - Traitement du game_id : 81302
# 2024-08-01 19:52:29,675 - WARNING - Pas de données pour le jeu 81302
# 2024-08-01 19:52:31,073 - INFO - Traitement du game_id : 81303
# 2024-08-01 19:52:31,285 - WARNING - Pas de données pour le jeu 81303
# 2024-08-01 19:52:32,100 - INFO - Traitement du game_id : 81304
# 2024-08-01 19:52:32,336 - INFO - Détails récupérés pour le jeu 81304
# 2024-08-01 19:52:33,147 - INFO - Informations de la page Steam récupérées pour le jeu 81304
# 2024-08-01 19:52:34,103 - INFO - Traitement du game_id : 81305
# 2024-08-01 19:52:34,520 - INFO - Détails récupérés pour le jeu 81305
# 2024-08-01 19:52:35,191 - INFO - Informations de la page Steam récupérées pour le jeu 81305
# 2024-08-01 19:52:36,380 - INFO - Traitement du game_id : 81306
# 2024-08-01 19:52:36,639 - INFO - Détails récupérés pour le jeu 81306
# 2024-08-01 19:52:37,405 - INFO - Informations de la page Steam récupérées pour le jeu 81306
# 2024-08-01 19:52:39,001 - INFO - Traitement du game_id : 81307
# 2024-08-01 19:52:39,217 - INFO - Détails récupérés pour le jeu 81307
# 2024-08-01 19:52:39,880 - INFO - Informations de la page Steam récupérées pour le jeu 81307
# 2024-08-01 19:52:40,678 - INFO - Traitement du game_id : 81308
# 2024-08-01 19:52:41,015 - INFO - Détails récupérés pour le jeu 81308
# 2024-08-01 19:52:41,531 - INFO - Informations de la page Steam récupérées pour le jeu 81308
# 2024-08-01 19:52:43,206 - INFO - Traitement du game_id : 81309
# 2024-08-01 19:52:43,449 - INFO - Détails récupérés pour le jeu 81309
# 2024-08-01 19:52:44,191 - INFO - Informations de la page Steam récupérées pour le jeu 81309
# 2024-08-01 19:52:45,596 - INFO - Traitement du game_id : 81310
# 2024-08-01 19:52:45,860 - INFO - Détails récupérés pour le jeu 81310
# 2024-08-01 19:52:46,486 - INFO - Informations de la page Steam récupérées pour le jeu 81310
# 2024-08-01 19:52:47,466 - INFO - Traitement du game_id : 81311
# 2024-08-01 19:52:47,791 - INFO - Détails récupérés pour le jeu 81311
# 2024-08-01 19:52:48,661 - INFO - Informations de la page Steam récupérées pour le jeu 81311
# 2024-08-01 19:52:50,348 - INFO - Traitement du game_id : 81312
# 2024-08-01 19:52:50,565 - WARNING - Pas de données pour le jeu 81312
# 2024-08-01 19:52:52,021 - INFO - Traitement du game_id : 81313
# 2024-08-01 19:52:52,246 - INFO - Détails récupérés pour le jeu 81313
# 2024-08-01 19:52:53,031 - INFO - Informations de la page Steam récupérées pour le jeu 81313
# 2024-08-01 19:52:54,089 - INFO - Traitement du game_id : 81314
# 2024-08-01 19:52:54,324 - INFO - Détails récupérés pour le jeu 81314
# 2024-08-01 19:52:55,045 - INFO - Informations de la page Steam récupérées pour le jeu 81314
# 2024-08-01 19:52:56,413 - INFO - Traitement du game_id : 81315
# 2024-08-01 19:52:56,636 - WARNING - Pas de données pour le jeu 81315
# 2024-08-01 19:52:57,719 - INFO - Traitement du game_id : 81316
# 2024-08-01 19:52:57,949 - INFO - Détails récupérés pour le jeu 81316
# 2024-08-01 19:52:58,648 - INFO - Informations de la page Steam récupérées pour le jeu 81316
# 2024-08-01 19:53:00,075 - INFO - Traitement du game_id : 81317
# 2024-08-01 19:53:00,323 - INFO - Détails récupérés pour le jeu 81317
# 2024-08-01 19:53:00,911 - INFO - Informations de la page Steam récupérées pour le jeu 81317
# 2024-08-01 19:53:01,926 - INFO - Traitement du game_id : 81318
# 2024-08-01 19:53:02,208 - INFO - Détails récupérés pour le jeu 81318
# 2024-08-01 19:53:03,024 - INFO - Informations de la page Steam récupérées pour le jeu 81318
# 2024-08-01 19:53:04,479 - INFO - Traitement du game_id : 81319
# 2024-08-01 19:53:04,982 - WARNING - Pas de données pour le jeu 81319
# 2024-08-01 19:53:05,505 - INFO - Traitement du game_id : 81320
# 2024-08-01 19:53:05,840 - INFO - Détails récupérés pour le jeu 81320
# 2024-08-01 19:53:06,631 - INFO - Informations de la page Steam récupérées pour le jeu 81320
# 2024-08-01 19:53:08,334 - INFO - Traitement du game_id : 81321
# 2024-08-01 19:53:08,536 - WARNING - Pas de données pour le jeu 81321
# 2024-08-01 19:53:09,488 - INFO - Traitement du game_id : 81322
# 2024-08-01 19:53:09,731 - INFO - Détails récupérés pour le jeu 81322
# 2024-08-01 19:53:10,751 - INFO - Informations de la page Steam récupérées pour le jeu 81322
# 2024-08-01 19:53:12,235 - INFO - Traitement du game_id : 81323
# 2024-08-01 19:53:12,562 - INFO - Détails récupérés pour le jeu 81323
# 2024-08-01 19:53:12,959 - INFO - Informations de la page Steam récupérées pour le jeu 81323
# 2024-08-01 19:53:13,985 - INFO - Traitement du game_id : 81324
# 2024-08-01 19:53:14,224 - INFO - Détails récupérés pour le jeu 81324
# 2024-08-01 19:53:14,938 - INFO - Informations de la page Steam récupérées pour le jeu 81324
# 2024-08-01 19:53:16,573 - INFO - Traitement du game_id : 81325
# 2024-08-01 19:53:16,788 - WARNING - Pas de données pour le jeu 81325
# 2024-08-01 19:53:18,151 - INFO - Traitement du game_id : 81326
# 2024-08-01 19:53:18,409 - INFO - Détails récupérés pour le jeu 81326
# 2024-08-01 19:53:19,126 - INFO - Informations de la page Steam récupérées pour le jeu 81326
# 2024-08-01 19:53:20,501 - INFO - Traitement du game_id : 81327
# 2024-08-01 19:53:20,703 - WARNING - Pas de données pour le jeu 81327
# 2024-08-01 19:53:21,438 - INFO - Traitement du game_id : 81328
# 2024-08-01 19:53:21,651 - INFO - Détails récupérés pour le jeu 81328
# 2024-08-01 19:53:22,411 - INFO - Informations de la page Steam récupérées pour le jeu 81328
# 2024-08-01 19:53:23,456 - INFO - Traitement du game_id : 81329
# 2024-08-01 19:53:23,679 - INFO - Détails récupérés pour le jeu 81329
# 2024-08-01 19:53:24,301 - INFO - Informations de la page Steam récupérées pour le jeu 81329
# 2024-08-01 19:53:24,950 - INFO - Traitement du game_id : 81330
# 2024-08-01 19:53:25,169 - INFO - Détails récupérés pour le jeu 81330
# 2024-08-01 19:53:25,925 - INFO - Informations de la page Steam récupérées pour le jeu 81330
# 2024-08-01 19:53:27,521 - INFO - Traitement du game_id : 81331
# 2024-08-01 19:53:27,840 - INFO - Détails récupérés pour le jeu 81331
# 2024-08-01 19:53:28,493 - INFO - Informations de la page Steam récupérées pour le jeu 81331
# 2024-08-01 19:53:29,483 - INFO - Traitement du game_id : 81332
# 2024-08-01 19:53:29,804 - INFO - Détails récupérés pour le jeu 81332
# 2024-08-01 19:53:30,635 - INFO - Informations de la page Steam récupérées pour le jeu 81332
# 2024-08-01 19:53:31,293 - INFO - Traitement du game_id : 81333
# 2024-08-01 19:53:31,505 - WARNING - Pas de données pour le jeu 81333
# 2024-08-01 19:53:32,257 - INFO - Traitement du game_id : 81334
# 2024-08-01 19:53:32,478 - INFO - Détails récupérés pour le jeu 81334
# 2024-08-01 19:53:33,131 - INFO - Informations de la page Steam récupérées pour le jeu 81334
# 2024-08-01 19:53:54,050 - INFO - Traitement du game_id : 81335
# 2024-08-01 19:53:54,303 - INFO - Détails récupérés pour le jeu 81335
# 2024-08-01 19:53:55,040 - INFO - Informations de la page Steam récupérées pour le jeu 81335
# 2024-08-01 19:53:56,618 - INFO - Traitement du game_id : 81336
# 2024-08-01 19:53:56,849 - INFO - Détails récupérés pour le jeu 81336
# 2024-08-01 19:53:57,299 - INFO - Informations de la page Steam récupérées pour le jeu 81336
# 2024-08-01 19:55:22,986 - INFO - Informations de la page Steam récupérées pour le jeu 81383
# 2024-08-01 19:55:23,859 - INFO - Traitement du game_id : 81384
# 2024-08-01 19:55:24,116 - INFO - Détails récupérés pour le jeu 81384
# 2024-08-01 19:55:24,989 - INFO - Informations de la page Steam récupérées pour le jeu 81384
# 2024-08-01 19:55:25,651 - INFO - Traitement du game_id : 81385
# 2024-08-01 19:55:25,889 - INFO - Détails récupérés pour le jeu 81385
# 2024-08-01 19:55:26,535 - INFO - Informations de la page Steam récupérées pour le jeu 81385
# 2024-08-01 19:55:28,070 - INFO - Traitement du game_id : 81386
# 2024-08-01 19:55:28,303 - INFO - Détails récupérés pour le jeu 81386
# 2024-08-01 19:55:28,948 - INFO - Informations de la page Steam récupérées pour le jeu 81386
# 2024-08-01 19:55:30,532 - INFO - Traitement du game_id : 81387
# 2024-08-01 19:55:30,768 - INFO - Détails récupérés pour le jeu 81387
# 2024-08-01 19:55:31,536 - INFO - Informations de la page Steam récupérées pour le jeu 81387
# 2024-08-01 19:55:32,263 - INFO - Traitement du game_id : 81388
# 2024-08-01 19:55:32,520 - WARNING - Pas de données pour le jeu 81388
# 2024-08-01 19:55:33,717 - INFO - Traitement du game_id : 81389
# 2024-08-01 19:55:33,950 - INFO - Détails récupérés pour le jeu 81389
# 2024-08-01 19:55:34,773 - INFO - Informations de la page Steam récupérées pour le jeu 81389
# 2024-08-01 19:55:36,284 - INFO - Traitement du game_id : 81390
# 2024-08-01 19:55:36,534 - INFO - Détails récupérés pour le jeu 81390
# 2024-08-01 19:55:37,083 - INFO - Informations de la page Steam récupérées pour le jeu 81390
# 2024-08-01 19:55:38,471 - INFO - Traitement du game_id : 81391
# 2024-08-01 19:55:38,719 - INFO - Détails récupérés pour le jeu 81391
# 2024-08-01 19:55:40,325 - INFO - Informations de la page Steam récupérées pour le jeu 81391
# 2024-08-01 19:55:42,023 - INFO - Traitement du game_id : 81392
# 2024-08-01 19:55:42,280 - INFO - Détails récupérés pour le jeu 81392
# 2024-08-01 19:55:43,413 - INFO - Informations de la page Steam récupérées pour le jeu 81392
# 2024-08-01 19:55:44,318 - INFO - Traitement du game_id : 81393
# 2024-08-01 19:55:44,582 - INFO - Détails récupérés pour le jeu 81393
# 2024-08-01 19:55:45,570 - INFO - Informations de la page Steam récupérées pour le jeu 81393
# 2024-08-01 19:55:46,648 - INFO - Traitement du game_id : 81395
# 2024-08-01 19:55:46,873 - INFO - Détails récupérés pour le jeu 81395
# 2024-08-01 19:55:47,673 - INFO - Informations de la page Steam récupérées pour le jeu 81395
# 2024-08-01 19:55:48,978 - INFO - Traitement du game_id : 81396
# 2024-08-01 19:55:49,178 - WARNING - Pas de données pour le jeu 81396
# 2024-08-01 19:55:50,647 - INFO - Traitement du game_id : 81397
# 2024-08-01 19:55:50,889 - WARNING - Pas de données pour le jeu 81397
# 2024-08-01 19:55:51,463 - INFO - Traitement du game_id : 81398
# 2024-08-01 20:00:00,007 - INFO - Traitement du game_id : 81478
# 2024-08-01 20:00:00,741 - INFO - Détails récupérés pour le jeu 81478
# 2024-08-01 20:00:01,852 - INFO - Informations de la page Steam récupérées pour le jeu 81478
# 2024-08-01 20:00:03,122 - INFO - Traitement du game_id : 81479
# 2024-08-01 20:00:03,350 - INFO - Détails récupérés pour le jeu 81479
# 2024-08-01 20:00:04,050 - INFO - Informations de la page Steam récupérées pour le jeu 81479
# 2024-08-01 20:00:05,519 - INFO - Traitement du game_id : 81480
# 2024-08-01 20:00:05,811 - WARNING - Pas de données pour le jeu 81480
# 2024-08-01 20:00:07,216 - INFO - Traitement du game_id : 81481
# 2024-08-01 20:00:07,439 - INFO - Détails récupérés pour le jeu 81481
# 2024-08-01 20:00:08,347 - INFO - Informations de la page Steam récupérées pour le jeu 81481
# 2024-08-01 20:00:09,915 - INFO - Traitement du game_id : 81482
# 2024-08-01 20:00:10,135 - INFO - Détails récupérés pour le jeu 81482
# 2024-08-01 20:00:10,802 - INFO - Informations de la page Steam récupérées pour le jeu 81482
# 2024-08-01 20:00:11,515 - INFO - Traitement du game_id : 81483
# 2024-08-01 20:00:11,744 - INFO - Détails récupérés pour le jeu 81483
# 2024-08-01 20:00:12,526 - INFO - Informations de la page Steam récupérées pour le jeu 81483
# 2024-08-01 20:00:15,825 - INFO - Traitement du game_id : 81484
# 2024-08-01 20:00:16,061 - WARNING - Pas de données pour le jeu 81484
# 2024-08-01 20:00:17,068 - INFO - Traitement du game_id : 81485
# 2024-08-01 20:00:17,269 - WARNING - Pas de données pour le jeu 81485
# 2024-08-01 20:00:17,878 - INFO - Traitement du game_id : 81486
# 2024-08-01 20:00:18,114 - INFO - Détails récupérés pour le jeu 81486
# 2024-08-01 20:00:18,771 - INFO - Informations de la page Steam récupérées pour le jeu 81486
# 2024-08-01 20:00:19,909 - INFO - Traitement du game_id : 81487
# 2024-08-01 20:00:20,344 - INFO - Détails récupérés pour le jeu 81487
# 2024-08-01 20:00:21,048 - INFO - Informations de la page Steam récupérées pour le jeu 81487
# 2024-08-01 20:00:21,611 - INFO - Traitement du game_id : 81488
# 2024-08-01 20:00:22,069 - INFO - Détails récupérés pour le jeu 81488
# 2024-08-01 20:00:22,759 - INFO - Informations de la page Steam récupérées pour le jeu 81488
# 2024-08-01 20:00:23,799 - INFO - Traitement du game_id : 81489
# 2024-08-01 20:00:24,033 - INFO - Détails récupérés pour le jeu 81489
# 2024-08-01 20:00:24,893 - INFO - Informations de la page Steam récupérées pour le jeu 81489
# 2024-08-01 20:00:25,563 - INFO - Traitement du game_id : 81490
# 2024-08-01 20:00:25,793 - INFO - Détails récupérés pour le jeu 81490
# 2024-08-01 20:00:26,565 - INFO - Informations de la page Steam récupérées pour le jeu 81490
# 2024-08-01 20:00:27,544 - INFO - Traitement du game_id : 81491
# 2024-08-01 20:00:27,763 - INFO - Détails récupérés pour le jeu 81491
# 2024-08-01 20:00:28,686 - INFO - Informations de la page Steam récupérées pour le jeu 81491
# 2024-08-01 20:00:30,123 - INFO - Traitement du game_id : 81492
# 2024-08-01 20:00:30,380 - INFO - Détails récupérés pour le jeu 81492
# 2024-08-01 20:00:31,310 - INFO - Informations de la page Steam récupérées pour le jeu 81492
# 2024-08-01 20:00:32,038 - INFO - Traitement du game_id : 81493
# 2024-08-01 20:00:32,254 - WARNING - Pas de données pour le jeu 81493
# 2024-08-01 20:00:32,824 - INFO - Traitement du game_id : 81494
# 2024-08-01 20:00:33,058 - WARNING - Pas de données pour le jeu 81494
# 2024-08-01 20:00:33,775 - INFO - Traitement du game_id : 81495
# 2024-08-01 20:00:33,981 - WARNING - Pas de données pour le jeu 81495
# 2024-08-01 20:00:35,024 - INFO - Traitement du game_id : 81496
# 2024-08-01 20:00:35,241 - INFO - Détails récupérés pour le jeu 81496
# 2024-08-01 20:00:35,967 - INFO - Informations de la page Steam récupérées pour le jeu 81496
# 2024-08-01 20:00:37,573 - INFO - Traitement du game_id : 81497
# 2024-08-01 20:00:37,903 - WARNING - Pas de données pour le jeu 81497
# 2024-08-01 20:00:38,425 - INFO - Traitement du game_id : 81498
# 2024-08-01 20:00:38,828 - WARNING - Pas de données pour le jeu 81498
# 2024-08-01 20:00:39,848 - INFO - Traitement du game_id : 81499
# 2024-08-01 20:00:40,073 - INFO - Détails récupérés pour le jeu 81499
# 2024-08-01 20:00:40,990 - INFO - Informations de la page Steam récupérées pour le jeu 81499
# 2024-08-01 20:00:42,701 - INFO - Traitement du game_id : 81500
# 2024-08-01 20:00:42,955 - INFO - Détails récupérés pour le jeu 81500
# 2024-08-01 20:00:43,670 - INFO - Informations de la page Steam récupérées pour le jeu 81500
# 2024-08-01 20:00:44,673 - INFO - Traitement du game_id : 81501
# 2024-08-01 20:00:44,892 - INFO - Détails récupérés pour le jeu 81501
# 2024-08-01 20:00:45,651 - INFO - Informations de la page Steam récupérées pour le jeu 81501
# 2024-08-01 20:00:47,144 - INFO - Traitement du game_id : 81502
# 2024-08-01 20:00:47,431 - INFO - Détails récupérés pour le jeu 81502
# 2024-08-01 20:00:48,250 - INFO - Informations de la page Steam récupérées pour le jeu 81502
# 2024-08-01 20:00:48,959 - INFO - Traitement du game_id : 81503
# 2024-08-01 20:00:49,181 - INFO - Détails récupérés pour le jeu 81503
# 2024-08-01 20:00:49,810 - INFO - Informations de la page Steam récupérées pour le jeu 81503
# 2024-08-01 20:00:52,605 - INFO - Traitement du game_id : 81504
# 2024-08-01 20:00:53,035 - INFO - Détails récupérés pour le jeu 81504
# 2024-08-01 20:00:53,813 - INFO - Informations de la page Steam récupérées pour le jeu 81504
# 2024-08-01 20:00:54,807 - INFO - Traitement du game_id : 81505
# 2024-08-01 20:00:55,022 - INFO - Détails récupérés pour le jeu 81505
# 2024-08-01 20:00:55,851 - INFO - Informations de la page Steam récupérées pour le jeu 81505
# 2024-08-01 20:00:56,453 - INFO - Traitement du game_id : 81506
# 2024-08-01 20:00:56,679 - WARNING - Pas de données pour le jeu 81506
# 2024-08-01 20:00:57,731 - INFO - Traitement du game_id : 81507
# 2024-08-01 20:00:57,999 - INFO - Détails récupérés pour le jeu 81507
# 2024-08-01 20:00:58,859 - INFO - Informations de la page Steam récupérées pour le jeu 81507
# 2024-08-01 20:00:59,966 - INFO - Traitement du game_id : 81508
# 2024-08-01 20:01:00,191 - WARNING - Pas de données pour le jeu 81508
# 2024-08-01 20:01:01,171 - INFO - Traitement du game_id : 81509
# 2024-08-01 20:01:01,374 - WARNING - Pas de données pour le jeu 81509
# 2024-08-01 20:01:02,984 - INFO - Traitement du game_id : 81510
# 2024-08-01 20:01:03,205 - INFO - Détails récupérés pour le jeu 81510
# 2024-08-01 20:01:03,940 - INFO - Informations de la page Steam récupérées pour le jeu 81510
# 2024-08-01 20:01:04,850 - INFO - Traitement du game_id : 81511
# 2024-08-01 20:01:05,095 - INFO - Détails récupérés pour le jeu 81511
# 2024-08-01 20:01:05,790 - INFO - Informations de la page Steam récupérées pour le jeu 81511
# 2024-08-01 20:01:07,462 - INFO - Traitement du game_id : 81512
# 2024-08-01 20:01:07,712 - INFO - Détails récupérés pour le jeu 81512
# 2024-08-01 20:01:08,547 - INFO - Informations de la page Steam récupérées pour le jeu 81512
# 2024-08-01 20:01:09,626 - INFO - Traitement du game_id : 81513
# 2024-08-01 20:01:09,858 - INFO - Détails récupérés pour le jeu 81513
# 2024-08-01 20:01:10,541 - INFO - Informations de la page Steam récupérées pour le jeu 81513
# 2024-08-01 20:01:12,206 - INFO - Traitement du game_id : 81514
# 2024-08-01 20:01:12,438 - INFO - Détails récupérés pour le jeu 81514
# 2024-08-01 20:01:13,564 - INFO - Informations de la page Steam récupérées pour le jeu 81514
# 2024-08-01 20:01:14,751 - INFO - Traitement du game_id : 81515
# 2024-08-01 20:01:15,045 - WARNING - Pas de données pour le jeu 81515
# 2024-08-01 20:03:03,138 - INFO - Traitement du game_id : 81516
# 2024-08-01 20:03:03,440 - WARNING - Pas de données pour le jeu 81516
# 2024-08-01 20:03:04,728 - INFO - Traitement du game_id : 81517
# 2024-08-01 20:03:04,939 - INFO - Détails récupérés pour le jeu 81517
# 2024-08-01 20:03:05,919 - INFO - Informations de la page Steam récupérées pour le jeu 81517
# 2024-08-01 20:03:06,625 - INFO - Traitement du game_id : 81518
# 2024-08-01 20:03:06,854 - INFO - Détails récupérés pour le jeu 81518
# 2024-08-01 20:03:07,683 - INFO - Informations de la page Steam récupérées pour le jeu 81518
# 2024-08-01 20:03:09,091 - INFO - Traitement du game_id : 81519
# 2024-08-01 20:03:09,321 - INFO - Détails récupérés pour le jeu 81519
# 2024-08-01 20:03:10,034 - INFO - Informations de la page Steam récupérées pour le jeu 81519
# 2024-08-01 20:03:10,797 - INFO - Traitement du game_id : 81520
# 2024-08-01 20:03:11,122 - INFO - Détails récupérés pour le jeu 81520
# 2024-08-01 20:03:11,987 - INFO - Informations de la page Steam récupérées pour le jeu 81520
# 2024-08-01 20:03:13,359 - INFO - Traitement du game_id : 81521
# 2024-08-01 20:03:13,597 - WARNING - Pas de données pour le jeu 81521
# 2024-08-01 20:03:14,923 - INFO - Traitement du game_id : 81522
# 2024-08-01 20:03:15,149 - INFO - Détails récupérés pour le jeu 81522
# 2024-08-01 20:03:15,912 - INFO - Informations de la page Steam récupérées pour le jeu 81522
# 2024-08-01 20:03:17,517 - INFO - Traitement du game_id : 81523
# 2024-08-01 20:03:17,911 - INFO - Détails récupérés pour le jeu 81523
# 2024-08-01 20:03:18,733 - INFO - Informations de la page Steam récupérées pour le jeu 81523
# 2024-08-01 20:03:19,839 - INFO - Traitement du game_id : 81524
# 2024-08-01 20:03:20,046 - WARNING - Pas de données pour le jeu 81524
# 2024-08-01 20:03:21,412 - INFO - Traitement du game_id : 81525
# 2024-08-01 20:03:21,630 - WARNING - Pas de données pour le jeu 81525
# 2024-08-01 20:03:22,565 - INFO - Traitement du game_id : 81526
# 2024-08-01 20:03:22,773 - WARNING - Pas de données pour le jeu 81526
# 2024-08-01 20:03:24,014 - INFO - Traitement du game_id : 81527
# 2024-08-01 20:03:24,322 - WARNING - Pas de données pour le jeu 81527
# 2024-08-01 20:03:25,818 - INFO - Traitement du game_id : 81528
# 2024-08-01 20:03:26,184 - WARNING - Pas de données pour le jeu 81528
# 2024-08-01 20:03:27,444 - INFO - Traitement du game_id : 81529
# 2024-08-01 20:03:27,864 - INFO - Détails récupérés pour le jeu 81529
# 2024-08-01 20:03:28,722 - INFO - Informations de la page Steam récupérées pour le jeu 81529
# 2024-08-01 20:03:30,212 - INFO - Traitement du game_id : 81530
# 2024-08-01 20:03:30,583 - WARNING - Pas de données pour le jeu 81530
# 2024-08-01 20:03:31,927 - INFO - Traitement du game_id : 81531
# 2024-08-01 20:03:32,188 - INFO - Détails récupérés pour le jeu 81531
# 2024-08-01 20:03:32,945 - INFO - Informations de la page Steam récupérées pour le jeu 81531
# 2024-08-01 20:03:34,496 - INFO - Traitement du game_id : 81532
# 2024-08-01 20:03:34,716 - INFO - Détails récupérés pour le jeu 81532
# 2024-08-01 20:03:35,587 - INFO - Informations de la page Steam récupérées pour le jeu 81532
# 2024-08-01 20:03:36,801 - INFO - Traitement du game_id : 81533
# 2024-08-01 20:03:37,034 - INFO - Détails récupérés pour le jeu 81533
# 2024-08-01 20:03:37,789 - INFO - Informations de la page Steam récupérées pour le jeu 81533
# 2024-08-01 20:03:38,695 - INFO - Traitement du game_id : 81534
# 2024-08-01 20:03:38,918 - INFO - Détails récupérés pour le jeu 81534
# 2024-08-01 20:03:39,746 - INFO - Informations de la page Steam récupérées pour le jeu 81534
# 2024-08-01 20:03:40,270 - INFO - Traitement du game_id : 81535
# 2024-08-01 20:03:40,504 - WARNING - Pas de données pour le jeu 81535
# 2024-08-01 20:03:41,556 - INFO - Traitement du game_id : 81536
# 2024-08-01 20:03:41,763 - WARNING - Pas de données pour le jeu 81536
# 2024-08-01 20:03:42,600 - INFO - Traitement du game_id : 81537
# 2024-08-01 20:03:42,811 - WARNING - Pas de données pour le jeu 81537
# 2024-08-01 20:03:43,450 - INFO - Traitement du game_id : 81538
# 2024-08-01 20:03:43,716 - WARNING - Pas de données pour le jeu 81538
# 2024-08-01 20:03:44,788 - INFO - Traitement du game_id : 81539
# 2024-08-01 20:03:44,994 - WARNING - Pas de données pour le jeu 81539
# 2024-08-01 20:03:45,532 - INFO - Traitement du game_id : 81540
# 2024-08-01 20:03:45,752 - WARNING - Pas de données pour le jeu 81540
# 2024-08-01 20:03:47,350 - INFO - Traitement du game_id : 81541
# 2024-08-01 20:03:47,589 - WARNING - Pas de données pour le jeu 81541
# 2024-08-01 20:03:48,361 - INFO - Traitement du game_id : 81542
# 2024-08-01 20:03:48,573 - INFO - Détails récupérés pour le jeu 81542
# 2024-08-01 20:08:11,422 - ERROR - Erreur lors du scraping pour le jeu 81542: HTTPSConnectionPool(host='store.steampowered.com', port=443): Read timed out. (read timeout=10)
# 2024-08-01 20:08:12,726 - INFO - Traitement du game_id : 81543
# 2024-08-01 20:08:12,964 - INFO - Détails récupérés pour le jeu 81543
# 2024-08-01 20:08:13,680 - INFO - Informations de la page Steam récupérées pour le jeu 81543
# ...
# 2024-08-01 20:40:54,304 - INFO - Traitement du game_id : 92100
# 2024-08-01 20:40:54,614 - INFO - Détails récupérés pour le jeu 92100
# 2024-08-01 20:40:55,319 - INFO - Informations de la page Steam récupérées pour le jeu 92100
# 2024-08-01 20:40:56,552 - INFO - Traitement du game_id : 92200
# 2024-08-01 20:40:56,793 - INFO - Détails récupérés pour le jeu 92200
# 2024-08-01 20:40:57,403 - INFO - Informations de la page Steam récupérées pour le jeu 92200
# 2024-08-01 20:40:58,442 - INFO - Traitement du game_id : 92210
# 2024-08-01 20:40:58,792 - INFO - Détails récupérés pour le jeu 92210
# 2024-08-01 20:40:59,703 - INFO - Informations de la page Steam récupérées pour le jeu 92210
# 2024-08-01 20:41:01,117 - INFO - Traitement du game_id : 92220
# 2024-08-01 20:41:01,388 - INFO - Détails récupérés pour le jeu 92220
# 2024-08-01 20:41:01,789 - INFO - Informations de la page Steam récupérées pour le jeu 92220
# 2024-08-01 20:41:03,293 - INFO - Traitement du game_id : 92230
# 2024-08-01 20:41:03,489 - WARNING - Pas de données pour le jeu 92230
# 2024-08-01 20:41:04,769 - INFO - Traitement du game_id : 92240
# 2024-08-01 20:41:04,992 - WARNING - Pas de données pour le jeu 92240
# 2024-08-01 20:41:05,817 - INFO - Traitement du game_id : 92250
# 2024-08-01 20:41:06,079 - WARNING - Pas de données pour le jeu 92250
# 2024-08-01 20:41:07,699 - INFO - Traitement du game_id : 92300
# 2024-08-01 20:41:07,954 - INFO - Détails récupérés pour le jeu 92300
# 2024-08-01 20:41:08,811 - INFO - Informations de la page Steam récupérées pour le jeu 92300
# 2024-08-01 20:41:09,532 - INFO - Traitement du game_id : 92302
# 2024-08-01 20:41:09,770 - INFO - Détails récupérés pour le jeu 92302
# 2024-08-01 20:41:10,117 - INFO - Informations de la page Steam récupérées pour le jeu 92302
# 2024-08-01 20:41:11,259 - INFO - Traitement du game_id : 92303
# 2024-08-01 20:41:11,694 - INFO - Détails récupérés pour le jeu 92303
# 2024-08-01 20:41:12,220 - INFO - Informations de la page Steam récupérées pour le jeu 92303
# 2024-08-01 20:41:13,160 - INFO - Traitement du game_id : 92310
# 2024-08-01 20:41:13,389 - INFO - Détails récupérés pour le jeu 92310
# 2024-08-01 20:41:14,010 - INFO - Informations de la page Steam récupérées pour le jeu 92310
# 2024-08-01 20:41:14,736 - INFO - Traitement du game_id : 92400
# 2024-08-01 20:41:15,138 - INFO - Détails récupérés pour le jeu 92400
# 2024-08-01 20:41:15,777 - INFO - Informations de la page Steam récupérées pour le jeu 92400
# 2024-08-01 20:41:16,539 - INFO - Traitement du game_id : 92500
# 2024-08-01 20:41:16,767 - WARNING - Pas de données pour le jeu 92500
# 2024-08-01 20:41:18,398 - INFO - Traitement du game_id : 92502
# 2024-08-01 20:41:18,627 - WARNING - Pas de données pour le jeu 92502
# 2024-08-01 20:41:19,184 - INFO - Traitement du game_id : 92503
# 2024-08-01 20:41:19,415 - WARNING - Pas de données pour le jeu 92503
# 2024-08-01 20:41:21,001 - INFO - Traitement du game_id : 92504
# 2024-08-01 20:41:21,361 - WARNING - Pas de données pour le jeu 92504
# 2024-08-01 20:41:22,786 - INFO - Traitement du game_id : 92505
# 2024-08-01 20:41:22,989 - WARNING - Pas de données pour le jeu 92505
# 2024-08-01 20:41:23,714 - INFO - Traitement du game_id : 92506
# 2024-08-01 20:41:23,965 - WARNING - Pas de données pour le jeu 92506
# 2024-08-01 20:41:24,807 - INFO - Traitement du game_id : 92507
# 2024-08-01 20:41:25,018 - WARNING - Pas de données pour le jeu 92507
# 2024-08-01 20:41:25,851 - INFO - Traitement du game_id : 92508
# 2024-08-01 20:41:26,053 - WARNING - Pas de données pour le jeu 92508
# 2024-08-01 20:41:27,607 - INFO - Traitement du game_id : 92600
# 2024-08-01 20:41:27,917 - INFO - Détails récupérés pour le jeu 92600
# 2024-08-01 20:41:28,768 - INFO - Informations de la page Steam récupérées pour le jeu 92600
# 2024-08-01 20:41:30,051 - INFO - Traitement du game_id : 92620
# 2024-08-01 20:41:30,866 - INFO - Détails récupérés pour le jeu 92620
# 2024-08-01 20:41:31,261 - INFO - Informations de la page Steam récupérées pour le jeu 92620
# 2024-08-01 20:41:32,228 - INFO - Traitement du game_id : 92621
# 2024-08-01 20:41:32,582 - INFO - Détails récupérés pour le jeu 92621
# 2024-08-01 20:41:32,993 - INFO - Informations de la page Steam récupérées pour le jeu 92621
# 2024-08-01 20:41:33,560 - INFO - Traitement du game_id : 92622
# 2024-08-01 20:41:33,786 - INFO - Détails récupérés pour le jeu 92622
# 2024-08-01 20:41:34,138 - INFO - Informations de la page Steam récupérées pour le jeu 92622
# 2024-08-01 20:41:34,693 - INFO - Traitement du game_id : 92700
# 2024-08-01 20:41:34,921 - INFO - Détails récupérés pour le jeu 92700
# 2024-08-01 20:41:35,454 - INFO - Informations de la page Steam récupérées pour le jeu 92700
# 2024-08-01 20:41:36,723 - INFO - Traitement du game_id : 92800
# 2024-08-01 20:41:36,946 - INFO - Détails récupérés pour le jeu 92800
# 2024-08-01 20:41:37,548 - INFO - Informations de la page Steam récupérées pour le jeu 92800
# 2024-08-01 20:41:38,741 - INFO - Traitement du game_id : 92803
# 2024-08-01 20:41:38,984 - INFO - Détails récupérés pour le jeu 92803
# 2024-08-01 20:41:39,541 - INFO - Informations de la page Steam récupérées pour le jeu 92803
# 2024-08-01 20:41:41,046 - INFO - Traitement du game_id : 92810
# 2024-08-01 20:41:41,593 - INFO - Détails récupérés pour le jeu 92810
# 2024-08-01 20:41:42,434 - INFO - Informations de la page Steam récupérées pour le jeu 92810
# 2024-08-01 20:41:42,991 - INFO - Traitement du game_id : 92900
# 2024-08-01 20:41:43,222 - INFO - Détails récupérés pour le jeu 92900
# 2024-08-01 20:41:43,903 - INFO - Informations de la page Steam récupérées pour le jeu 92900
# 2024-08-01 20:41:45,601 - INFO - Traitement du game_id : 93200
# 2024-08-01 20:41:45,869 - INFO - Détails récupérés pour le jeu 93200
# 2024-08-01 20:41:46,394 - INFO - Informations de la page Steam récupérées pour le jeu 93200
# 2024-08-01 20:41:47,298 - INFO - Traitement du game_id : 93206
# 2024-08-01 20:41:47,556 - INFO - Détails récupérés pour le jeu 93206
# 2024-08-01 20:41:47,987 - INFO - Informations de la page Steam récupérées pour le jeu 93206
# 2024-08-01 20:41:48,907 - INFO - Traitement du game_id : 93207
# 2024-08-01 20:41:49,163 - INFO - Détails récupérés pour le jeu 93207
# 2024-08-01 20:41:49,629 - INFO - Informations de la page Steam récupérées pour le jeu 93207
# 2024-08-01 20:41:51,016 - INFO - Traitement du game_id : 93305
# 2024-08-01 20:41:51,220 - WARNING - Pas de données pour le jeu 93305
# 2024-08-01 20:41:52,004 - INFO - Traitement du game_id : 94000
# 2024-08-01 20:41:52,257 - INFO - Détails récupérés pour le jeu 94000
# 2024-08-01 20:41:52,736 - INFO - Informations de la page Steam récupérées pour le jeu 94000
# 2024-08-01 20:41:54,189 - INFO - Traitement du game_id : 94200
# 2024-08-01 20:41:54,581 - INFO - Détails récupérés pour le jeu 94200
# 2024-08-01 20:41:55,186 - INFO - Informations de la page Steam récupérées pour le jeu 94200
# 2024-08-01 20:41:56,809 - INFO - Traitement du game_id : 94202
# 2024-08-01 20:41:57,281 - INFO - Détails récupérés pour le jeu 94202
# 2024-08-01 20:41:57,697 - INFO - Informations de la page Steam récupérées pour le jeu 94202
# 2024-08-01 20:41:58,230 - INFO - Traitement du game_id : 94203
# 2024-08-01 20:41:58,459 - INFO - Détails récupérés pour le jeu 94203
# 2024-08-01 20:41:58,918 - INFO - Informations de la page Steam récupérées pour le jeu 94203
# 2024-08-01 20:42:00,118 - INFO - Traitement du game_id : 94205
# 2024-08-01 20:42:00,364 - WARNING - Pas de données pour le jeu 94205
# 2024-08-01 20:42:01,819 - INFO - Traitement du game_id : 94300
# 2024-08-01 20:42:02,101 - INFO - Détails récupérés pour le jeu 94300
# 2024-08-01 20:42:02,789 - INFO - Informations de la page Steam récupérées pour le jeu 94300
# 2024-08-01 20:42:03,411 - INFO - Traitement du game_id : 94303
# 2024-08-01 20:42:03,664 - INFO - Détails récupérés pour le jeu 94303
# 2024-08-01 20:42:04,085 - INFO - Informations de la page Steam récupérées pour le jeu 94303
# 2024-08-01 20:42:05,555 - INFO - Traitement du game_id : 94304
# 2024-08-01 20:42:05,887 - INFO - Détails récupérés pour le jeu 94304
# 2024-08-01 20:42:06,423 - INFO - Informations de la page Steam récupérées pour le jeu 94304
# 2024-08-01 20:42:07,838 - INFO - Traitement du game_id : 94400
# 2024-08-01 20:42:08,122 - INFO - Détails récupérés pour le jeu 94400
# 2024-08-01 20:42:08,649 - INFO - Informations de la page Steam récupérées pour le jeu 94400
# 2024-08-01 20:42:10,149 - INFO - Traitement du game_id : 94500
# 2024-08-01 20:42:10,370 - INFO - Détails récupérés pour le jeu 94500
# 2024-08-01 20:42:10,948 - INFO - Informations de la page Steam récupérées pour le jeu 94500
# 2024-08-01 20:42:11,495 - INFO - Traitement du game_id : 94510
# 2024-08-01 20:42:11,741 - INFO - Détails récupérés pour le jeu 94510
# 2024-08-01 20:42:12,328 - INFO - Informations de la page Steam récupérées pour le jeu 94510
# 2024-08-01 20:42:13,079 - INFO - Traitement du game_id : 94520
# 2024-08-01 20:42:13,304 - INFO - Détails récupérés pour le jeu 94520
# 2024-08-01 20:42:13,907 - INFO - Informations de la page Steam récupérées pour le jeu 94520
# 2024-08-01 20:42:15,496 - INFO - Traitement du game_id : 94530
# 2024-08-01 20:42:15,735 - INFO - Détails récupérés pour le jeu 94530
# 2024-08-01 20:42:16,285 - INFO - Informations de la page Steam récupérées pour le jeu 94530
# 2024-08-01 20:42:17,236 - INFO - Traitement du game_id : 94590
# 2024-08-01 20:42:17,557 - INFO - Détails récupérés pour le jeu 94590
# 2024-08-01 20:42:18,099 - INFO - Informations de la page Steam récupérées pour le jeu 94590
# 2024-08-01 20:42:19,573 - INFO - Traitement du game_id : 94600
# 2024-08-01 20:42:19,788 - INFO - Détails récupérés pour le jeu 94600
# 2024-08-01 20:42:20,679 - INFO - Informations de la page Steam récupérées pour le jeu 94600
# 2024-08-01 20:42:21,454 - INFO - Traitement du game_id : 94610
# 2024-08-01 20:42:21,692 - INFO - Détails récupérés pour le jeu 94610
# 2024-08-01 20:42:22,248 - INFO - Informations de la page Steam récupérées pour le jeu 94610
# 2024-08-01 20:42:23,341 - INFO - Traitement du game_id : 94620
# 2024-08-01 20:42:23,575 - INFO - Détails récupérés pour le jeu 94620
# 2024-08-01 20:42:24,239 - INFO - Informations de la page Steam récupérées pour le jeu 94620
# 2024-08-01 20:42:25,350 - INFO - Traitement du game_id : 95300
# 2024-08-01 20:42:25,616 - INFO - Détails récupérés pour le jeu 95300
# 2024-08-01 20:42:26,335 - INFO - Informations de la page Steam récupérées pour le jeu 95300
# 2024-08-01 20:42:27,369 - INFO - Traitement du game_id : 95310
# 2024-08-01 20:42:27,585 - INFO - Détails récupérés pour le jeu 95310
# 2024-08-01 20:42:28,292 - INFO - Informations de la page Steam récupérées pour le jeu 95310
# 2024-08-01 20:42:29,739 - INFO - Traitement du game_id : 95400
# 2024-08-01 20:42:29,990 - INFO - Détails récupérés pour le jeu 95400
# 2024-08-01 20:42:30,505 - INFO - Informations de la page Steam récupérées pour le jeu 95400
# 2024-08-01 20:42:31,352 - INFO - Traitement du game_id : 95500
# 2024-08-01 20:42:31,586 - WARNING - Pas de données pour le jeu 95500
# 2024-08-01 20:42:33,285 - INFO - Traitement du game_id : 95502
# 2024-08-01 20:42:33,507 - WARNING - Pas de données pour le jeu 95502
# 2024-08-01 20:42:35,113 - INFO - Traitement du game_id : 95510
# 2024-08-01 20:42:35,314 - WARNING - Pas de données pour le jeu 95510
# 2024-08-01 20:42:35,882 - INFO - Traitement du game_id : 95700
# 2024-08-01 20:42:36,132 - INFO - Détails récupérés pour le jeu 95700
# 2024-08-01 20:42:37,005 - INFO - Informations de la page Steam récupérées pour le jeu 95700
# 2024-08-01 20:42:38,464 - INFO - Traitement du game_id : 95900
# 2024-08-01 20:42:38,719 - INFO - Détails récupérés pour le jeu 95900
# 2024-08-01 20:42:39,294 - INFO - Informations de la page Steam récupérées pour le jeu 95900
# 2024-08-01 20:42:40,102 - INFO - Traitement du game_id : 96000
# 2024-08-01 20:42:40,415 - INFO - Détails récupérés pour le jeu 96000
# 2024-08-01 20:42:41,168 - INFO - Informations de la page Steam récupérées pour le jeu 96000
# 2024-08-01 20:42:41,727 - INFO - Traitement du game_id : 96010
# 2024-08-01 20:42:41,952 - INFO - Détails récupérés pour le jeu 96010
# 2024-08-01 20:42:42,667 - INFO - Informations de la page Steam récupérées pour le jeu 96010
# 2024-08-01 20:42:44,116 - INFO - Traitement du game_id : 96100
# 2024-08-01 20:42:44,359 - INFO - Détails récupérés pour le jeu 96100
# 2024-08-01 20:42:44,798 - INFO - Informations de la page Steam récupérées pour le jeu 96100
# 2024-08-01 20:42:45,995 - INFO - Traitement du game_id : 96200
# 2024-08-01 20:42:46,253 - INFO - Détails récupérés pour le jeu 96200
# 2024-08-01 20:42:46,859 - INFO - Informations de la page Steam récupérées pour le jeu 96200
# 2024-08-01 20:42:48,557 - INFO - Traitement du game_id : 96300
# 2024-08-01 20:42:48,819 - WARNING - Pas de données pour le jeu 96300
# 2024-08-01 20:42:50,089 - INFO - Traitement du game_id : 96308
# 2024-08-01 20:42:50,299 - WARNING - Pas de données pour le jeu 96308
# 2024-08-01 20:42:51,556 - INFO - Traitement du game_id : 96419
# 2024-08-01 20:42:51,762 - WARNING - Pas de données pour le jeu 96419
# 2024-08-01 20:42:52,736 - INFO - Traitement du game_id : 96800
# 2024-08-01 20:42:52,977 - INFO - Détails récupérés pour le jeu 96800
# 2024-08-01 20:42:53,607 - INFO - Informations de la page Steam récupérées pour le jeu 96800
# 2024-08-01 20:42:54,779 - INFO - Traitement du game_id : 96810
# 2024-08-01 20:42:54,981 - WARNING - Pas de données pour le jeu 96810
# 2024-08-01 20:42:56,383 - INFO - Traitement du game_id : 96819
# 2024-08-01 20:42:56,596 - WARNING - Pas de données pour le jeu 96819
# 2024-08-01 20:42:57,717 - INFO - Traitement du game_id : 96831
# 2024-08-01 20:42:57,932 - WARNING - Pas de données pour le jeu 96831
# 2024-08-01 20:42:58,827 - INFO - Traitement du game_id : 96900
# 2024-08-01 20:42:59,124 - INFO - Détails récupérés pour le jeu 96900
# 2024-08-01 20:42:59,689 - INFO - Informations de la page Steam récupérées pour le jeu 96900
# 2024-08-01 20:43:01,251 - INFO - Traitement du game_id : 97000
# 2024-08-01 20:43:01,501 - INFO - Détails récupérés pour le jeu 97000
# 2024-08-01 20:43:01,978 - INFO - Informations de la page Steam récupérées pour le jeu 97000
# 2024-08-01 20:43:02,993 - INFO - Traitement du game_id : 97010
# 2024-08-01 20:43:03,231 - INFO - Détails récupérés pour le jeu 97010
# 2024-08-01 20:43:03,788 - INFO - Informations de la page Steam récupérées pour le jeu 97010
# 2024-08-01 20:43:05,421 - INFO - Traitement du game_id : 97110
# 2024-08-01 20:43:05,684 - INFO - Détails récupérés pour le jeu 97110
# 2024-08-01 20:43:06,344 - INFO - Informations de la page Steam récupérées pour le jeu 97110
# 2024-08-01 20:43:07,635 - INFO - Traitement du game_id : 97120
# 2024-08-01 20:43:07,891 - INFO - Détails récupérés pour le jeu 97120
# 2024-08-01 20:43:08,630 - INFO - Informations de la page Steam récupérées pour le jeu 97120
# 2024-08-01 20:43:10,043 - INFO - Traitement du game_id : 97130
# 2024-08-01 20:43:10,303 - INFO - Détails récupérés pour le jeu 97130
# 2024-08-01 20:43:10,798 - INFO - Informations de la page Steam récupérées pour le jeu 97130
# 2024-08-01 20:43:11,739 - INFO - Traitement du game_id : 97340
# 2024-08-01 20:43:11,966 - INFO - Détails récupérés pour le jeu 97340
# 2024-08-01 20:43:12,689 - INFO - Informations de la page Steam récupérées pour le jeu 97340
# 2024-08-01 20:43:13,668 - INFO - Traitement du game_id : 98001
# 2024-08-01 20:43:13,894 - WARNING - Pas de données pour le jeu 98001
# 2024-08-01 20:43:15,567 - INFO - Traitement du game_id : 98002
# 2024-08-01 20:43:15,802 - WARNING - Pas de données pour le jeu 98002
# 2024-08-01 20:43:16,543 - INFO - Traitement du game_id : 98003
# 2024-08-01 20:43:16,778 - WARNING - Pas de données pour le jeu 98003
# 2024-08-01 20:43:18,088 - INFO - Traitement du game_id : 98004
# 2024-08-01 20:43:18,295 - WARNING - Pas de données pour le jeu 98004
# 2024-08-01 20:43:19,107 - INFO - Traitement du game_id : 98005
# 2024-08-01 20:43:19,358 - WARNING - Pas de données pour le jeu 98005
# 2024-08-01 20:43:20,516 - INFO - Traitement du game_id : 98006
# 2024-08-01 20:43:20,963 - WARNING - Pas de données pour le jeu 98006
# 2024-08-01 20:43:21,806 - INFO - Mise à jour terminée avec succès
# 2024-08-01 20:43:21,809 - INFO - Fichier temporaire supprimé
