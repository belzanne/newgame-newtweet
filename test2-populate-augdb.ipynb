# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random

# Fonction pour télécharger la base de données steam_games.db
def download_db(url, local_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    print(f"Échec du téléchargement de la base de données. Code de statut: {response.status_code}")
    return False

# Fonction pour obtenir les détails d'un jeu via l'API Steam
def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(steam_game_id)]['success']:
            return data[str(steam_game_id)]['data']
    return None

# Fonction pour obtenir les informations de la page Steam d'un jeu
def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Vérifier la présence de contenu généré par IA
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        
        # Recherche de la section "AI Generated Content Disclosure"
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        # Récupérer les tags
        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except Exception as e:
        print(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
        return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                print(f"Database is locked. Retrying in {delay} seconds...")
                time.sleep(delay)
                delay *= 2  # Augmenter le délai exponentiellement
            else:
                raise


def ensure_column_exists(cursor, table_name, column_name, column_type):
    """Vérifie si une colonne existe dans la table et l'ajoute si ce n'est pas le cas."""
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        print(f"Colonne '{column_name}' ajoutée à la table {table_name}")



# Fonction principale

def update_aug_steam_games():
    # Charger le dernier game_id traité
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
    except FileNotFoundError:
        last_processed_id = 12570  # Valeur par défaut si le fichier n'existe pas

    # Télécharger steam_games.db
    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            print("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            # Connexion aux bases de données
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            # Vérifier et ajouter la colonne 'type' si nécessaire
            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            # Récupérer les 500 prochains game_ids
            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 1000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                print(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    # Préparer les données pour l'insertion
                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    # Insérer ou mettre à jour les données
                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                # Mettre à jour le dernier game_id traité
                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                # Pause pour éviter de surcharger l'API
                time.sleep(random.uniform(0.5, 1.7))

            # Commit des changements
            conn_aug.commit()
            
        except Exception as e:
            print(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    # Supprimer le fichier temporaire
    os.unlink(temp_db.name)

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# Traitement du game_id : 33280
# Traitement du game_id : 33287
# Traitement du game_id : 33288
# Traitement du game_id : 33289
# Traitement du game_id : 33290
# Traitement du game_id : 33310
# Traitement du game_id : 33320
# Traitement du game_id : 33325
# Traitement du game_id : 33326
# Traitement du game_id : 33349
# Traitement du game_id : 33359
# Traitement du game_id : 33360
# Traitement du game_id : 33361
# Traitement du game_id : 33362
# Traitement du game_id : 33370
# Traitement du game_id : 33371
# Traitement du game_id : 33390
# Traitement du game_id : 33400
# Traitement du game_id : 33420
# Traitement du game_id : 33428
# Traitement du game_id : 33435
# Traitement du game_id : 33436
# Traitement du game_id : 33446
# Traitement du game_id : 33447
# Traitement du game_id : 33448
# Traitement du game_id : 33456
# Traitement du game_id : 33457
# Traitement du game_id : 33460
# Traitement du game_id : 33500
# Traitement du game_id : 33510
# Traitement du game_id : 33520
# Traitement du game_id : 33530
# Traitement du game_id : 33540
# Traitement du game_id : 33549
# Traitement du game_id : 33550
# Traitement du game_id : 33559
# Traitement du game_id : 33560
# Traitement du game_id : 33570
# Traitement du game_id : 33580
# Traitement du game_id : 33600
# Traitement du game_id : 33610
# Traitement du game_id : 33620
# Traitement du game_id : 33630
# Traitement du game_id : 33650
# Traitement du game_id : 33660
# Traitement du game_id : 33670
# Traitement du game_id : 33680
# Traitement du game_id : 33700
# Traitement du game_id : 33710
# Traitement du game_id : 33720
# Traitement du game_id : 33730
# Traitement du game_id : 33740
# Traitement du game_id : 33750
# Traitement du game_id : 33760
# Traitement du game_id : 33770
# Traitement du game_id : 33780
# Traitement du game_id : 33790
# Traitement du game_id : 33900
# Traitement du game_id : 33905
# Traitement du game_id : 33909
# Traitement du game_id : 33910
# Traitement du game_id : 33919
# Traitement du game_id : 33920
# Traitement du game_id : 33930
# Traitement du game_id : 33934
# Traitement du game_id : 33935
# Traitement du game_id : 33936
# Traitement du game_id : 33950
# Traitement du game_id : 33960
# Traitement du game_id : 33970
# Traitement du game_id : 33980
# Traitement du game_id : 33990
# Traitement du game_id : 34000
# Traitement du game_id : 34009
# Traitement du game_id : 34010
# Traitement du game_id : 34019
# Traitement du game_id : 34030
# Traitement du game_id : 34039
# Traitement du game_id : 34049
# Traitement du game_id : 34050
# Traitement du game_id : 34110
# Traitement du game_id : 34120
# Traitement du game_id : 34170
# Traitement du game_id : 34171
# Traitement du game_id : 34172
# Traitement du game_id : 34173
# Traitement du game_id : 34174
# Traitement du game_id : 34175
# Traitement du game_id : 34176
# Traitement du game_id : 34177
# Traitement du game_id : 34178
# Traitement du game_id : 34179
# Traitement du game_id : 34184
# Traitement du game_id : 34189
# Traitement du game_id : 34190
# Traitement du game_id : 34200
# Traitement du game_id : 34220
# Traitement du game_id : 34229
# Traitement du game_id : 34250
# Traitement du game_id : 34270
# Traitement du game_id : 34272
# Traitement du game_id : 34273
# Traitement du game_id : 34274
# Traitement du game_id : 34275
# Traitement du game_id : 34276
# Traitement du game_id : 34277
# Traitement du game_id : 34278
# Traitement du game_id : 34279
# Traitement du game_id : 34280
# Traitement du game_id : 34281
# Traitement du game_id : 34282
# Traitement du game_id : 34283
# Traitement du game_id : 34284
# Traitement du game_id : 34285
# Traitement du game_id : 34286
# Traitement du game_id : 34287
# Traitement du game_id : 34288
# Traitement du game_id : 34289
# Traitement du game_id : 34310
# Traitement du game_id : 34311
# Traitement du game_id : 34312
# Traitement du game_id : 34313
# Traitement du game_id : 34314
# Traitement du game_id : 34315
# Traitement du game_id : 34316
# Traitement du game_id : 34317
# Traitement du game_id : 34318
# Traitement du game_id : 34319
# Traitement du game_id : 34330
# Traitement du game_id : 34342
# Traitement du game_id : 34343
# Traitement du game_id : 34344
# Traitement du game_id : 34345
# Traitement du game_id : 34346
# Traitement du game_id : 34347
# Traitement du game_id : 34348
# Traitement du game_id : 34350
# Traitement du game_id : 34390
# Traitement du game_id : 34400
# Traitement du game_id : 34410
# Traitement du game_id : 34420
# Traitement du game_id : 34440
# Traitement du game_id : 34450
# Traitement du game_id : 34460
# Traitement du game_id : 34470
# Traitement du game_id : 34490
# Traitement du game_id : 34491
# Traitement du game_id : 34492
# Traitement du game_id : 34493
# Traitement du game_id : 34494
# Traitement du game_id : 34495
# Traitement du game_id : 34496
# Traitement du game_id : 34497
# Traitement du game_id : 34498
# Traitement du game_id : 34500
# Traitement du game_id : 34510
# Traitement du game_id : 34600
# Traitement du game_id : 34609
# Traitement du game_id : 34610
# Traitement du game_id : 34611
# Traitement du game_id : 34612
# Traitement du game_id : 34613
# Traitement du game_id : 34614
# Traitement du game_id : 34615
# Traitement du game_id : 34616
# Traitement du game_id : 34620
# Traitement du game_id : 34630
# Traitement du game_id : 34640
# Traitement du game_id : 34650
# Traitement du game_id : 34660
# Traitement du game_id : 34670
# Traitement du game_id : 34680
# Traitement du game_id : 34800
# Traitement du game_id : 34810
# Traitement du game_id : 34820
# Traitement du game_id : 34830
# Traitement du game_id : 34841
# Traitement du game_id : 34842
# Traitement du game_id : 34850
# Traitement du game_id : 34860
# Traitement du game_id : 34870
# Traitement du game_id : 34880
# Traitement du game_id : 34900
# Traitement du game_id : 34910
# Traitement du game_id : 34920
# Traitement du game_id : 34930
# Traitement du game_id : 35000
# Traitement du game_id : 35010
# Traitement du game_id : 35019
# Traitement du game_id : 35020
# Traitement du game_id : 35030
# Traitement du game_id : 35040
# Traitement du game_id : 35050
# Traitement du game_id : 35060
# Traitement du game_id : 35070
# Traitement du game_id : 35080
# Traitement du game_id : 35081
# Traitement du game_id : 35082
# Traitement du game_id : 35083
# Traitement du game_id : 35084
# Traitement du game_id : 35085
# Traitement du game_id : 35086
# Traitement du game_id : 35087
# Traitement du game_id : 35088
# Traitement du game_id : 35089
# Traitement du game_id : 35090
# Traitement du game_id : 35091
# Traitement du game_id : 35092
# Traitement du game_id : 35093
# Traitement du game_id : 35094
# Traitement du game_id : 35095
# Traitement du game_id : 35096
# Traitement du game_id : 35097
# Traitement du game_id : 35098
# Traitement du game_id : 35099
# Traitement du game_id : 35100
# Traitement du game_id : 35101
# Traitement du game_id : 35102
# Traitement du game_id : 35103
# Traitement du game_id : 35110
# Traitement du game_id : 35130
# Traitement du game_id : 35134
# Traitement du game_id : 35135
# Traitement du game_id : 35136
# Traitement du game_id : 35137
# Traitement du game_id : 35138
# Traitement du game_id : 35140
# Traitement du game_id : 35150
# Traitement du game_id : 35300
# Traitement du game_id : 35310
# Traitement du game_id : 35320
# Traitement du game_id : 35417
# Traitement du game_id : 38430
# Traitement du game_id : 38440
# Traitement du game_id : 38450
# Traitement du game_id : 38460
# Traitement du game_id : 38480
# Traitement du game_id : 38490
# Traitement du game_id : 38530
# Traitement du game_id : 38600
# Traitement du game_id : 38700
# Traitement du game_id : 38710
# Traitement du game_id : 38720
# Traitement du game_id : 38730
# Traitement du game_id : 38740
# Traitement du game_id : 38743
# Traitement du game_id : 38750
# Traitement du game_id : 38800
# Traitement du game_id : 38810
# Traitement du game_id : 38820
# Traitement du game_id : 38830
# Traitement du game_id : 38900
# Traitement du game_id : 38910
# Traitement du game_id : 38920
# Traitement du game_id : 38921
# Traitement du game_id : 38922
# Traitement du game_id : 38923
# Traitement du game_id : 38924
# Traitement du game_id : 38925
# Traitement du game_id : 38926
# Traitement du game_id : 38927
# Traitement du game_id : 39000
# Traitement du game_id : 39100
# Traitement du game_id : 39110
# Traitement du game_id : 39120
# Traitement du game_id : 39122
# Traitement du game_id : 39123
# Traitement du game_id : 39124
# Traitement du game_id : 39125
# Traitement du game_id : 39126
# Traitement du game_id : 39127
# Traitement du game_id : 39128
# Traitement du game_id : 39129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 191
#     188     os.unlink(temp_db.name)
#     190 if __name__ == "__main__":
# --> 191     update_aug_steam_games()
#
# Cell In[11], line 133, in update_aug_steam_games()
#     131 game_id = game_id[0]
#     132 print(f"Traitement du game_id : {game_id}")
# --> 133 game_data = get_game_details(game_id)
#     134 if game_data:
#     135     steam_page_info = get_steam_page_info(game_id)
#
# Cell In[11], line 26, in get_game_details(steam_game_id)
#      24 def get_game_details(steam_game_id):
#      25     url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
# ---> 26     response = requests.get(url)
#      27     if response.status_code == 200:
#      28         data = response.json()
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random
import logging

# Configuration du logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def download_db(url, local_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        logging.info(f"Base de données téléchargée avec succès: {local_path}")
        return True
    except requests.RequestException as e:
        logging.error(f"Échec du téléchargement de la base de données: {e}")
        return False

def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        if data[str(steam_game_id)]['success']:
            logging.info(f"Détails récupérés pour le jeu {steam_game_id}")
            return data[str(steam_game_id)]['data']
        else:
            logging.warning(f"Pas de données pour le jeu {steam_game_id}")
    except requests.RequestException as e:
        logging.error(f"Erreur lors de la récupération des détails pour le jeu {steam_game_id}: {e}")
    except json.JSONDecodeError as e:
        logging.error(f"Erreur de décodage JSON pour le jeu {steam_game_id}: {e}")
    return None

def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        logging.info(f"Informations de la page Steam récupérées pour le jeu {app_id}")
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except requests.RequestException as e:
        logging.error(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
    except Exception as e:
        logging.error(f"Erreur inattendue lors du scraping pour le jeu {app_id}: {e}")
    return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                logging.warning(f"Base de données verrouillée. Nouvelle tentative dans {delay} secondes...")
                time.sleep(delay)
                delay *= 2
            else:
                raise

def ensure_column_exists(cursor, table_name, column_name, column_type):
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        logging.info(f"Colonne '{column_name}' ajoutée à la table {table_name}")

def update_aug_steam_games():
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
        logging.info(f"Dernier game_id traité: {last_processed_id}")
    except FileNotFoundError:
        last_processed_id = 12570
        logging.info(f"Fichier last_processed_game_id.txt non trouvé. Utilisation de la valeur par défaut: {last_processed_id}")

    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            logging.error("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 5000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                logging.info(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                time.sleep(random.uniform(0.5, 1.7))

            conn_aug.commit()
            logging.info("Mise à jour terminée avec succès")
            
        except Exception as e:
            logging.error(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    os.unlink(temp_db.name)
    logging.info("Fichier temporaire supprimé")

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# 2024-08-02 08:42:05,730 - INFO - Dernier game_id traité: 355310
# 2024-08-02 08:42:07,153 - INFO - Base de données téléchargée avec succès: /var/folders/b5/ckj362xj7ng_xqbjrqp077qh0000gn/T/tmpyk1shb2c.db
# 2024-08-02 08:42:07,160 - INFO - Traitement du game_id : 355340
# 2024-08-02 08:42:07,556 - INFO - Détails récupérés pour le jeu 355340
# 2024-08-02 08:42:07,960 - INFO - Informations de la page Steam récupérées pour le jeu 355340
# 2024-08-02 08:42:09,298 - INFO - Traitement du game_id : 355341
# 2024-08-02 08:42:09,536 - INFO - Détails récupérés pour le jeu 355341
# 2024-08-02 08:42:10,068 - INFO - Informations de la page Steam récupérées pour le jeu 355341
# 2024-08-02 08:42:10,863 - INFO - Traitement du game_id : 355350
# 2024-08-02 08:42:11,242 - INFO - Détails récupérés pour le jeu 355350
# 2024-08-02 08:42:11,790 - INFO - Informations de la page Steam récupérées pour le jeu 355350
# 2024-08-02 08:42:12,593 - INFO - Traitement du game_id : 355360
# 2024-08-02 08:42:12,871 - INFO - Détails récupérés pour le jeu 355360
# 2024-08-02 08:42:13,374 - INFO - Informations de la page Steam récupérées pour le jeu 355360
# 2024-08-02 08:42:14,216 - INFO - Traitement du game_id : 355370
# 2024-08-02 08:42:14,498 - INFO - Détails récupérés pour le jeu 355370
# 2024-08-02 08:42:15,097 - INFO - Informations de la page Steam récupérées pour le jeu 355370
# 2024-08-02 08:42:15,870 - INFO - Traitement du game_id : 355380
# 2024-08-02 08:42:16,140 - INFO - Détails récupérés pour le jeu 355380
# 2024-08-02 08:42:16,772 - INFO - Informations de la page Steam récupérées pour le jeu 355380
# 2024-08-02 08:42:18,271 - INFO - Traitement du game_id : 355400
# 2024-08-02 08:42:18,520 - INFO - Détails récupérés pour le jeu 355400
# 2024-08-02 08:42:19,159 - INFO - Informations de la page Steam récupérées pour le jeu 355400
# 2024-08-02 08:42:19,668 - INFO - Traitement du game_id : 355410
# 2024-08-02 08:42:19,968 - INFO - Détails récupérés pour le jeu 355410
# 2024-08-02 08:42:20,541 - INFO - Informations de la page Steam récupérées pour le jeu 355410
# 2024-08-02 08:42:21,601 - INFO - Traitement du game_id : 355420
# 2024-08-02 08:42:21,893 - INFO - Détails récupérés pour le jeu 355420
# 2024-08-02 08:51:20,618 - INFO - Détails récupérés pour le jeu 356810
# 2024-08-02 08:51:21,799 - INFO - Informations de la page Steam récupérées pour le jeu 356810
# 2024-08-02 08:51:22,349 - INFO - Traitement du game_id : 356820
# 2024-08-02 08:51:22,713 - INFO - Détails récupérés pour le jeu 356820
# 2024-08-02 08:51:23,500 - INFO - Informations de la page Steam récupérées pour le jeu 356820
# 2024-08-02 08:51:24,768 - INFO - Traitement du game_id : 356831
# 2024-08-02 08:51:24,988 - INFO - Détails récupérés pour le jeu 356831
# 2024-08-02 08:51:25,401 - INFO - Informations de la page Steam récupérées pour le jeu 356831
# 2024-08-02 08:51:26,602 - INFO - Traitement du game_id : 356860
# 2024-08-02 09:25:30,906 - ERROR - Erreur lors de la récupération des détails pour le jeu 356860: HTTPSConnectionPool(host='store.steampowered.com', port=443): Read timed out. (read timeout=10)
# 2024-08-02 09:42:51,288 - INFO - Traitement du game_id : 356870
# 2024-08-02 09:42:51,545 - INFO - Détails récupérés pour le jeu 356870
# 2024-08-02 09:42:52,265 - INFO - Informations de la page Steam récupérées pour le jeu 356870
# 2024-08-02 09:42:52,781 - INFO - Traitement du game_id : 356880
# 2024-08-02 09:42:53,010 - INFO - Détails récupérés pour le jeu 356880
# 2024-08-02 09:42:53,861 - INFO - Informations de la page Steam récupérées pour le jeu 356880
# 2024-08-02 09:42:55,042 - INFO - Traitement du game_id : 356890
# 2024-08-02 09:42:55,314 - INFO - Détails récupérés pour le jeu 356890
# 2024-08-02 10:16:48,674 - ERROR - Erreur lors du scraping pour le jeu 356890: HTTPSConnectionPool(host='store.steampowered.com', port=443): Read timed out. (read timeout=10)
# 2024-08-02 10:16:49,337 - INFO - Traitement du game_id : 356910
# 2024-08-02 10:16:49,662 - INFO - Détails récupérés pour le jeu 356910
# 2024-08-02 10:25:41,077 - INFO - Informations de la page Steam récupérées pour le jeu 356910
# 2024-08-02 10:25:41,604 - INFO - Traitement du game_id : 356960
# 2024-08-02 10:25:41,866 - INFO - Détails récupérés pour le jeu 356960
# 2024-08-02 10:25:42,277 - INFO - Informations de la page Steam récupérées pour le jeu 356960
# 2024-08-02 10:25:43,111 - INFO - Traitement du game_id : 356970
# 2024-08-02 10:25:43,374 - INFO - Détails récupérés pour le jeu 356970
# 2024-08-02 10:25:43,968 - INFO - Informations de la page Steam récupérées pour le jeu 356970
# 2024-08-02 10:25:45,227 - INFO - Traitement du game_id : 357030
# 2024-08-02 10:25:45,495 - INFO - Détails récupérés pour le jeu 357030
# 2024-08-02 10:25:46,136 - INFO - Informations de la page Steam récupérées pour le jeu 357030
# 2024-08-02 10:25:47,248 - INFO - Traitement du game_id : 357040
# 2024-08-02 10:25:47,518 - INFO - Détails récupérés pour le jeu 357040
# 2024-08-02 10:25:48,009 - INFO - Informations de la page Steam récupérées pour le jeu 357040
# 2024-08-02 10:25:48,603 - INFO - Traitement du game_id : 357060
# 2024-08-02 10:25:48,844 - WARNING - Pas de données pour le jeu 357060
# 2024-08-02 10:25:50,457 - INFO - Traitement du game_id : 357070
# 2024-08-02 10:25:50,726 - INFO - Détails récupérés pour le jeu 357070
# 2024-08-02 10:25:51,240 - INFO - Informations de la page Steam récupérées pour le jeu 357070
# 2024-08-02 10:25:52,047 - INFO - Traitement du game_id : 357080
# 2024-08-02 10:25:52,283 - INFO - Détails récupérés pour le jeu 357080
# 2024-08-02 10:25:53,292 - INFO - Informations de la page Steam récupérées pour le jeu 357080
# 2024-08-02 10:25:54,128 - INFO - Traitement du game_id : 357090
# 2024-08-02 10:25:54,400 - INFO - Détails récupérés pour le jeu 357090
# 2024-08-02 10:25:55,154 - INFO - Informations de la page Steam récupérées pour le jeu 357090
# 2024-08-02 10:25:56,665 - INFO - Traitement du game_id : 357100
# 2024-08-02 10:25:56,913 - INFO - Détails récupérés pour le jeu 357100
# 2024-08-02 10:25:57,466 - INFO - Informations de la page Steam récupérées pour le jeu 357100
# 2024-08-02 10:25:58,004 - INFO - Traitement du game_id : 357110
# 2024-08-02 10:25:58,238 - INFO - Détails récupérés pour le jeu 357110
# 2024-08-02 10:25:59,009 - INFO - Informations de la page Steam récupérées pour le jeu 357110
# 2024-08-02 10:26:00,358 - INFO - Traitement du game_id : 357120
# 2024-08-02 10:26:00,653 - INFO - Détails récupérés pour le jeu 357120
# 2024-08-02 10:26:01,533 - INFO - Informations de la page Steam récupérées pour le jeu 357120
# 2024-08-02 10:26:02,559 - INFO - Traitement du game_id : 357170
# 2024-08-02 10:26:03,037 - INFO - Détails récupérés pour le jeu 357170
# 2024-08-02 10:26:03,413 - INFO - Informations de la page Steam récupérées pour le jeu 357170
# 2024-08-02 10:26:04,726 - INFO - Traitement du game_id : 357171
# 2024-08-02 10:26:05,043 - INFO - Détails récupérés pour le jeu 357171
# 2024-08-02 10:26:05,750 - INFO - Informations de la page Steam récupérées pour le jeu 357171
# 2024-08-02 10:26:06,722 - INFO - Traitement du game_id : 357180
# 2024-08-02 10:26:06,966 - INFO - Détails récupérés pour le jeu 357180
# 2024-08-02 10:26:07,374 - INFO - Informations de la page Steam récupérées pour le jeu 357180
# 2024-08-02 10:26:08,284 - INFO - Traitement du game_id : 357190
# 2024-08-02 10:26:08,607 - INFO - Détails récupérés pour le jeu 357190
# 2024-08-02 10:26:09,143 - INFO - Informations de la page Steam récupérées pour le jeu 357190
# 2024-08-02 10:26:10,474 - INFO - Traitement du game_id : 357200
# 2024-08-02 10:26:10,710 - INFO - Détails récupérés pour le jeu 357200
# 2024-08-02 10:26:11,474 - INFO - Informations de la page Steam récupérées pour le jeu 357200
# 2024-08-02 10:26:12,033 - INFO - Traitement du game_id : 357210
# 2024-08-02 10:26:12,357 - WARNING - Pas de données pour le jeu 357210
# 2024-08-02 10:26:13,986 - INFO - Traitement du game_id : 357240
# 2024-08-02 10:26:14,259 - INFO - Détails récupérés pour le jeu 357240
# 2024-08-02 10:26:14,903 - INFO - Informations de la page Steam récupérées pour le jeu 357240
# 2024-08-02 10:26:16,150 - INFO - Traitement du game_id : 357250
# 2024-08-02 10:26:16,498 - INFO - Détails récupérés pour le jeu 357250
# 2024-08-02 10:26:16,997 - INFO - Informations de la page Steam récupérées pour le jeu 357250
# 2024-08-02 10:26:18,226 - INFO - Traitement du game_id : 357260
# 2024-08-02 10:26:18,559 - INFO - Détails récupérés pour le jeu 357260
# 2024-08-02 10:26:19,211 - INFO - Informations de la page Steam récupérées pour le jeu 357260
# 2024-08-02 10:26:19,802 - INFO - Traitement du game_id : 357261
# 2024-08-02 10:26:20,281 - INFO - Détails récupérés pour le jeu 357261
# 2024-08-02 10:26:20,817 - INFO - Informations de la page Steam récupérées pour le jeu 357261
# 2024-08-02 10:26:21,698 - INFO - Traitement du game_id : 357262
# 2024-08-02 10:26:21,974 - INFO - Détails récupérés pour le jeu 357262
# 2024-08-02 10:26:22,528 - INFO - Informations de la page Steam récupérées pour le jeu 357262
# 2024-08-02 10:26:23,789 - INFO - Traitement du game_id : 357280
# 2024-08-02 10:26:24,072 - INFO - Détails récupérés pour le jeu 357280
# 2024-08-02 10:26:24,875 - INFO - Informations de la page Steam récupérées pour le jeu 357280
# 2024-08-02 10:26:26,092 - INFO - Traitement du game_id : 357290
# 2024-08-02 10:26:26,329 - INFO - Détails récupérés pour le jeu 357290
# 2024-08-02 10:26:27,178 - INFO - Informations de la page Steam récupérées pour le jeu 357290
# 2024-08-02 10:26:28,559 - INFO - Traitement du game_id : 357300
# 2024-08-02 10:26:28,824 - INFO - Détails récupérés pour le jeu 357300
# 2024-08-02 10:26:29,379 - INFO - Informations de la page Steam récupérées pour le jeu 357300
# 2024-08-02 10:26:30,726 - INFO - Traitement du game_id : 357310
# 2024-08-02 10:26:31,006 - INFO - Détails récupérés pour le jeu 357310
# 2024-08-02 10:26:31,667 - INFO - Informations de la page Steam récupérées pour le jeu 357310
# 2024-08-02 10:26:32,249 - INFO - Traitement du game_id : 357320
# 2024-08-02 10:26:32,486 - INFO - Détails récupérés pour le jeu 357320
# 2024-08-02 10:26:33,211 - INFO - Informations de la page Steam récupérées pour le jeu 357320
# 2024-08-02 10:26:34,257 - INFO - Traitement du game_id : 357330
# 2024-08-02 10:26:34,536 - INFO - Détails récupérés pour le jeu 357330
# 2024-08-02 10:26:35,322 - INFO - Informations de la page Steam récupérées pour le jeu 357330
# 2024-08-02 10:26:36,151 - INFO - Traitement du game_id : 357340
# 2024-08-02 10:26:36,626 - INFO - Détails récupérés pour le jeu 357340
# 2024-08-02 10:26:37,152 - INFO - Informations de la page Steam récupérées pour le jeu 357340
# 2024-08-02 10:26:37,856 - INFO - Traitement du game_id : 357350
# 2024-08-02 10:26:38,220 - INFO - Détails récupérés pour le jeu 357350
# 2024-08-02 10:26:38,634 - INFO - Informations de la page Steam récupérées pour le jeu 357350
# 2024-08-02 10:26:39,425 - INFO - Traitement du game_id : 357360
# 2024-08-02 10:26:39,683 - INFO - Détails récupérés pour le jeu 357360
# 2024-08-02 10:26:40,327 - INFO - Informations de la page Steam récupérées pour le jeu 357360
# 2024-08-02 10:26:41,037 - INFO - Traitement du game_id : 357370
# 2024-08-02 10:26:41,300 - INFO - Détails récupérés pour le jeu 357370
# 2024-08-02 10:26:42,086 - INFO - Informations de la page Steam récupérées pour le jeu 357370
# 2024-08-02 10:26:42,709 - INFO - Traitement du game_id : 357400
# 2024-08-02 10:26:42,967 - INFO - Détails récupérés pour le jeu 357400
# 2024-08-02 10:26:43,672 - INFO - Informations de la page Steam récupérées pour le jeu 357400
# 2024-08-02 10:26:44,931 - INFO - Traitement du game_id : 357440
# 2024-08-02 10:26:45,173 - INFO - Détails récupérés pour le jeu 357440
# 2024-08-02 10:26:45,699 - INFO - Informations de la page Steam récupérées pour le jeu 357440
# 2024-08-02 10:26:46,742 - INFO - Traitement du game_id : 357450
# 2024-08-02 10:26:47,009 - INFO - Détails récupérés pour le jeu 357450
# 2024-08-02 10:26:47,720 - INFO - Informations de la page Steam récupérées pour le jeu 357450
# 2024-08-02 10:26:48,887 - INFO - Traitement du game_id : 357470
# 2024-08-02 10:26:49,406 - INFO - Détails récupérés pour le jeu 357470
# 2024-08-02 10:26:50,078 - INFO - Informations de la page Steam récupérées pour le jeu 357470
# 2024-08-02 10:26:51,606 - INFO - Traitement du game_id : 357480
# 2024-08-02 10:26:51,986 - INFO - Détails récupérés pour le jeu 357480
# 2024-08-02 10:26:52,619 - INFO - Informations de la page Steam récupérées pour le jeu 357480
# 2024-08-02 10:26:53,803 - INFO - Traitement du game_id : 357490
# 2024-08-02 10:26:54,176 - INFO - Détails récupérés pour le jeu 357490
# 2024-08-02 10:26:54,916 - INFO - Informations de la page Steam récupérées pour le jeu 357490
# 2024-08-02 10:26:55,973 - INFO - Traitement du game_id : 357500
# 2024-08-02 10:26:56,236 - INFO - Détails récupérés pour le jeu 357500
# 2024-08-02 10:26:56,943 - INFO - Informations de la page Steam récupérées pour le jeu 357500
# 2024-08-02 10:26:58,195 - INFO - Traitement du game_id : 357600
# 2024-08-02 10:26:58,497 - INFO - Détails récupérés pour le jeu 357600
# 2024-08-02 10:26:59,114 - INFO - Informations de la page Steam récupérées pour le jeu 357600
# 2024-08-02 10:26:59,879 - INFO - Traitement du game_id : 357650
# 2024-08-02 10:27:00,340 - INFO - Détails récupérés pour le jeu 357650
# 2024-08-02 10:27:01,291 - INFO - Informations de la page Steam récupérées pour le jeu 357650
# 2024-08-02 10:27:02,336 - INFO - Traitement du game_id : 357670
# 2024-08-02 10:27:02,569 - INFO - Détails récupérés pour le jeu 357670
# 2024-08-02 10:27:03,010 - INFO - Informations de la page Steam récupérées pour le jeu 357670
# 2024-08-02 10:27:04,427 - INFO - Traitement du game_id : 357690
# 2024-08-02 10:27:04,664 - INFO - Détails récupérés pour le jeu 357690
# 2024-08-02 10:27:05,198 - INFO - Informations de la page Steam récupérées pour le jeu 357690
# 2024-08-02 10:27:06,032 - INFO - Traitement du game_id : 357700
# 2024-08-02 10:27:06,363 - INFO - Détails récupérés pour le jeu 357700
# 2024-08-02 10:27:06,892 - INFO - Informations de la page Steam récupérées pour le jeu 357700
# 2024-08-02 10:27:07,817 - INFO - Traitement du game_id : 357710
# 2024-08-02 10:27:08,243 - INFO - Détails récupérés pour le jeu 357710
# 2024-08-02 10:27:08,734 - INFO - Informations de la page Steam récupérées pour le jeu 357710
# 2024-08-02 10:27:09,692 - INFO - Traitement du game_id : 357711
# 2024-08-02 10:27:10,172 - INFO - Détails récupérés pour le jeu 357711
# 2024-08-02 10:27:10,586 - INFO - Informations de la page Steam récupérées pour le jeu 357711
# 2024-08-02 10:27:11,261 - INFO - Traitement du game_id : 357720
# 2024-08-02 10:27:11,526 - INFO - Détails récupérés pour le jeu 357720
# 2024-08-02 10:27:12,354 - INFO - Informations de la page Steam récupérées pour le jeu 357720
# 2024-08-02 10:27:13,986 - INFO - Traitement du game_id : 357750
# 2024-08-02 10:27:14,352 - INFO - Détails récupérés pour le jeu 357750
# 2024-08-02 10:27:14,993 - INFO - Informations de la page Steam récupérées pour le jeu 357750
# 2024-08-02 10:27:16,538 - INFO - Traitement du game_id : 357760
# 2024-08-02 10:27:16,775 - INFO - Détails récupérés pour le jeu 357760
# 2024-08-02 10:27:17,274 - INFO - Informations de la page Steam récupérées pour le jeu 357760
# 2024-08-02 10:27:18,535 - INFO - Traitement du game_id : 357780
# 2024-08-02 10:27:18,897 - INFO - Détails récupérés pour le jeu 357780
# 2024-08-02 10:27:19,314 - INFO - Informations de la page Steam récupérées pour le jeu 357780
# 2024-08-02 10:27:20,001 - INFO - Traitement du game_id : 357800
# 2024-08-02 10:27:20,232 - INFO - Détails récupérés pour le jeu 357800
# 2024-08-02 10:27:20,877 - INFO - Informations de la page Steam récupérées pour le jeu 357800
# 2024-08-02 10:27:21,412 - INFO - Traitement du game_id : 357820
# 2024-08-02 10:27:21,634 - WARNING - Pas de données pour le jeu 357820
# 2024-08-02 10:27:22,390 - INFO - Traitement du game_id : 357830
# 2024-08-02 10:27:22,625 - INFO - Détails récupérés pour le jeu 357830
# 2024-08-02 10:27:23,049 - INFO - Informations de la page Steam récupérées pour le jeu 357830
# 2024-08-02 10:27:24,049 - INFO - Traitement du game_id : 357840
# 2024-08-02 10:27:24,428 - INFO - Détails récupérés pour le jeu 357840
# 2024-08-02 10:27:24,956 - INFO - Informations de la page Steam récupérées pour le jeu 357840
# 2024-08-02 10:27:26,402 - INFO - Traitement du game_id : 357890
# 2024-08-02 10:27:26,763 - INFO - Détails récupérés pour le jeu 357890
# 2024-08-02 10:27:27,306 - INFO - Informations de la page Steam récupérées pour le jeu 357890
# 2024-08-02 10:27:28,145 - INFO - Traitement du game_id : 357900
# 2024-08-02 10:27:28,483 - INFO - Détails récupérés pour le jeu 357900
# 2024-08-02 10:27:29,366 - INFO - Informations de la page Steam récupérées pour le jeu 357900
# 2024-08-02 10:27:30,199 - INFO - Traitement du game_id : 357910
# 2024-08-02 10:27:30,573 - INFO - Détails récupérés pour le jeu 357910
# 2024-08-02 10:27:31,582 - INFO - Informations de la page Steam récupérées pour le jeu 357910
# 2024-08-02 10:27:33,064 - INFO - Traitement du game_id : 357920
# 2024-08-02 10:27:33,396 - INFO - Détails récupérés pour le jeu 357920
# 2024-08-02 10:27:34,085 - INFO - Informations de la page Steam récupérées pour le jeu 357920
# 2024-08-02 10:27:34,656 - INFO - Traitement du game_id : 357930
# 2024-08-02 10:27:34,962 - INFO - Détails récupérés pour le jeu 357930
# 2024-08-02 10:27:35,656 - INFO - Informations de la page Steam récupérées pour le jeu 357930
# 2024-08-02 10:27:36,533 - INFO - Traitement du game_id : 357940
# 2024-08-02 10:27:36,793 - INFO - Détails récupérés pour le jeu 357940
# 2024-08-02 10:27:37,499 - INFO - Informations de la page Steam récupérées pour le jeu 357940
# 2024-08-02 10:27:38,821 - INFO - Traitement du game_id : 357970
# 2024-08-02 10:27:39,049 - INFO - Détails récupérés pour le jeu 357970
# 2024-08-02 10:27:39,726 - INFO - Informations de la page Steam récupérées pour le jeu 357970
# 2024-08-02 10:27:40,758 - INFO - Traitement du game_id : 357980
# 2024-08-02 10:27:41,109 - WARNING - Pas de données pour le jeu 357980
# 2024-08-02 10:27:41,910 - INFO - Traitement du game_id : 358000
# 2024-08-02 10:27:42,164 - INFO - Détails récupérés pour le jeu 358000
# 2024-08-02 10:27:42,792 - INFO - Informations de la page Steam récupérées pour le jeu 358000
# 2024-08-02 10:27:44,122 - INFO - Traitement du game_id : 358010
# 2024-08-02 10:27:44,381 - INFO - Détails récupérés pour le jeu 358010
# 2024-08-02 10:27:45,137 - INFO - Informations de la page Steam récupérées pour le jeu 358010
# 2024-08-02 10:27:46,627 - INFO - Traitement du game_id : 358020
# 2024-08-02 10:27:46,879 - INFO - Détails récupérés pour le jeu 358020
# 2024-08-02 10:27:47,267 - INFO - Informations de la page Steam récupérées pour le jeu 358020
# 2024-08-02 10:27:48,544 - INFO - Traitement du game_id : 358030
# 2024-08-02 10:27:49,003 - INFO - Détails récupérés pour le jeu 358030
# 2024-08-02 10:27:49,443 - INFO - Informations de la page Steam récupérées pour le jeu 358030
# 2024-08-02 10:27:51,050 - INFO - Traitement du game_id : 358070
# 2024-08-02 10:27:51,387 - INFO - Détails récupérés pour le jeu 358070
# 2024-08-02 10:27:52,164 - INFO - Informations de la page Steam récupérées pour le jeu 358070
# 2024-08-02 10:27:53,440 - INFO - Traitement du game_id : 358080
# 2024-08-02 10:27:53,918 - INFO - Détails récupérés pour le jeu 358080
# 2024-08-02 10:27:54,842 - INFO - Informations de la page Steam récupérées pour le jeu 358080
# 2024-08-02 10:27:56,132 - INFO - Traitement du game_id : 358090
# 2024-08-02 10:27:56,623 - INFO - Détails récupérés pour le jeu 358090
# 2024-08-02 10:27:57,545 - INFO - Informations de la page Steam récupérées pour le jeu 358090
# 2024-08-02 10:27:59,218 - INFO - Traitement du game_id : 358110
# 2024-08-02 10:27:59,447 - WARNING - Pas de données pour le jeu 358110
# 2024-08-02 10:28:00,219 - INFO - Traitement du game_id : 358120
# 2024-08-02 10:28:00,592 - INFO - Détails récupérés pour le jeu 358120
# 2024-08-02 10:28:01,342 - INFO - Informations de la page Steam récupérées pour le jeu 358120
# 2024-08-02 10:28:02,328 - INFO - Traitement du game_id : 358130
# 2024-08-02 10:28:02,751 - INFO - Détails récupérés pour le jeu 358130
# 2024-08-02 10:28:03,330 - INFO - Informations de la page Steam récupérées pour le jeu 358130
# 2024-08-02 10:28:04,074 - INFO - Traitement du game_id : 358140
# 2024-08-02 10:28:04,413 - INFO - Détails récupérés pour le jeu 358140
# 2024-08-02 10:28:04,925 - INFO - Informations de la page Steam récupérées pour le jeu 358140
# 2024-08-02 10:28:05,596 - INFO - Traitement du game_id : 358141
# 2024-08-02 10:28:05,836 - INFO - Détails récupérés pour le jeu 358141
# 2024-08-02 10:28:06,483 - INFO - Informations de la page Steam récupérées pour le jeu 358141
# 2024-08-02 10:28:07,222 - INFO - Traitement du game_id : 358142
# 2024-08-02 10:28:07,458 - INFO - Détails récupérés pour le jeu 358142
# 2024-08-02 10:28:07,933 - INFO - Informations de la page Steam récupérées pour le jeu 358142
# 2024-08-02 10:28:09,627 - INFO - Traitement du game_id : 358143
# 2024-08-02 10:28:09,977 - INFO - Détails récupérés pour le jeu 358143
# 2024-08-02 10:28:24,028 - INFO - Informations de la page Steam récupérées pour le jeu 358143
# 2024-08-02 10:28:24,577 - INFO - Traitement du game_id : 358150
# 2024-08-02 10:28:25,097 - INFO - Détails récupérés pour le jeu 358150
# 2024-08-02 10:28:25,600 - INFO - Informations de la page Steam récupérées pour le jeu 358150
# 2024-08-02 10:28:27,122 - INFO - Traitement du game_id : 358190
# 2024-08-02 10:28:27,387 - INFO - Détails récupérés pour le jeu 358190
# 2024-08-02 10:28:27,747 - INFO - Informations de la page Steam récupérées pour le jeu 358190
# 2024-08-02 10:28:29,433 - INFO - Traitement du game_id : 358200
# 2024-08-02 10:28:29,692 - INFO - Détails récupérés pour le jeu 358200
# 2024-08-02 10:28:30,207 - INFO - Informations de la page Steam récupérées pour le jeu 358200
# 2024-08-02 10:28:31,724 - INFO - Traitement du game_id : 358210
# 2024-08-02 10:28:32,013 - INFO - Détails récupérés pour le jeu 358210
# 2024-08-02 10:28:32,696 - INFO - Informations de la page Steam récupérées pour le jeu 358210
# 2024-08-02 10:28:34,002 - INFO - Traitement du game_id : 358220
# 2024-08-02 10:28:34,246 - INFO - Détails récupérés pour le jeu 358220
# 2024-08-02 10:28:34,848 - INFO - Informations de la page Steam récupérées pour le jeu 358220
# 2024-08-02 10:28:36,302 - INFO - Traitement du game_id : 358230
# 2024-08-02 10:28:36,548 - INFO - Détails récupérés pour le jeu 358230
# 2024-08-02 10:28:37,155 - INFO - Informations de la page Steam récupérées pour le jeu 358230
# 2024-08-02 10:28:37,826 - INFO - Traitement du game_id : 358250
# 2024-08-02 10:28:38,065 - INFO - Détails récupérés pour le jeu 358250
# 2024-08-02 10:28:38,452 - INFO - Informations de la page Steam récupérées pour le jeu 358250
# 2024-08-02 10:28:38,967 - INFO - Traitement du game_id : 358260
# 2024-08-02 10:28:39,262 - INFO - Détails récupérés pour le jeu 358260
# 2024-08-02 10:28:39,998 - INFO - Informations de la page Steam récupérées pour le jeu 358260
# 2024-08-02 10:28:40,792 - INFO - Traitement du game_id : 358270
# 2024-08-02 10:28:41,293 - INFO - Détails récupérés pour le jeu 358270
# 2024-08-02 10:28:41,997 - INFO - Informations de la page Steam récupérées pour le jeu 358270
# 2024-08-02 10:28:42,656 - INFO - Traitement du game_id : 358290
# 2024-08-02 10:28:42,926 - INFO - Détails récupérés pour le jeu 358290
# 2024-08-02 10:28:43,860 - INFO - Informations de la page Steam récupérées pour le jeu 358290
# 2024-08-02 10:28:45,112 - INFO - Traitement du game_id : 358300
# 2024-08-02 10:28:45,423 - INFO - Détails récupérés pour le jeu 358300
# 2024-08-02 10:28:46,067 - INFO - Informations de la page Steam récupérées pour le jeu 358300
# 2024-08-02 10:28:46,799 - INFO - Traitement du game_id : 358310
# 2024-08-02 10:28:47,056 - INFO - Détails récupérés pour le jeu 358310
# 2024-08-02 10:28:47,789 - INFO - Informations de la page Steam récupérées pour le jeu 358310
# 2024-08-02 10:28:49,415 - INFO - Traitement du game_id : 358320
# 2024-08-02 10:28:49,642 - INFO - Détails récupérés pour le jeu 358320
# 2024-08-02 10:28:50,471 - INFO - Informations de la page Steam récupérées pour le jeu 358320
# 2024-08-02 10:28:51,327 - INFO - Traitement du game_id : 358340
# 2024-08-02 10:28:51,562 - INFO - Détails récupérés pour le jeu 358340
# 2024-08-02 10:28:52,151 - INFO - Informations de la page Steam récupérées pour le jeu 358340
# 2024-08-02 10:28:53,689 - INFO - Traitement du game_id : 358350
# 2024-08-02 10:28:53,941 - INFO - Détails récupérés pour le jeu 358350
# 2024-08-02 10:28:54,588 - INFO - Informations de la page Steam récupérées pour le jeu 358350
# 2024-08-02 10:28:55,558 - INFO - Traitement du game_id : 358360
# 2024-08-02 10:28:55,832 - INFO - Détails récupérés pour le jeu 358360
# 2024-08-02 10:28:56,258 - INFO - Informations de la page Steam récupérées pour le jeu 358360
# ...
# 2024-08-02 14:31:12,673 - INFO - Informations de la page Steam récupérées pour le jeu 416380
# 2024-08-02 14:31:13,765 - INFO - Traitement du game_id : 416390
# 2024-08-02 14:31:14,025 - INFO - Détails récupérés pour le jeu 416390
# 2024-08-02 14:31:14,584 - INFO - Informations de la page Steam récupérées pour le jeu 416390
# 2024-08-02 14:31:15,527 - INFO - Traitement du game_id : 416400
# 2024-08-02 14:31:15,752 - INFO - Détails récupérés pour le jeu 416400
# 2024-08-02 14:31:16,314 - INFO - Informations de la page Steam récupérées pour le jeu 416400
# 2024-08-02 14:31:16,965 - INFO - Traitement du game_id : 416410
# 2024-08-02 14:31:17,200 - WARNING - Pas de données pour le jeu 416410
# 2024-08-02 14:31:17,943 - INFO - Traitement du game_id : 416420
# 2024-08-02 14:31:18,185 - INFO - Détails récupérés pour le jeu 416420
# 2024-08-02 14:31:18,559 - INFO - Informations de la page Steam récupérées pour le jeu 416420
# 2024-08-02 14:31:20,139 - INFO - Traitement du game_id : 416421
# 2024-08-02 14:31:20,378 - INFO - Détails récupérés pour le jeu 416421
# 2024-08-02 14:31:20,917 - INFO - Informations de la page Steam récupérées pour le jeu 416421
# 2024-08-02 14:31:21,433 - INFO - Traitement du game_id : 416422
# 2024-08-02 14:31:21,670 - INFO - Détails récupérés pour le jeu 416422
# 2024-08-02 14:31:22,049 - INFO - Informations de la page Steam récupérées pour le jeu 416422
# 2024-08-02 14:31:23,285 - INFO - Traitement du game_id : 416423
# 2024-08-02 14:31:23,494 - WARNING - Pas de données pour le jeu 416423
# 2024-08-02 14:31:24,414 - INFO - Traitement du game_id : 416424
# 2024-08-02 14:31:24,915 - INFO - Détails récupérés pour le jeu 416424
# 2024-08-02 14:31:25,328 - INFO - Informations de la page Steam récupérées pour le jeu 416424
# 2024-08-02 14:31:26,445 - INFO - Traitement du game_id : 416430
# 2024-08-02 14:31:26,735 - INFO - Détails récupérés pour le jeu 416430
# 2024-08-02 14:31:27,386 - INFO - Informations de la page Steam récupérées pour le jeu 416430
# 2024-08-02 14:31:28,701 - INFO - Traitement du game_id : 416440
# 2024-08-02 14:31:28,930 - INFO - Détails récupérés pour le jeu 416440
# 2024-08-02 14:31:29,678 - INFO - Informations de la page Steam récupérées pour le jeu 416440
# 2024-08-02 14:31:31,244 - INFO - Traitement du game_id : 416450
# 2024-08-02 14:31:31,673 - INFO - Détails récupérés pour le jeu 416450
# 2024-08-02 14:31:32,330 - INFO - Informations de la page Steam récupérées pour le jeu 416450
# 2024-08-02 14:31:33,345 - INFO - Traitement du game_id : 416480
# 2024-08-02 14:31:33,665 - INFO - Détails récupérés pour le jeu 416480
# 2024-08-02 14:31:34,151 - INFO - Informations de la page Steam récupérées pour le jeu 416480
# 2024-08-02 14:31:35,203 - INFO - Traitement du game_id : 416530
# 2024-08-02 14:31:35,447 - INFO - Détails récupérés pour le jeu 416530
# 2024-08-02 14:31:35,971 - INFO - Informations de la page Steam récupérées pour le jeu 416530
# 2024-08-02 14:31:36,590 - INFO - Traitement du game_id : 416550
# 2024-08-02 14:31:36,840 - INFO - Détails récupérés pour le jeu 416550
# 2024-08-02 14:31:37,533 - INFO - Informations de la page Steam récupérées pour le jeu 416550
# 2024-08-02 14:31:38,594 - INFO - Traitement du game_id : 416590
# 2024-08-02 14:31:38,861 - INFO - Détails récupérés pour le jeu 416590
# 2024-08-02 14:31:39,336 - INFO - Informations de la page Steam récupérées pour le jeu 416590
# 2024-08-02 14:31:40,316 - INFO - Traitement du game_id : 416600
# 2024-08-02 14:31:40,580 - INFO - Détails récupérés pour le jeu 416600
# 2024-08-02 14:31:41,060 - INFO - Informations de la page Steam récupérées pour le jeu 416600
# 2024-08-02 14:31:42,040 - INFO - Traitement du game_id : 416610
# 2024-08-02 14:31:42,403 - INFO - Détails récupérés pour le jeu 416610
# 2024-08-02 14:31:43,055 - INFO - Informations de la page Steam récupérées pour le jeu 416610
# 2024-08-02 14:31:43,817 - INFO - Traitement du game_id : 416630
# 2024-08-02 14:31:44,052 - INFO - Détails récupérés pour le jeu 416630
# 2024-08-02 14:31:44,515 - INFO - Informations de la page Steam récupérées pour le jeu 416630
# 2024-08-02 14:31:45,420 - INFO - Traitement du game_id : 416640
# 2024-08-02 14:31:45,673 - INFO - Détails récupérés pour le jeu 416640
# 2024-08-02 14:31:46,777 - INFO - Informations de la page Steam récupérées pour le jeu 416640
# 2024-08-02 14:31:47,925 - INFO - Traitement du game_id : 416650
# 2024-08-02 14:31:48,181 - INFO - Détails récupérés pour le jeu 416650
# 2024-08-02 14:31:49,297 - INFO - Informations de la page Steam récupérées pour le jeu 416650
# 2024-08-02 14:31:50,711 - INFO - Traitement du game_id : 416670
# 2024-08-02 14:31:50,947 - INFO - Détails récupérés pour le jeu 416670
# 2024-08-02 14:31:51,593 - INFO - Informations de la page Steam récupérées pour le jeu 416670
# 2024-08-02 14:31:52,743 - INFO - Traitement du game_id : 416680
# 2024-08-02 14:31:53,175 - INFO - Détails récupérés pour le jeu 416680
# 2024-08-02 14:31:54,077 - INFO - Informations de la page Steam récupérées pour le jeu 416680
# 2024-08-02 14:31:55,601 - INFO - Traitement du game_id : 416690
# 2024-08-02 14:31:55,829 - INFO - Détails récupérés pour le jeu 416690
# 2024-08-02 14:31:56,390 - INFO - Informations de la page Steam récupérées pour le jeu 416690
# 2024-08-02 14:31:57,549 - INFO - Traitement du game_id : 416700
# 2024-08-02 14:31:57,808 - INFO - Détails récupérés pour le jeu 416700
# 2024-08-02 14:31:58,761 - INFO - Informations de la page Steam récupérées pour le jeu 416700
# 2024-08-02 14:31:59,675 - INFO - Traitement du game_id : 416710
# 2024-08-02 14:31:59,901 - INFO - Détails récupérés pour le jeu 416710
# 2024-08-02 14:32:00,505 - INFO - Informations de la page Steam récupérées pour le jeu 416710
# 2024-08-02 14:32:01,198 - INFO - Traitement du game_id : 416711
# 2024-08-02 14:32:01,438 - INFO - Détails récupérés pour le jeu 416711
# 2024-08-02 14:32:01,797 - INFO - Informations de la page Steam récupérées pour le jeu 416711
# 2024-08-02 14:32:03,256 - INFO - Traitement du game_id : 416712
# 2024-08-02 14:32:03,512 - INFO - Détails récupérés pour le jeu 416712
# 2024-08-02 14:32:03,902 - INFO - Informations de la page Steam récupérées pour le jeu 416712
# 2024-08-02 14:32:04,880 - INFO - Traitement du game_id : 416713
# 2024-08-02 14:32:05,104 - INFO - Détails récupérés pour le jeu 416713
# 2024-08-02 14:32:05,548 - INFO - Informations de la page Steam récupérées pour le jeu 416713
# 2024-08-02 14:32:06,660 - INFO - Traitement du game_id : 416720
# 2024-08-02 14:32:06,904 - INFO - Détails récupérés pour le jeu 416720
# 2024-08-02 14:32:07,643 - INFO - Informations de la page Steam récupérées pour le jeu 416720
# 2024-08-02 14:32:09,122 - INFO - Traitement du game_id : 416750
# 2024-08-02 14:32:09,349 - INFO - Détails récupérés pour le jeu 416750
# 2024-08-02 14:32:09,762 - INFO - Informations de la page Steam récupérées pour le jeu 416750
# 2024-08-02 14:32:10,807 - INFO - Traitement du game_id : 416760
# 2024-08-02 14:32:11,120 - INFO - Détails récupérés pour le jeu 416760
# 2024-08-02 14:32:11,771 - INFO - Informations de la page Steam récupérées pour le jeu 416760
# 2024-08-02 14:32:12,876 - INFO - Traitement du game_id : 416770
# 2024-08-02 14:32:13,330 - INFO - Détails récupérés pour le jeu 416770
# 2024-08-02 14:32:14,239 - INFO - Informations de la page Steam récupérées pour le jeu 416770
# 2024-08-02 14:32:15,536 - INFO - Traitement du game_id : 416790
# 2024-08-02 14:32:15,916 - INFO - Détails récupérés pour le jeu 416790
# 2024-08-02 14:32:16,567 - INFO - Informations de la page Steam récupérées pour le jeu 416790
# 2024-08-02 14:32:17,610 - INFO - Traitement du game_id : 416800
# 2024-08-02 14:32:17,852 - INFO - Détails récupérés pour le jeu 416800
# 2024-08-02 14:32:18,776 - INFO - Informations de la page Steam récupérées pour le jeu 416800
# 2024-08-02 14:32:20,260 - INFO - Traitement du game_id : 416830
# 2024-08-02 14:32:20,547 - INFO - Détails récupérés pour le jeu 416830
# 2024-08-02 14:32:21,298 - INFO - Informations de la page Steam récupérées pour le jeu 416830
# 2024-08-02 14:32:22,221 - INFO - Traitement du game_id : 416840
# 2024-08-02 14:32:22,671 - INFO - Détails récupérés pour le jeu 416840
# 2024-08-02 14:32:23,438 - INFO - Informations de la page Steam récupérées pour le jeu 416840
# 2024-08-02 14:32:24,656 - INFO - Traitement du game_id : 416850
# 2024-08-02 14:32:24,961 - INFO - Détails récupérés pour le jeu 416850
# 2024-08-02 14:32:25,406 - INFO - Informations de la page Steam récupérées pour le jeu 416850
# 2024-08-02 14:32:26,428 - INFO - Traitement du game_id : 416870
# 2024-08-02 14:32:26,678 - INFO - Détails récupérés pour le jeu 416870
# 2024-08-02 14:32:35,971 - INFO - Informations de la page Steam récupérées pour le jeu 416870
# 2024-08-02 14:32:37,463 - INFO - Traitement du game_id : 416880
# 2024-08-02 14:32:37,792 - WARNING - Pas de données pour le jeu 416880
# 2024-08-02 14:32:39,394 - INFO - Traitement du game_id : 416900
# 2024-08-02 14:32:39,631 - INFO - Détails récupérés pour le jeu 416900
# 2024-08-02 14:32:40,499 - INFO - Informations de la page Steam récupérées pour le jeu 416900
# 2024-08-02 14:32:41,226 - INFO - Traitement du game_id : 416920
# 2024-08-02 14:32:41,570 - INFO - Détails récupérés pour le jeu 416920
# 2024-08-02 14:32:42,218 - INFO - Informations de la page Steam récupérées pour le jeu 416920
# 2024-08-02 14:32:43,594 - INFO - Traitement du game_id : 416930
# 2024-08-02 14:32:43,826 - INFO - Détails récupérés pour le jeu 416930
# 2024-08-02 14:32:44,464 - INFO - Informations de la page Steam récupérées pour le jeu 416930
# 2024-08-02 14:32:45,730 - INFO - Traitement du game_id : 417020
# 2024-08-02 14:32:45,954 - INFO - Détails récupérés pour le jeu 417020
# 2024-08-02 14:32:46,762 - INFO - Informations de la page Steam récupérées pour le jeu 417020
# 2024-08-02 14:32:48,335 - INFO - Traitement du game_id : 417060
# 2024-08-02 14:32:48,628 - INFO - Détails récupérés pour le jeu 417060
# 2024-08-02 14:32:49,095 - INFO - Informations de la page Steam récupérées pour le jeu 417060
# 2024-08-02 14:32:49,628 - INFO - Traitement du game_id : 417080
# 2024-08-02 14:32:49,863 - INFO - Détails récupérés pour le jeu 417080
# 2024-08-02 14:32:50,734 - INFO - Informations de la page Steam récupérées pour le jeu 417080
# 2024-08-02 14:32:51,608 - INFO - Traitement du game_id : 417110
# 2024-08-02 14:32:51,880 - INFO - Détails récupérés pour le jeu 417110
# 2024-08-02 14:32:52,573 - INFO - Informations de la page Steam récupérées pour le jeu 417110
# 2024-08-02 14:32:53,398 - INFO - Traitement du game_id : 417130
# 2024-08-02 14:32:53,853 - INFO - Détails récupérés pour le jeu 417130
# 2024-08-02 14:32:54,503 - INFO - Informations de la page Steam récupérées pour le jeu 417130
# 2024-08-02 14:32:56,159 - INFO - Traitement du game_id : 417150
# 2024-08-02 14:32:56,463 - INFO - Détails récupérés pour le jeu 417150
# 2024-08-02 14:32:57,281 - INFO - Informations de la page Steam récupérées pour le jeu 417150
# 2024-08-02 14:32:58,766 - INFO - Traitement du game_id : 417160
# 2024-08-02 14:32:59,130 - INFO - Détails récupérés pour le jeu 417160
# 2024-08-02 14:32:59,566 - INFO - Informations de la page Steam récupérées pour le jeu 417160
# 2024-08-02 14:33:01,024 - INFO - Traitement du game_id : 417190
# 2024-08-02 14:33:01,325 - INFO - Détails récupérés pour le jeu 417190
# 2024-08-02 14:33:02,041 - INFO - Informations de la page Steam récupérées pour le jeu 417190
# 2024-08-02 14:33:02,843 - INFO - Traitement du game_id : 417200
# 2024-08-02 14:33:03,091 - INFO - Détails récupérés pour le jeu 417200
# 2024-08-02 14:33:03,752 - INFO - Informations de la page Steam récupérées pour le jeu 417200
# 2024-08-02 14:33:04,707 - INFO - Traitement du game_id : 417230
# 2024-08-02 14:33:04,927 - INFO - Détails récupérés pour le jeu 417230
# 2024-08-02 14:33:05,638 - INFO - Informations de la page Steam récupérées pour le jeu 417230
# 2024-08-02 14:33:06,543 - INFO - Traitement du game_id : 417260
# 2024-08-02 14:33:06,777 - INFO - Détails récupérés pour le jeu 417260
# 2024-08-02 14:33:08,401 - INFO - Informations de la page Steam récupérées pour le jeu 417260
# 2024-08-02 14:33:09,086 - INFO - Traitement du game_id : 417280
# 2024-08-02 14:33:09,386 - WARNING - Pas de données pour le jeu 417280
# 2024-08-02 14:33:10,289 - INFO - Traitement du game_id : 417290
# 2024-08-02 14:33:10,575 - INFO - Détails récupérés pour le jeu 417290
# 2024-08-02 14:33:11,074 - INFO - Informations de la page Steam récupérées pour le jeu 417290
# 2024-08-02 14:33:12,212 - INFO - Traitement du game_id : 417310
# 2024-08-02 14:33:12,473 - INFO - Détails récupérés pour le jeu 417310
# 2024-08-02 14:33:13,186 - INFO - Informations de la page Steam récupérées pour le jeu 417310
# 2024-08-02 14:33:14,790 - INFO - Traitement du game_id : 417350
# 2024-08-02 14:33:15,027 - INFO - Détails récupérés pour le jeu 417350
# 2024-08-02 14:33:16,222 - INFO - Informations de la page Steam récupérées pour le jeu 417350
# 2024-08-02 14:33:17,527 - INFO - Traitement du game_id : 417360
# 2024-08-02 14:33:17,776 - INFO - Détails récupérés pour le jeu 417360
# 2024-08-02 14:33:18,215 - INFO - Informations de la page Steam récupérées pour le jeu 417360
# 2024-08-02 14:33:19,310 - INFO - Traitement du game_id : 417380
# 2024-08-02 14:33:19,686 - INFO - Détails récupérés pour le jeu 417380
# 2024-08-02 14:33:20,220 - INFO - Informations de la page Steam récupérées pour le jeu 417380
# 2024-08-02 14:33:21,073 - INFO - Traitement du game_id : 417390
# 2024-08-02 14:33:21,315 - INFO - Détails récupérés pour le jeu 417390
# 2024-08-02 14:33:21,933 - INFO - Informations de la page Steam récupérées pour le jeu 417390
# 2024-08-02 14:33:23,034 - INFO - Traitement du game_id : 417400
# 2024-08-02 14:33:23,365 - INFO - Détails récupérés pour le jeu 417400
# 2024-08-02 14:33:23,819 - INFO - Informations de la page Steam récupérées pour le jeu 417400
# 2024-08-02 14:33:24,802 - INFO - Traitement du game_id : 417410
# 2024-08-02 14:33:25,134 - INFO - Détails récupérés pour le jeu 417410
# 2024-08-02 14:33:25,879 - INFO - Informations de la page Steam récupérées pour le jeu 417410
# 2024-08-02 14:33:27,264 - INFO - Traitement du game_id : 417420
# 2024-08-02 14:33:27,544 - INFO - Détails récupérés pour le jeu 417420
# 2024-08-02 14:33:28,206 - INFO - Informations de la page Steam récupérées pour le jeu 417420
# 2024-08-02 14:33:29,694 - INFO - Traitement du game_id : 417430
# 2024-08-02 14:33:29,935 - INFO - Détails récupérés pour le jeu 417430
# 2024-08-02 14:33:30,456 - INFO - Informations de la page Steam récupérées pour le jeu 417430
# 2024-08-02 14:33:31,855 - INFO - Traitement du game_id : 417461
# 2024-08-02 14:33:32,094 - INFO - Détails récupérés pour le jeu 417461
# 2024-08-02 14:33:32,522 - INFO - Informations de la page Steam récupérées pour le jeu 417461
# 2024-08-02 14:33:33,033 - INFO - Traitement du game_id : 417462
# 2024-08-02 14:33:33,275 - INFO - Détails récupérés pour le jeu 417462
# 2024-08-02 14:33:33,802 - INFO - Informations de la page Steam récupérées pour le jeu 417462
# 2024-08-02 14:33:34,738 - INFO - Traitement du game_id : 417463
# 2024-08-02 14:33:34,975 - INFO - Détails récupérés pour le jeu 417463
# 2024-08-02 14:33:35,446 - INFO - Informations de la page Steam récupérées pour le jeu 417463
# 2024-08-02 14:33:36,328 - INFO - Traitement du game_id : 417464
# 2024-08-02 14:33:36,600 - INFO - Détails récupérés pour le jeu 417464
# 2024-08-02 14:33:37,178 - INFO - Informations de la page Steam récupérées pour le jeu 417464
# 2024-08-02 14:33:38,126 - INFO - Traitement du game_id : 417465
# 2024-08-02 14:33:38,388 - INFO - Détails récupérés pour le jeu 417465
# 2024-08-02 14:33:38,899 - INFO - Informations de la page Steam récupérées pour le jeu 417465
# 2024-08-02 14:33:40,312 - INFO - Traitement du game_id : 417480
# 2024-08-02 14:33:40,699 - INFO - Détails récupérés pour le jeu 417480
# 2024-08-02 14:33:41,498 - INFO - Informations de la page Steam récupérées pour le jeu 417480
# 2024-08-02 14:33:42,883 - INFO - Traitement du game_id : 417520
# 2024-08-02 14:33:43,280 - INFO - Détails récupérés pour le jeu 417520
# 2024-08-02 14:33:44,416 - INFO - Informations de la page Steam récupérées pour le jeu 417520
# 2024-08-02 14:33:45,931 - INFO - Mise à jour terminée avec succès
# 2024-08-02 14:33:45,933 - INFO - Fichier temporaire supprimé
