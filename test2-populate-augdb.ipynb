# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random

# Fonction pour télécharger la base de données steam_games.db
def download_db(url, local_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    print(f"Échec du téléchargement de la base de données. Code de statut: {response.status_code}")
    return False

# Fonction pour obtenir les détails d'un jeu via l'API Steam
def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(steam_game_id)]['success']:
            return data[str(steam_game_id)]['data']
    return None

# Fonction pour obtenir les informations de la page Steam d'un jeu
def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Vérifier la présence de contenu généré par IA
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        
        # Recherche de la section "AI Generated Content Disclosure"
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        # Récupérer les tags
        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except Exception as e:
        print(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
        return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                print(f"Database is locked. Retrying in {delay} seconds...")
                time.sleep(delay)
                delay *= 2  # Augmenter le délai exponentiellement
            else:
                raise


def ensure_column_exists(cursor, table_name, column_name, column_type):
    """Vérifie si une colonne existe dans la table et l'ajoute si ce n'est pas le cas."""
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        print(f"Colonne '{column_name}' ajoutée à la table {table_name}")



# Fonction principale

def update_aug_steam_games():
    # Charger le dernier game_id traité
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
    except FileNotFoundError:
        last_processed_id = 12570  # Valeur par défaut si le fichier n'existe pas

    # Télécharger steam_games.db
    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            print("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            # Connexion aux bases de données
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            # Vérifier et ajouter la colonne 'type' si nécessaire
            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            # Récupérer les 500 prochains game_ids
            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 1000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                print(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    # Préparer les données pour l'insertion
                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    # Insérer ou mettre à jour les données
                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                # Mettre à jour le dernier game_id traité
                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                # Pause pour éviter de surcharger l'API
                time.sleep(random.uniform(0.5, 1.7))

            # Commit des changements
            conn_aug.commit()
            
        except Exception as e:
            print(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    # Supprimer le fichier temporaire
    os.unlink(temp_db.name)

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# Traitement du game_id : 33280
# Traitement du game_id : 33287
# Traitement du game_id : 33288
# Traitement du game_id : 33289
# Traitement du game_id : 33290
# Traitement du game_id : 33310
# Traitement du game_id : 33320
# Traitement du game_id : 33325
# Traitement du game_id : 33326
# Traitement du game_id : 33349
# Traitement du game_id : 33359
# Traitement du game_id : 33360
# Traitement du game_id : 33361
# Traitement du game_id : 33362
# Traitement du game_id : 33370
# Traitement du game_id : 33371
# Traitement du game_id : 33390
# Traitement du game_id : 33400
# Traitement du game_id : 33420
# Traitement du game_id : 33428
# Traitement du game_id : 33435
# Traitement du game_id : 33436
# Traitement du game_id : 33446
# Traitement du game_id : 33447
# Traitement du game_id : 33448
# Traitement du game_id : 33456
# Traitement du game_id : 33457
# Traitement du game_id : 33460
# Traitement du game_id : 33500
# Traitement du game_id : 33510
# Traitement du game_id : 33520
# Traitement du game_id : 33530
# Traitement du game_id : 33540
# Traitement du game_id : 33549
# Traitement du game_id : 33550
# Traitement du game_id : 33559
# Traitement du game_id : 33560
# Traitement du game_id : 33570
# Traitement du game_id : 33580
# Traitement du game_id : 33600
# Traitement du game_id : 33610
# Traitement du game_id : 33620
# Traitement du game_id : 33630
# Traitement du game_id : 33650
# Traitement du game_id : 33660
# Traitement du game_id : 33670
# Traitement du game_id : 33680
# Traitement du game_id : 33700
# Traitement du game_id : 33710
# Traitement du game_id : 33720
# Traitement du game_id : 33730
# Traitement du game_id : 33740
# Traitement du game_id : 33750
# Traitement du game_id : 33760
# Traitement du game_id : 33770
# Traitement du game_id : 33780
# Traitement du game_id : 33790
# Traitement du game_id : 33900
# Traitement du game_id : 33905
# Traitement du game_id : 33909
# Traitement du game_id : 33910
# Traitement du game_id : 33919
# Traitement du game_id : 33920
# Traitement du game_id : 33930
# Traitement du game_id : 33934
# Traitement du game_id : 33935
# Traitement du game_id : 33936
# Traitement du game_id : 33950
# Traitement du game_id : 33960
# Traitement du game_id : 33970
# Traitement du game_id : 33980
# Traitement du game_id : 33990
# Traitement du game_id : 34000
# Traitement du game_id : 34009
# Traitement du game_id : 34010
# Traitement du game_id : 34019
# Traitement du game_id : 34030
# Traitement du game_id : 34039
# Traitement du game_id : 34049
# Traitement du game_id : 34050
# Traitement du game_id : 34110
# Traitement du game_id : 34120
# Traitement du game_id : 34170
# Traitement du game_id : 34171
# Traitement du game_id : 34172
# Traitement du game_id : 34173
# Traitement du game_id : 34174
# Traitement du game_id : 34175
# Traitement du game_id : 34176
# Traitement du game_id : 34177
# Traitement du game_id : 34178
# Traitement du game_id : 34179
# Traitement du game_id : 34184
# Traitement du game_id : 34189
# Traitement du game_id : 34190
# Traitement du game_id : 34200
# Traitement du game_id : 34220
# Traitement du game_id : 34229
# Traitement du game_id : 34250
# Traitement du game_id : 34270
# Traitement du game_id : 34272
# Traitement du game_id : 34273
# Traitement du game_id : 34274
# Traitement du game_id : 34275
# Traitement du game_id : 34276
# Traitement du game_id : 34277
# Traitement du game_id : 34278
# Traitement du game_id : 34279
# Traitement du game_id : 34280
# Traitement du game_id : 34281
# Traitement du game_id : 34282
# Traitement du game_id : 34283
# Traitement du game_id : 34284
# Traitement du game_id : 34285
# Traitement du game_id : 34286
# Traitement du game_id : 34287
# Traitement du game_id : 34288
# Traitement du game_id : 34289
# Traitement du game_id : 34310
# Traitement du game_id : 34311
# Traitement du game_id : 34312
# Traitement du game_id : 34313
# Traitement du game_id : 34314
# Traitement du game_id : 34315
# Traitement du game_id : 34316
# Traitement du game_id : 34317
# Traitement du game_id : 34318
# Traitement du game_id : 34319
# Traitement du game_id : 34330
# Traitement du game_id : 34342
# Traitement du game_id : 34343
# Traitement du game_id : 34344
# Traitement du game_id : 34345
# Traitement du game_id : 34346
# Traitement du game_id : 34347
# Traitement du game_id : 34348
# Traitement du game_id : 34350
# Traitement du game_id : 34390
# Traitement du game_id : 34400
# Traitement du game_id : 34410
# Traitement du game_id : 34420
# Traitement du game_id : 34440
# Traitement du game_id : 34450
# Traitement du game_id : 34460
# Traitement du game_id : 34470
# Traitement du game_id : 34490
# Traitement du game_id : 34491
# Traitement du game_id : 34492
# Traitement du game_id : 34493
# Traitement du game_id : 34494
# Traitement du game_id : 34495
# Traitement du game_id : 34496
# Traitement du game_id : 34497
# Traitement du game_id : 34498
# Traitement du game_id : 34500
# Traitement du game_id : 34510
# Traitement du game_id : 34600
# Traitement du game_id : 34609
# Traitement du game_id : 34610
# Traitement du game_id : 34611
# Traitement du game_id : 34612
# Traitement du game_id : 34613
# Traitement du game_id : 34614
# Traitement du game_id : 34615
# Traitement du game_id : 34616
# Traitement du game_id : 34620
# Traitement du game_id : 34630
# Traitement du game_id : 34640
# Traitement du game_id : 34650
# Traitement du game_id : 34660
# Traitement du game_id : 34670
# Traitement du game_id : 34680
# Traitement du game_id : 34800
# Traitement du game_id : 34810
# Traitement du game_id : 34820
# Traitement du game_id : 34830
# Traitement du game_id : 34841
# Traitement du game_id : 34842
# Traitement du game_id : 34850
# Traitement du game_id : 34860
# Traitement du game_id : 34870
# Traitement du game_id : 34880
# Traitement du game_id : 34900
# Traitement du game_id : 34910
# Traitement du game_id : 34920
# Traitement du game_id : 34930
# Traitement du game_id : 35000
# Traitement du game_id : 35010
# Traitement du game_id : 35019
# Traitement du game_id : 35020
# Traitement du game_id : 35030
# Traitement du game_id : 35040
# Traitement du game_id : 35050
# Traitement du game_id : 35060
# Traitement du game_id : 35070
# Traitement du game_id : 35080
# Traitement du game_id : 35081
# Traitement du game_id : 35082
# Traitement du game_id : 35083
# Traitement du game_id : 35084
# Traitement du game_id : 35085
# Traitement du game_id : 35086
# Traitement du game_id : 35087
# Traitement du game_id : 35088
# Traitement du game_id : 35089
# Traitement du game_id : 35090
# Traitement du game_id : 35091
# Traitement du game_id : 35092
# Traitement du game_id : 35093
# Traitement du game_id : 35094
# Traitement du game_id : 35095
# Traitement du game_id : 35096
# Traitement du game_id : 35097
# Traitement du game_id : 35098
# Traitement du game_id : 35099
# Traitement du game_id : 35100
# Traitement du game_id : 35101
# Traitement du game_id : 35102
# Traitement du game_id : 35103
# Traitement du game_id : 35110
# Traitement du game_id : 35130
# Traitement du game_id : 35134
# Traitement du game_id : 35135
# Traitement du game_id : 35136
# Traitement du game_id : 35137
# Traitement du game_id : 38210
# Traitement du game_id : 38220
# Traitement du game_id : 38229
# Traitement du game_id : 38230
# Traitement du game_id : 38240
# Traitement du game_id : 38400
# Traitement du game_id : 38410
# Traitement du game_id : 38420
# Traitement du game_id : 38430
# Traitement du game_id : 38440
# Traitement du game_id : 38450
# Traitement du game_id : 38460
# Traitement du game_id : 38480
# Traitement du game_id : 38490
# Traitement du game_id : 38530
# Traitement du game_id : 38600
# Traitement du game_id : 38700
# Traitement du game_id : 38710
# Traitement du game_id : 38720
# Traitement du game_id : 38730
# Traitement du game_id : 38740
# Traitement du game_id : 38743
# Traitement du game_id : 38750
# Traitement du game_id : 38800
# Traitement du game_id : 38810
# Traitement du game_id : 38820
# Traitement du game_id : 38830
# Traitement du game_id : 38900
# Traitement du game_id : 38910
# Traitement du game_id : 38920
# Traitement du game_id : 38921
# Traitement du game_id : 38922
# Traitement du game_id : 38923
# Traitement du game_id : 38924
# Traitement du game_id : 38925
# Traitement du game_id : 38926
# Traitement du game_id : 38927
# Traitement du game_id : 39000
# Traitement du game_id : 39100
# Traitement du game_id : 39110
# Traitement du game_id : 39120
# Traitement du game_id : 39122
# Traitement du game_id : 39123
# Traitement du game_id : 39124
# Traitement du game_id : 39125
# Traitement du game_id : 39126
# Traitement du game_id : 39127
# Traitement du game_id : 39128
# Traitement du game_id : 39129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 191
#     188     os.unlink(temp_db.name)
#     190 if __name__ == "__main__":
# --> 191     update_aug_steam_games()
#
# Cell In[11], line 133, in update_aug_steam_games()
#     131 game_id = game_id[0]
#     132 print(f"Traitement du game_id : {game_id}")
# --> 133 game_data = get_game_details(game_id)
#     134 if game_data:
#     135     steam_page_info = get_steam_page_info(game_id)
#
# Cell In[11], line 26, in get_game_details(steam_game_id)
#      24 def get_game_details(steam_game_id):
#      25     url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
# ---> 26     response = requests.get(url)
#      27     if response.status_code == 200:
#      28         data = response.json()
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random
import logging

# Configuration du logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def download_db(url, local_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        logging.info(f"Base de données téléchargée avec succès: {local_path}")
        return True
    except requests.RequestException as e:
        logging.error(f"Échec du téléchargement de la base de données: {e}")
        return False

def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        if data[str(steam_game_id)]['success']:
            logging.info(f"Détails récupérés pour le jeu {steam_game_id}")
            return data[str(steam_game_id)]['data']
        else:
            logging.warning(f"Pas de données pour le jeu {steam_game_id}")
    except requests.RequestException as e:
        logging.error(f"Erreur lors de la récupération des détails pour le jeu {steam_game_id}: {e}")
    except json.JSONDecodeError as e:
        logging.error(f"Erreur de décodage JSON pour le jeu {steam_game_id}: {e}")
    return None

def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        logging.info(f"Informations de la page Steam récupérées pour le jeu {app_id}")
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except requests.RequestException as e:
        logging.error(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
    except Exception as e:
        logging.error(f"Erreur inattendue lors du scraping pour le jeu {app_id}: {e}")
    return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                logging.warning(f"Base de données verrouillée. Nouvelle tentative dans {delay} secondes...")
                time.sleep(delay)
                delay *= 2
            else:
                raise

def ensure_column_exists(cursor, table_name, column_name, column_type):
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        logging.info(f"Colonne '{column_name}' ajoutée à la table {table_name}")

def update_aug_steam_games():
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
        logging.info(f"Dernier game_id traité: {last_processed_id}")
    except FileNotFoundError:
        last_processed_id = 12570
        logging.info(f"Fichier last_processed_game_id.txt non trouvé. Utilisation de la valeur par défaut: {last_processed_id}")

    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            logging.error("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 1000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                logging.info(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                time.sleep(random.uniform(0.5, 1.7))

            conn_aug.commit()
            logging.info("Mise à jour terminée avec succès")
            
        except Exception as e:
            logging.error(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    os.unlink(temp_db.name)
    logging.info("Fichier temporaire supprimé")

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# 2024-08-01 19:10:09,948 - INFO - Dernier game_id traité: 70640
# 2024-08-01 19:10:10,562 - INFO - Base de données téléchargée avec succès: /var/folders/b5/ckj362xj7ng_xqbjrqp077qh0000gn/T/tmpfzxl9_1h.db
# 2024-08-01 19:10:10,565 - INFO - Traitement du game_id : 70650
# 2024-08-01 19:10:10,807 - INFO - Détails récupérés pour le jeu 70650
# 2024-08-01 19:10:11,242 - INFO - Informations de la page Steam récupérées pour le jeu 70650
# 2024-08-01 19:10:12,838 - INFO - Traitement du game_id : 70660
# 2024-08-01 19:10:13,090 - INFO - Détails récupérés pour le jeu 70660
# 2024-08-01 19:10:13,780 - INFO - Informations de la page Steam récupérées pour le jeu 70660
# 2024-08-01 19:10:14,609 - INFO - Traitement du game_id : 70900
# 2024-08-01 19:10:14,840 - INFO - Détails récupérés pour le jeu 70900
# 2024-08-01 19:10:15,676 - INFO - Informations de la page Steam récupérées pour le jeu 70900
# 2024-08-01 19:10:17,096 - INFO - Traitement du game_id : 70910
# 2024-08-01 19:10:17,382 - INFO - Détails récupérés pour le jeu 70910
# 2024-08-01 19:10:17,908 - INFO - Informations de la page Steam récupérées pour le jeu 70910
# 2024-08-01 19:10:18,652 - INFO - Traitement du game_id : 71000
# 2024-08-01 19:10:18,913 - INFO - Détails récupérés pour le jeu 71000
# 2024-08-01 19:10:19,353 - INFO - Informations de la page Steam récupérées pour le jeu 71000
# 2024-08-01 19:10:20,718 - INFO - Traitement du game_id : 71110
# 2024-08-01 19:10:21,149 - INFO - Détails récupérés pour le jeu 71110
# 2024-08-01 19:10:21,854 - INFO - Informations de la page Steam récupérées pour le jeu 71110
# 2024-08-01 19:10:22,488 - INFO - Traitement du game_id : 71111
# 2024-08-01 19:10:22,711 - INFO - Détails récupérés pour le jeu 71111
# 2024-08-01 19:10:23,395 - INFO - Informations de la page Steam récupérées pour le jeu 71111
# 2024-08-01 19:10:24,867 - INFO - Traitement du game_id : 71112
# 2024-08-01 19:10:25,121 - INFO - Détails récupérés pour le jeu 71112
# 2024-08-01 19:10:25,735 - INFO - Informations de la page Steam récupérées pour le jeu 71112
# 2024-08-01 19:10:26,611 - INFO - Traitement du game_id : 71114
# 2024-08-01 19:10:26,918 - INFO - Détails récupérés pour le jeu 71114
# 2024-08-01 19:10:27,695 - INFO - Informations de la page Steam récupérées pour le jeu 71114
# 2024-08-01 19:10:28,844 - INFO - Traitement du game_id : 71115
# 2024-08-01 19:10:29,086 - INFO - Détails récupérés pour le jeu 71115
# 2024-08-01 19:10:29,945 - INFO - Informations de la page Steam récupérées pour le jeu 71115
# 2024-08-01 19:10:30,653 - INFO - Traitement du game_id : 71116
# 2024-08-01 19:10:30,907 - INFO - Détails récupérés pour le jeu 71116
# 2024-08-01 19:10:31,728 - INFO - Informations de la page Steam récupérées pour le jeu 71116
# 2024-08-01 19:10:33,163 - INFO - Traitement du game_id : 71117
# 2024-08-01 19:10:33,560 - INFO - Détails récupérés pour le jeu 71117
# 2024-08-01 19:10:34,341 - INFO - Informations de la page Steam récupérées pour le jeu 71117
# 2024-08-01 19:10:35,244 - INFO - Traitement du game_id : 71118
# 2024-08-01 19:10:35,491 - INFO - Détails récupérés pour le jeu 71118
# 2024-08-01 19:10:36,574 - INFO - Informations de la page Steam récupérées pour le jeu 71118
# 2024-08-01 19:10:37,204 - INFO - Traitement du game_id : 71119
# 2024-08-01 19:10:37,454 - INFO - Détails récupérés pour le jeu 71119
# 2024-08-01 19:10:38,160 - INFO - Informations de la page Steam récupérées pour le jeu 71119
# 2024-08-01 19:10:39,648 - INFO - Traitement du game_id : 71120
# 2024-08-01 19:10:39,870 - INFO - Détails récupérés pour le jeu 71120
# 2024-08-01 19:10:40,476 - INFO - Informations de la page Steam récupérées pour le jeu 71120
# 2024-08-01 19:10:41,499 - INFO - Traitement du game_id : 71160
# 2024-08-01 19:10:41,737 - INFO - Détails récupérés pour le jeu 71160
# 2024-08-01 19:10:42,309 - INFO - Informations de la page Steam récupérées pour le jeu 71160
# 2024-08-01 19:10:43,769 - INFO - Traitement du game_id : 71161
# 2024-08-01 19:10:44,107 - INFO - Détails récupérés pour le jeu 71161
# 2024-08-01 19:10:44,854 - INFO - Informations de la page Steam récupérées pour le jeu 71161
# 2024-08-01 19:10:46,341 - INFO - Traitement du game_id : 71164
# 2024-08-01 19:10:46,687 - INFO - Détails récupérés pour le jeu 71164
# 2024-08-01 19:10:47,234 - INFO - Informations de la page Steam récupérées pour le jeu 71164
# 2024-08-01 19:10:48,227 - INFO - Traitement du game_id : 71165
# 2024-08-01 19:10:48,468 - INFO - Détails récupérés pour le jeu 71165
# 2024-08-01 19:10:49,035 - INFO - Informations de la page Steam récupérées pour le jeu 71165
# 2024-08-01 19:10:50,499 - INFO - Traitement du game_id : 71166
# 2024-08-01 19:13:05,079 - INFO - Traitement du game_id : 73059
# 2024-08-01 19:13:05,270 - WARNING - Pas de données pour le jeu 73059
# 2024-08-01 19:13:06,589 - INFO - Traitement du game_id : 73060
# 2024-08-01 19:13:06,961 - INFO - Détails récupérés pour le jeu 73060
# 2024-08-01 19:13:07,672 - INFO - Informations de la page Steam récupérées pour le jeu 73060
# 2024-08-01 19:13:08,516 - INFO - Traitement du game_id : 73071
# 2024-08-01 19:13:08,740 - INFO - Détails récupérés pour le jeu 73071
# 2024-08-01 19:13:09,178 - INFO - Informations de la page Steam récupérées pour le jeu 73071
# 2024-08-01 19:13:09,706 - INFO - Traitement du game_id : 73088
# 2024-08-01 19:13:09,921 - WARNING - Pas de données pour le jeu 73088
# 2024-08-01 19:13:10,689 - INFO - Traitement du game_id : 73089
# 2024-08-01 19:13:10,890 - WARNING - Pas de données pour le jeu 73089
# 2024-08-01 19:13:11,961 - INFO - Traitement du game_id : 73091
# 2024-08-01 19:13:12,176 - INFO - Détails récupérés pour le jeu 73091
# 2024-08-01 19:13:12,744 - INFO - Informations de la page Steam récupérées pour le jeu 73091
# 2024-08-01 19:13:13,994 - INFO - Traitement du game_id : 73092
# 2024-08-01 19:13:14,237 - INFO - Détails récupérés pour le jeu 73092
# 2024-08-01 19:13:14,647 - INFO - Informations de la page Steam récupérées pour le jeu 73092
# 2024-08-01 19:13:15,476 - INFO - Traitement du game_id : 73093
# 2024-08-01 19:13:15,714 - INFO - Détails récupérés pour le jeu 73093
# 2024-08-01 19:13:16,096 - INFO - Informations de la page Steam récupérées pour le jeu 73093
# 2024-08-01 19:13:17,467 - INFO - Traitement du game_id : 73094
# 2024-08-01 19:13:17,717 - WARNING - Pas de données pour le jeu 73094
# 2024-08-01 19:13:18,802 - INFO - Traitement du game_id : 73095
# 2024-08-01 19:13:19,099 - INFO - Détails récupérés pour le jeu 73095
# 2024-08-01 19:13:19,511 - INFO - Informations de la page Steam récupérées pour le jeu 73095
# 2024-08-01 19:13:20,372 - INFO - Traitement du game_id : 73096
# 2024-08-01 19:13:20,596 - INFO - Détails récupérés pour le jeu 73096
# 2024-08-01 19:13:21,164 - INFO - Informations de la page Steam récupérées pour le jeu 73096
# 2024-08-01 19:13:22,262 - INFO - Traitement du game_id : 73097
# 2024-08-01 19:13:22,493 - INFO - Détails récupérés pour le jeu 73097
# 2024-08-01 19:13:23,060 - INFO - Informations de la page Steam récupérées pour le jeu 73097
# 2024-08-01 19:13:24,366 - INFO - Traitement du game_id : 73098
# 2024-08-01 19:13:24,607 - INFO - Détails récupérés pour le jeu 73098
# 2024-08-01 19:13:25,160 - INFO - Informations de la page Steam récupérées pour le jeu 73098
# 2024-08-01 19:13:26,059 - INFO - Traitement du game_id : 73099
# 2024-08-01 19:13:26,263 - WARNING - Pas de données pour le jeu 73099
# 2024-08-01 19:13:26,855 - INFO - Traitement du game_id : 73108
# 2024-08-01 19:13:27,057 - WARNING - Pas de données pour le jeu 73108
# 2024-08-01 19:13:53,590 - INFO - Traitement du game_id : 73187
# 2024-08-01 19:13:53,985 - INFO - Détails récupérés pour le jeu 73187
# 2024-08-01 19:13:54,451 - INFO - Informations de la page Steam récupérées pour le jeu 73187
# 2024-08-01 19:13:55,996 - INFO - Traitement du game_id : 73188
# 2024-08-01 19:13:56,201 - WARNING - Pas de données pour le jeu 73188
# 2024-08-01 19:13:57,452 - INFO - Traitement du game_id : 73190
# 2024-08-01 19:13:57,720 - INFO - Détails récupérés pour le jeu 73190
# 2024-08-01 19:13:58,385 - INFO - Informations de la page Steam récupérées pour le jeu 73190
# 2024-08-01 19:13:59,603 - INFO - Traitement du game_id : 73192
# 2024-08-01 19:13:59,832 - INFO - Détails récupérés pour le jeu 73192
# 2024-08-01 19:14:00,286 - INFO - Informations de la page Steam récupérées pour le jeu 73192
# 2024-08-01 19:14:01,694 - INFO - Traitement du game_id : 73193
# 2024-08-01 19:14:01,923 - INFO - Détails récupérés pour le jeu 73193
# 2024-08-01 19:14:02,264 - INFO - Informations de la page Steam récupérées pour le jeu 73193
# 2024-08-01 19:14:03,649 - INFO - Traitement du game_id : 73194
# 2024-08-01 19:14:03,935 - INFO - Détails récupérés pour le jeu 73194
# 2024-08-01 19:14:04,259 - INFO - Informations de la page Steam récupérées pour le jeu 73194
# 2024-08-01 19:14:05,737 - INFO - Traitement du game_id : 73195
# 2024-08-01 19:14:05,959 - INFO - Détails récupérés pour le jeu 73195
# 2024-08-01 19:14:06,358 - INFO - Informations de la page Steam récupérées pour le jeu 73195
# 2024-08-01 19:14:07,031 - INFO - Traitement du game_id : 73210
# 2024-08-01 19:14:07,391 - INFO - Détails récupérés pour le jeu 73210
# 2024-08-01 19:14:07,915 - INFO - Informations de la page Steam récupérées pour le jeu 73210
# 2024-08-01 19:14:09,537 - INFO - Traitement du game_id : 73230
# 2024-08-01 19:14:09,784 - INFO - Détails récupérés pour le jeu 73230
# 2024-08-01 19:14:10,498 - INFO - Informations de la page Steam récupérées pour le jeu 73230
# 2024-08-01 19:14:11,393 - INFO - Traitement du game_id : 78000
# 2024-08-01 19:14:11,680 - INFO - Détails récupérés pour le jeu 78000
# 2024-08-01 19:14:12,107 - INFO - Informations de la page Steam récupérées pour le jeu 78000
# 2024-08-01 19:14:12,909 - INFO - Traitement du game_id : 78002
# 2024-08-01 19:14:13,138 - WARNING - Pas de données pour le jeu 78002
# 2024-08-01 19:14:14,508 - INFO - Traitement du game_id : 80000
# 2024-08-01 19:14:14,760 - INFO - Détails récupérés pour le jeu 80000
# 2024-08-01 19:14:15,914 - INFO - Informations de la page Steam récupérées pour le jeu 80000
# 2024-08-01 19:14:17,046 - INFO - Traitement du game_id : 80010
# 2024-08-01 19:14:17,335 - INFO - Détails récupérés pour le jeu 80010
# 2024-08-01 19:14:17,857 - INFO - Informations de la page Steam récupérées pour le jeu 80010
# 2024-08-01 19:14:18,991 - INFO - Traitement du game_id : 80020
# 2024-08-01 19:14:19,197 - WARNING - Pas de données pour le jeu 80020
# 2024-08-01 19:14:19,929 - INFO - Traitement du game_id : 80200
# 2024-08-01 19:14:20,181 - INFO - Détails récupérés pour le jeu 80200
# 2024-08-01 19:14:20,995 - INFO - Informations de la page Steam récupérées pour le jeu 80200
# 2024-08-01 19:14:22,030 - INFO - Traitement du game_id : 80202
# 2024-08-01 19:14:22,266 - INFO - Détails récupérés pour le jeu 80202
# 2024-08-01 19:14:22,653 - INFO - Informations de la page Steam récupérées pour le jeu 80202
# 2024-08-01 19:14:23,714 - INFO - Traitement du game_id : 80204
# 2024-08-01 19:14:24,091 - INFO - Détails récupérés pour le jeu 80204
# 2024-08-01 19:14:24,508 - INFO - Informations de la page Steam récupérées pour le jeu 80204
# 2024-08-01 19:14:25,106 - INFO - Traitement du game_id : 80205
# 2024-08-01 19:14:25,342 - WARNING - Pas de données pour le jeu 80205
# 2024-08-01 19:14:26,203 - INFO - Traitement du game_id : 80206
# 2024-08-01 19:14:26,435 - WARNING - Pas de données pour le jeu 80206
# 2024-08-01 19:14:27,595 - INFO - Traitement du game_id : 80207
# 2024-08-01 19:14:27,900 - INFO - Détails récupérés pour le jeu 80207
# 2024-08-01 19:14:28,431 - INFO - Informations de la page Steam récupérées pour le jeu 80207
# 2024-08-01 19:14:29,088 - INFO - Traitement du game_id : 80222
# 2024-08-01 19:14:29,300 - WARNING - Pas de données pour le jeu 80222
# 2024-08-01 19:14:30,630 - INFO - Traitement du game_id : 80300
# 2024-08-01 19:14:30,864 - INFO - Détails récupérés pour le jeu 80300
# 2024-08-01 19:14:31,523 - INFO - Informations de la page Steam récupérées pour le jeu 80300
# 2024-08-01 19:14:32,805 - INFO - Traitement du game_id : 80310
# 2024-08-01 19:14:33,200 - INFO - Détails récupérés pour le jeu 80310
# 2024-08-01 19:14:33,962 - INFO - Informations de la page Steam récupérées pour le jeu 80310
# 2024-08-01 19:14:34,815 - INFO - Traitement du game_id : 80330
# 2024-08-01 19:14:35,151 - INFO - Détails récupérés pour le jeu 80330
# 2024-08-01 19:14:35,693 - INFO - Informations de la page Steam récupérées pour le jeu 80330
# 2024-08-01 19:14:37,228 - INFO - Traitement du game_id : 80340
# 2024-08-01 19:14:37,471 - INFO - Détails récupérés pour le jeu 80340
# 2024-08-01 19:14:38,021 - INFO - Informations de la page Steam récupérées pour le jeu 80340
# 2024-08-01 19:14:39,645 - INFO - Traitement du game_id : 80350
# 2024-08-01 19:14:39,943 - INFO - Détails récupérés pour le jeu 80350
# 2024-08-01 19:14:40,383 - INFO - Informations de la page Steam récupérées pour le jeu 80350
# 2024-08-01 19:14:41,807 - INFO - Traitement du game_id : 80360
# 2024-08-01 19:14:42,041 - INFO - Détails récupérés pour le jeu 80360
# 2024-08-01 19:14:42,705 - INFO - Informations de la page Steam récupérées pour le jeu 80360
# 2024-08-01 19:14:43,730 - INFO - Traitement du game_id : 80400
# 2024-08-01 19:14:44,003 - WARNING - Pas de données pour le jeu 80400
# 2024-08-01 19:15:12,413 - INFO - Traitement du game_id : 80418
# 2024-08-01 19:15:12,656 - WARNING - Pas de données pour le jeu 80418
# 2024-08-01 19:15:13,835 - INFO - Traitement du game_id : 80419
# 2024-08-01 19:15:14,038 - WARNING - Pas de données pour le jeu 80419
# 2024-08-01 19:15:15,449 - INFO - Traitement du game_id : 80420
# 2024-08-01 19:15:15,666 - INFO - Détails récupérés pour le jeu 80420
# 2024-08-01 19:15:16,256 - INFO - Informations de la page Steam récupérées pour le jeu 80420
# 2024-08-01 19:15:17,883 - INFO - Traitement du game_id : 80421
# 2024-08-01 19:15:18,081 - WARNING - Pas de données pour le jeu 80421
# 2024-08-01 19:15:18,961 - INFO - Traitement du game_id : 80422
# 2024-08-01 19:15:19,174 - INFO - Détails récupérés pour le jeu 80422
# 2024-08-01 19:15:19,865 - INFO - Informations de la page Steam récupérées pour le jeu 80422
# 2024-08-01 19:15:21,277 - INFO - Traitement du game_id : 80423
# 2024-08-01 19:15:21,595 - INFO - Détails récupérés pour le jeu 80423
# 2024-08-01 19:15:22,246 - INFO - Informations de la page Steam récupérées pour le jeu 80423
# 2024-08-01 19:15:23,049 - INFO - Traitement du game_id : 80424
# 2024-08-01 19:15:23,259 - INFO - Détails récupérés pour le jeu 80424
# 2024-08-01 19:15:24,059 - INFO - Informations de la page Steam récupérées pour le jeu 80424
# 2024-08-01 19:15:24,755 - INFO - Traitement du game_id : 80425
# 2024-08-01 19:15:24,987 - INFO - Détails récupérés pour le jeu 80425
# 2024-08-01 19:15:25,821 - INFO - Informations de la page Steam récupérées pour le jeu 80425
# 2024-08-01 19:15:26,679 - INFO - Traitement du game_id : 80426
# 2024-08-01 19:15:27,006 - INFO - Détails récupérés pour le jeu 80426
# 2024-08-01 19:15:27,722 - INFO - Informations de la page Steam récupérées pour le jeu 80426
# 2024-08-01 19:15:28,410 - INFO - Traitement du game_id : 80427
# 2024-08-01 19:15:28,636 - INFO - Détails récupérés pour le jeu 80427
# 2024-08-01 19:15:29,636 - INFO - Informations de la page Steam récupérées pour le jeu 80427
# 2024-08-01 19:15:30,523 - INFO - Traitement du game_id : 80428
# 2024-08-01 19:15:30,737 - WARNING - Pas de données pour le jeu 80428
# 2024-08-01 19:15:32,353 - INFO - Traitement du game_id : 80429
# 2024-08-01 19:15:32,784 - INFO - Détails récupérés pour le jeu 80429
# 2024-08-01 19:15:33,505 - INFO - Informations de la page Steam récupérées pour le jeu 80429
# 2024-08-01 19:15:35,189 - INFO - Traitement du game_id : 80430
# 2024-08-01 19:15:35,438 - INFO - Détails récupérés pour le jeu 80430
# 2024-08-01 19:15:36,314 - INFO - Informations de la page Steam récupérées pour le jeu 80430
# 2024-08-01 19:15:37,544 - INFO - Traitement du game_id : 80431
# 2024-08-01 19:15:37,861 - WARNING - Pas de données pour le jeu 80431
# 2024-08-01 19:15:39,008 - INFO - Traitement du game_id : 80432
# 2024-08-01 19:15:39,232 - INFO - Détails récupérés pour le jeu 80432
# 2024-08-01 19:15:40,021 - INFO - Informations de la page Steam récupérées pour le jeu 80432
# 2024-08-01 19:15:41,047 - INFO - Traitement du game_id : 80433
# 2024-08-01 19:15:41,280 - INFO - Détails récupérés pour le jeu 80433
# 2024-08-01 19:15:42,250 - INFO - Informations de la page Steam récupérées pour le jeu 80433
# 2024-08-01 19:15:43,891 - INFO - Traitement du game_id : 80434
# 2024-08-01 19:15:44,134 - WARNING - Pas de données pour le jeu 80434
# 2024-08-01 19:15:44,666 - INFO - Traitement du game_id : 80435
# 2024-08-01 19:15:44,894 - INFO - Détails récupérés pour le jeu 80435
# 2024-08-01 19:15:45,699 - INFO - Informations de la page Steam récupérées pour le jeu 80435
# 2024-08-01 19:15:46,539 - INFO - Traitement du game_id : 80436
# 2024-08-01 19:15:46,764 - INFO - Détails récupérés pour le jeu 80436
# 2024-08-01 19:15:47,490 - INFO - Informations de la page Steam récupérées pour le jeu 80436
# 2024-08-01 19:15:48,924 - INFO - Traitement du game_id : 80437
# 2024-08-01 19:15:49,153 - INFO - Détails récupérés pour le jeu 80437
# 2024-08-01 19:15:50,125 - INFO - Informations de la page Steam récupérées pour le jeu 80437
# 2024-08-01 19:15:51,247 - INFO - Traitement du game_id : 80438
# 2024-08-01 19:15:51,590 - INFO - Détails récupérés pour le jeu 80438
# 2024-08-01 19:15:52,168 - INFO - Informations de la page Steam récupérées pour le jeu 80438
# 2024-08-01 19:15:53,025 - INFO - Traitement du game_id : 80439
# 2024-08-01 19:15:53,426 - INFO - Détails récupérés pour le jeu 80439
# 2024-08-01 19:15:54,106 - INFO - Informations de la page Steam récupérées pour le jeu 80439
# 2024-08-01 19:15:54,885 - INFO - Traitement du game_id : 80440
# 2024-08-01 19:15:55,097 - WARNING - Pas de données pour le jeu 80440
# 2024-08-01 19:15:56,030 - INFO - Traitement du game_id : 80441
# 2024-08-01 19:15:56,230 - WARNING - Pas de données pour le jeu 80441
# 2024-08-01 19:15:57,543 - INFO - Traitement du game_id : 80442
# 2024-08-01 19:15:57,808 - INFO - Détails récupérés pour le jeu 80442
# 2024-08-01 19:15:58,428 - INFO - Informations de la page Steam récupérées pour le jeu 80442
# 2024-08-01 19:15:59,015 - INFO - Traitement du game_id : 80443
# 2024-08-01 19:15:59,297 - INFO - Détails récupérés pour le jeu 80443
# 2024-08-01 19:16:00,055 - INFO - Informations de la page Steam récupérées pour le jeu 80443
# 2024-08-01 19:16:01,135 - INFO - Traitement du game_id : 80444
# 2024-08-01 19:16:01,377 - INFO - Détails récupérés pour le jeu 80444
# 2024-08-01 19:16:02,128 - INFO - Informations de la page Steam récupérées pour le jeu 80444
# 2024-08-01 19:16:02,842 - INFO - Traitement du game_id : 80445
# 2024-08-01 19:16:03,107 - INFO - Détails récupérés pour le jeu 80445
# 2024-08-01 19:16:04,101 - INFO - Informations de la page Steam récupérées pour le jeu 80445
# 2024-08-01 19:16:05,447 - INFO - Traitement du game_id : 80446
# 2024-08-01 19:16:05,960 - INFO - Détails récupérés pour le jeu 80446
# 2024-08-01 19:16:06,812 - INFO - Informations de la page Steam récupérées pour le jeu 80446
# 2024-08-01 19:16:08,152 - INFO - Traitement du game_id : 80447
# 2024-08-01 19:16:08,419 - INFO - Détails récupérés pour le jeu 80447
# 2024-08-01 19:16:09,199 - INFO - Informations de la page Steam récupérées pour le jeu 80447
# 2024-08-01 19:16:10,261 - INFO - Traitement du game_id : 80448
# 2024-08-01 19:16:10,500 - INFO - Détails récupérés pour le jeu 80448
# 2024-08-01 19:16:11,144 - INFO - Informations de la page Steam récupérées pour le jeu 80448
# 2024-08-01 19:16:12,730 - INFO - Traitement du game_id : 80449
# 2024-08-01 19:16:12,966 - INFO - Détails récupérés pour le jeu 80449
# 2024-08-01 19:16:13,692 - INFO - Informations de la page Steam récupérées pour le jeu 80449
# 2024-08-01 19:16:14,862 - INFO - Traitement du game_id : 80450
# 2024-08-01 19:16:15,157 - INFO - Détails récupérés pour le jeu 80450
# 2024-08-01 19:16:16,096 - INFO - Informations de la page Steam récupérées pour le jeu 80450
# 2024-08-01 19:16:17,407 - INFO - Traitement du game_id : 80451
# 2024-08-01 19:16:17,757 - WARNING - Pas de données pour le jeu 80451
# 2024-08-01 19:16:18,545 - INFO - Traitement du game_id : 80452
# 2024-08-01 19:16:18,756 - WARNING - Pas de données pour le jeu 80452
# 2024-08-01 19:16:20,230 - INFO - Traitement du game_id : 80453
# 2024-08-01 19:16:20,494 - WARNING - Pas de données pour le jeu 80453
# 2024-08-01 19:16:21,916 - INFO - Traitement du game_id : 80454
# 2024-08-01 19:16:22,160 - WARNING - Pas de données pour le jeu 80454
# 2024-08-01 19:16:23,576 - INFO - Traitement du game_id : 80455
# 2024-08-01 19:16:23,810 - INFO - Détails récupérés pour le jeu 80455
# 2024-08-01 19:16:24,576 - INFO - Informations de la page Steam récupérées pour le jeu 80455
# 2024-08-01 19:16:25,505 - INFO - Traitement du game_id : 80456
# 2024-08-01 19:16:25,705 - WARNING - Pas de données pour le jeu 80456
# 2024-08-01 19:16:26,629 - INFO - Traitement du game_id : 80457
# 2024-08-01 19:16:26,858 - INFO - Détails récupérés pour le jeu 80457
# 2024-08-01 19:16:27,498 - INFO - Informations de la page Steam récupérées pour le jeu 80457
# 2024-08-01 19:16:28,264 - INFO - Traitement du game_id : 80458
# 2024-08-01 19:16:28,570 - INFO - Détails récupérés pour le jeu 80458
# 2024-08-01 19:16:29,698 - INFO - Informations de la page Steam récupérées pour le jeu 80458
# 2024-08-01 19:16:30,739 - INFO - Traitement du game_id : 80459
# 2024-08-01 19:16:30,972 - WARNING - Pas de données pour le jeu 80459
# 2024-08-01 19:16:31,555 - INFO - Traitement du game_id : 80460
# 2024-08-01 19:16:31,812 - INFO - Détails récupérés pour le jeu 80460
# 2024-08-01 19:16:32,433 - INFO - Informations de la page Steam récupérées pour le jeu 80460
# 2024-08-01 19:16:34,046 - INFO - Traitement du game_id : 80461
# 2024-08-01 19:16:34,345 - INFO - Détails récupérés pour le jeu 80461
# 2024-08-01 19:16:34,940 - INFO - Informations de la page Steam récupérées pour le jeu 80461
# 2024-08-01 19:16:35,661 - INFO - Traitement du game_id : 80462
# 2024-08-01 19:16:35,876 - INFO - Détails récupérés pour le jeu 80462
# 2024-08-01 19:16:36,561 - INFO - Informations de la page Steam récupérées pour le jeu 80462
# 2024-08-01 19:16:37,928 - INFO - Traitement du game_id : 80463
# 2024-08-01 19:16:38,249 - INFO - Détails récupérés pour le jeu 80463
# 2024-08-01 19:16:39,233 - INFO - Informations de la page Steam récupérées pour le jeu 80463
# 2024-08-01 19:16:40,872 - INFO - Traitement du game_id : 80464
# 2024-08-01 19:16:41,144 - INFO - Détails récupérés pour le jeu 80464
# 2024-08-01 19:16:41,874 - INFO - Informations de la page Steam récupérées pour le jeu 80464
# 2024-08-01 19:16:42,775 - INFO - Traitement du game_id : 80465
# 2024-08-01 19:16:42,996 - INFO - Détails récupérés pour le jeu 80465
# 2024-08-01 19:16:43,926 - INFO - Informations de la page Steam récupérées pour le jeu 80465
# 2024-08-01 19:16:45,204 - INFO - Traitement du game_id : 80466
# 2024-08-01 19:16:45,449 - INFO - Détails récupérés pour le jeu 80466
# 2024-08-01 19:16:46,356 - INFO - Informations de la page Steam récupérées pour le jeu 80466
# 2024-08-01 19:16:47,382 - INFO - Traitement du game_id : 80467
# 2024-08-01 19:16:47,608 - INFO - Détails récupérés pour le jeu 80467
# 2024-08-01 19:16:48,229 - INFO - Informations de la page Steam récupérées pour le jeu 80467
# 2024-08-01 19:16:49,328 - INFO - Traitement du game_id : 80468
# 2024-08-01 19:16:49,531 - WARNING - Pas de données pour le jeu 80468
# 2024-08-01 19:16:50,295 - INFO - Traitement du game_id : 80469
# 2024-08-01 19:16:50,538 - INFO - Détails récupérés pour le jeu 80469
# 2024-08-01 19:16:51,281 - INFO - Informations de la page Steam récupérées pour le jeu 80469
# 2024-08-01 19:16:52,797 - INFO - Traitement du game_id : 80470
# 2024-08-01 19:16:53,156 - INFO - Détails récupérés pour le jeu 80470
# 2024-08-01 19:16:53,770 - INFO - Informations de la page Steam récupérées pour le jeu 80470
# 2024-08-01 19:16:54,423 - INFO - Traitement du game_id : 80471
# 2024-08-01 19:16:54,621 - WARNING - Pas de données pour le jeu 80471
# 2024-08-01 19:16:55,210 - INFO - Traitement du game_id : 80472
# 2024-08-01 19:16:55,412 - WARNING - Pas de données pour le jeu 80472
# 2024-08-01 19:16:56,253 - INFO - Traitement du game_id : 80473
# 2024-08-01 19:16:56,492 - INFO - Détails récupérés pour le jeu 80473
# 2024-08-01 19:16:57,164 - INFO - Informations de la page Steam récupérées pour le jeu 80473
# 2024-08-01 19:16:58,850 - INFO - Traitement du game_id : 80474
# 2024-08-01 19:16:59,086 - WARNING - Pas de données pour le jeu 80474
# 2024-08-01 19:17:00,442 - INFO - Traitement du game_id : 80475
# 2024-08-01 19:17:00,683 - WARNING - Pas de données pour le jeu 80475
# 2024-08-01 19:17:01,778 - INFO - Traitement du game_id : 80476
# 2024-08-01 19:17:02,066 - INFO - Détails récupérés pour le jeu 80476
# 2024-08-01 19:17:03,065 - INFO - Informations de la page Steam récupérées pour le jeu 80476
# 2024-08-01 19:17:04,466 - INFO - Traitement du game_id : 80477
# 2024-08-01 19:17:04,685 - INFO - Détails récupérés pour le jeu 80477
# 2024-08-01 19:17:05,386 - INFO - Informations de la page Steam récupérées pour le jeu 80477
# 2024-08-01 19:17:06,498 - INFO - Traitement du game_id : 80478
# 2024-08-01 19:17:06,771 - WARNING - Pas de données pour le jeu 80478
# 2024-08-01 19:17:07,828 - INFO - Traitement du game_id : 80485
# 2024-08-01 19:17:08,032 - WARNING - Pas de données pour le jeu 80485
# 2024-08-01 19:17:08,797 - INFO - Traitement du game_id : 80486
# 2024-08-01 19:17:09,247 - INFO - Détails récupérés pour le jeu 80486
# 2024-08-01 19:17:09,936 - INFO - Informations de la page Steam récupérées pour le jeu 80486
# 2024-08-01 19:17:10,637 - INFO - Traitement du game_id : 80487
# 2024-08-01 19:17:10,934 - INFO - Détails récupérés pour le jeu 80487
# 2024-08-01 19:17:11,596 - INFO - Informations de la page Steam récupérées pour le jeu 80487
# 2024-08-01 19:17:12,554 - INFO - Traitement du game_id : 80488
# 2024-08-01 19:17:12,803 - INFO - Détails récupérés pour le jeu 80488
# 2024-08-01 19:17:13,517 - INFO - Informations de la page Steam récupérées pour le jeu 80488
# 2024-08-01 19:17:15,113 - INFO - Traitement du game_id : 80489
# 2024-08-01 19:17:15,372 - INFO - Détails récupérés pour le jeu 80489
# 2024-08-01 19:17:16,111 - INFO - Informations de la page Steam récupérées pour le jeu 80489
# 2024-08-01 19:17:17,133 - INFO - Traitement du game_id : 80490
# 2024-08-01 19:17:17,415 - INFO - Détails récupérés pour le jeu 80490
# 2024-08-01 19:17:18,318 - INFO - Informations de la page Steam récupérées pour le jeu 80490
# 2024-08-01 19:17:19,200 - INFO - Traitement du game_id : 80491
# 2024-08-01 19:17:19,401 - WARNING - Pas de données pour le jeu 80491
# 2024-08-01 19:17:20,580 - INFO - Traitement du game_id : 80492
# 2024-08-01 19:17:20,793 - INFO - Détails récupérés pour le jeu 80492
# 2024-08-01 19:17:21,541 - INFO - Informations de la page Steam récupérées pour le jeu 80492
# 2024-08-01 19:17:22,467 - INFO - Traitement du game_id : 80493
# 2024-08-01 19:17:22,695 - INFO - Détails récupérés pour le jeu 80493
# 2024-08-01 19:17:23,326 - INFO - Informations de la page Steam récupérées pour le jeu 80493
# 2024-08-01 19:17:24,458 - INFO - Traitement du game_id : 80494
# 2024-08-01 19:17:24,853 - INFO - Détails récupérés pour le jeu 80494
# 2024-08-01 19:17:25,480 - INFO - Informations de la page Steam récupérées pour le jeu 80494
# 2024-08-01 19:17:26,586 - INFO - Traitement du game_id : 80495
# 2024-08-01 19:17:26,802 - INFO - Détails récupérés pour le jeu 80495
# 2024-08-01 19:17:27,539 - INFO - Informations de la page Steam récupérées pour le jeu 80495
# 2024-08-01 19:17:28,482 - INFO - Traitement du game_id : 80496
# 2024-08-01 19:17:28,857 - INFO - Détails récupérés pour le jeu 80496
# 2024-08-01 19:17:29,573 - INFO - Informations de la page Steam récupérées pour le jeu 80496
# 2024-08-01 19:17:31,036 - INFO - Traitement du game_id : 80497
# 2024-08-01 19:17:31,510 - INFO - Détails récupérés pour le jeu 80497
# 2024-08-01 19:17:32,383 - INFO - Informations de la page Steam récupérées pour le jeu 80497
# 2024-08-01 19:17:33,455 - INFO - Traitement du game_id : 80498
# 2024-08-01 19:17:33,701 - INFO - Détails récupérés pour le jeu 80498
# 2024-08-01 19:17:34,494 - INFO - Informations de la page Steam récupérées pour le jeu 80498
# 2024-08-01 19:17:35,043 - INFO - Traitement du game_id : 80500
# 2024-08-01 19:17:35,261 - INFO - Détails récupérés pour le jeu 80500
# 2024-08-01 19:17:35,913 - INFO - Informations de la page Steam récupérées pour le jeu 80500
# 2024-08-01 19:17:37,216 - INFO - Traitement du game_id : 80501
# 2024-08-01 19:17:37,452 - INFO - Détails récupérés pour le jeu 80501
# 2024-08-01 19:17:38,113 - INFO - Informations de la page Steam récupérées pour le jeu 80501
# ...
# 2024-08-01 19:37:55,720 - WARNING - Pas de données pour le jeu 81206
# 2024-08-01 19:37:56,459 - INFO - Traitement du game_id : 81207
# 2024-08-01 19:37:56,676 - INFO - Détails récupérés pour le jeu 81207
# 2024-08-01 19:37:57,342 - INFO - Informations de la page Steam récupérées pour le jeu 81207
# 2024-08-01 19:37:58,167 - INFO - Traitement du game_id : 81208
# 2024-08-01 19:37:58,376 - WARNING - Pas de données pour le jeu 81208
# 2024-08-01 19:37:58,913 - INFO - Traitement du game_id : 81209
# 2024-08-01 19:37:59,119 - WARNING - Pas de données pour le jeu 81209
# 2024-08-01 19:38:00,704 - INFO - Traitement du game_id : 81210
# 2024-08-01 19:38:00,910 - INFO - Détails récupérés pour le jeu 81210
# 2024-08-01 19:38:01,511 - INFO - Informations de la page Steam récupérées pour le jeu 81210
# 2024-08-01 19:38:02,018 - INFO - Traitement du game_id : 81211
# 2024-08-01 19:38:02,242 - INFO - Détails récupérés pour le jeu 81211
# 2024-08-01 19:38:02,791 - INFO - Informations de la page Steam récupérées pour le jeu 81211
# 2024-08-01 19:38:03,912 - INFO - Traitement du game_id : 81212
# 2024-08-01 19:38:04,151 - INFO - Détails récupérés pour le jeu 81212
# 2024-08-01 19:38:04,893 - INFO - Informations de la page Steam récupérées pour le jeu 81212
# 2024-08-01 19:38:06,181 - INFO - Traitement du game_id : 81213
# 2024-08-01 19:38:06,405 - INFO - Détails récupérés pour le jeu 81213
# 2024-08-01 19:38:07,279 - INFO - Informations de la page Steam récupérées pour le jeu 81213
# 2024-08-01 19:38:08,522 - INFO - Traitement du game_id : 81214
# 2024-08-01 19:38:08,861 - INFO - Détails récupérés pour le jeu 81214
# 2024-08-01 19:38:09,524 - INFO - Informations de la page Steam récupérées pour le jeu 81214
# 2024-08-01 19:38:10,144 - INFO - Traitement du game_id : 81215
# 2024-08-01 19:38:10,376 - INFO - Détails récupérés pour le jeu 81215
# 2024-08-01 19:38:11,065 - INFO - Informations de la page Steam récupérées pour le jeu 81215
# 2024-08-01 19:38:11,851 - INFO - Traitement du game_id : 81216
# 2024-08-01 19:38:12,076 - INFO - Détails récupérés pour le jeu 81216
# 2024-08-01 19:38:12,861 - INFO - Informations de la page Steam récupérées pour le jeu 81216
# 2024-08-01 19:38:14,532 - INFO - Traitement du game_id : 81217
# 2024-08-01 19:38:14,747 - INFO - Détails récupérés pour le jeu 81217
# 2024-08-01 19:38:15,938 - INFO - Informations de la page Steam récupérées pour le jeu 81217
# 2024-08-01 19:38:16,880 - INFO - Traitement du game_id : 81218
# 2024-08-01 19:38:17,104 - WARNING - Pas de données pour le jeu 81218
# 2024-08-01 19:38:18,376 - INFO - Traitement du game_id : 81219
# 2024-08-01 19:38:18,575 - WARNING - Pas de données pour le jeu 81219
# 2024-08-01 19:38:20,265 - INFO - Traitement du game_id : 81220
# 2024-08-01 19:38:20,483 - INFO - Détails récupérés pour le jeu 81220
# 2024-08-01 19:38:21,176 - INFO - Informations de la page Steam récupérées pour le jeu 81220
# 2024-08-01 19:38:22,551 - INFO - Traitement du game_id : 81221
# 2024-08-01 19:38:22,791 - INFO - Détails récupérés pour le jeu 81221
# 2024-08-01 19:38:23,382 - INFO - Informations de la page Steam récupérées pour le jeu 81221
# 2024-08-01 19:38:24,077 - INFO - Traitement du game_id : 81222
# 2024-08-01 19:38:24,338 - INFO - Détails récupérés pour le jeu 81222
# 2024-08-01 19:38:25,155 - INFO - Informations de la page Steam récupérées pour le jeu 81222
# 2024-08-01 19:38:26,399 - INFO - Traitement du game_id : 81223
# 2024-08-01 19:38:26,632 - INFO - Détails récupérés pour le jeu 81223
# 2024-08-01 19:38:27,314 - INFO - Informations de la page Steam récupérées pour le jeu 81223
# 2024-08-01 19:38:28,081 - INFO - Traitement du game_id : 81224
# 2024-08-01 19:38:28,299 - INFO - Détails récupérés pour le jeu 81224
# 2024-08-01 19:38:28,985 - INFO - Informations de la page Steam récupérées pour le jeu 81224
# 2024-08-01 19:38:29,627 - INFO - Traitement du game_id : 81225
# 2024-08-01 19:38:29,893 - INFO - Détails récupérés pour le jeu 81225
# 2024-08-01 19:38:30,762 - INFO - Informations de la page Steam récupérées pour le jeu 81225
# 2024-08-01 19:38:32,376 - INFO - Traitement du game_id : 81226
# 2024-08-01 19:38:32,604 - INFO - Détails récupérés pour le jeu 81226
# 2024-08-01 19:38:33,557 - INFO - Informations de la page Steam récupérées pour le jeu 81226
# 2024-08-01 19:38:34,596 - INFO - Traitement du game_id : 81227
# 2024-08-01 19:38:34,824 - INFO - Détails récupérés pour le jeu 81227
# 2024-08-01 19:38:35,656 - INFO - Informations de la page Steam récupérées pour le jeu 81227
# 2024-08-01 19:38:36,876 - INFO - Traitement du game_id : 81228
# 2024-08-01 19:38:37,103 - WARNING - Pas de données pour le jeu 81228
# 2024-08-01 19:38:38,154 - INFO - Traitement du game_id : 81229
# 2024-08-01 19:38:38,433 - WARNING - Pas de données pour le jeu 81229
# 2024-08-01 19:38:39,414 - INFO - Traitement du game_id : 81230
# 2024-08-01 19:38:39,640 - INFO - Détails récupérés pour le jeu 81230
# 2024-08-01 19:38:40,622 - INFO - Informations de la page Steam récupérées pour le jeu 81230
# 2024-08-01 19:38:42,010 - INFO - Traitement du game_id : 81231
# 2024-08-01 19:38:42,244 - INFO - Détails récupérés pour le jeu 81231
# 2024-08-01 19:38:43,177 - INFO - Informations de la page Steam récupérées pour le jeu 81231
# 2024-08-01 19:38:44,734 - INFO - Traitement du game_id : 81232
# 2024-08-01 19:38:44,998 - INFO - Détails récupérés pour le jeu 81232
# 2024-08-01 19:38:45,683 - INFO - Informations de la page Steam récupérées pour le jeu 81232
# 2024-08-01 19:38:46,476 - INFO - Traitement du game_id : 81233
# 2024-08-01 19:38:46,715 - INFO - Détails récupérés pour le jeu 81233
# 2024-08-01 19:38:47,375 - INFO - Informations de la page Steam récupérées pour le jeu 81233
# 2024-08-01 19:38:47,993 - INFO - Traitement du game_id : 81234
# 2024-08-01 19:38:48,223 - INFO - Détails récupérés pour le jeu 81234
# 2024-08-01 19:38:48,898 - INFO - Informations de la page Steam récupérées pour le jeu 81234
# 2024-08-01 19:38:50,498 - INFO - Traitement du game_id : 81235
# 2024-08-01 19:38:50,760 - INFO - Détails récupérés pour le jeu 81235
# 2024-08-01 19:38:51,536 - INFO - Informations de la page Steam récupérées pour le jeu 81235
# 2024-08-01 19:38:52,907 - INFO - Traitement du game_id : 81236
# 2024-08-01 19:38:53,129 - WARNING - Pas de données pour le jeu 81236
# 2024-08-01 19:38:54,071 - INFO - Traitement du game_id : 81237
# 2024-08-01 19:38:54,286 - INFO - Détails récupérés pour le jeu 81237
# 2024-08-01 19:38:54,953 - INFO - Informations de la page Steam récupérées pour le jeu 81237
# 2024-08-01 19:38:56,046 - INFO - Traitement du game_id : 81238
# 2024-08-01 19:38:56,245 - WARNING - Pas de données pour le jeu 81238
# 2024-08-01 19:38:57,692 - INFO - Traitement du game_id : 81239
# 2024-08-01 19:38:57,946 - INFO - Détails récupérés pour le jeu 81239
# 2024-08-01 19:38:58,886 - INFO - Informations de la page Steam récupérées pour le jeu 81239
# 2024-08-01 19:38:59,509 - INFO - Traitement du game_id : 81240
# 2024-08-01 19:38:59,707 - WARNING - Pas de données pour le jeu 81240
# 2024-08-01 19:39:00,564 - INFO - Traitement du game_id : 81241
# 2024-08-01 19:39:00,824 - INFO - Détails récupérés pour le jeu 81241
# 2024-08-01 19:39:01,607 - INFO - Informations de la page Steam récupérées pour le jeu 81241
# 2024-08-01 19:39:02,774 - INFO - Traitement du game_id : 81242
# 2024-08-01 19:39:03,017 - INFO - Détails récupérés pour le jeu 81242
# 2024-08-01 19:39:03,780 - INFO - Informations de la page Steam récupérées pour le jeu 81242
# 2024-08-01 19:39:05,381 - INFO - Traitement du game_id : 81243
# 2024-08-01 19:39:05,601 - INFO - Détails récupérés pour le jeu 81243
# 2024-08-01 19:39:06,265 - INFO - Informations de la page Steam récupérées pour le jeu 81243
# 2024-08-01 19:39:07,508 - INFO - Traitement du game_id : 81244
# 2024-08-01 19:39:07,874 - WARNING - Pas de données pour le jeu 81244
# 2024-08-01 19:39:08,929 - INFO - Traitement du game_id : 81245
# 2024-08-01 19:39:09,163 - INFO - Détails récupérés pour le jeu 81245
# 2024-08-01 19:39:09,779 - INFO - Informations de la page Steam récupérées pour le jeu 81245
# 2024-08-01 19:39:10,850 - INFO - Traitement du game_id : 81246
# 2024-08-01 19:39:11,161 - WARNING - Pas de données pour le jeu 81246
# 2024-08-01 19:39:12,811 - INFO - Traitement du game_id : 81247
# 2024-08-01 19:39:13,015 - WARNING - Pas de données pour le jeu 81247
# 2024-08-01 19:39:13,596 - INFO - Traitement du game_id : 81248
# 2024-08-01 19:39:13,930 - WARNING - Pas de données pour le jeu 81248
# 2024-08-01 19:39:15,558 - INFO - Traitement du game_id : 81249
# 2024-08-01 19:39:15,761 - WARNING - Pas de données pour le jeu 81249
# 2024-08-01 19:39:16,439 - INFO - Traitement du game_id : 81250
# 2024-08-01 19:39:16,755 - INFO - Détails récupérés pour le jeu 81250
# 2024-08-01 19:39:17,443 - INFO - Informations de la page Steam récupérées pour le jeu 81250
# 2024-08-01 19:39:18,443 - INFO - Traitement du game_id : 81251
# 2024-08-01 19:39:18,804 - INFO - Détails récupérés pour le jeu 81251
# 2024-08-01 19:39:19,503 - INFO - Informations de la page Steam récupérées pour le jeu 81251
# 2024-08-01 19:39:20,260 - INFO - Traitement du game_id : 81252
# 2024-08-01 19:39:20,559 - INFO - Détails récupérés pour le jeu 81252
# 2024-08-01 19:39:21,334 - INFO - Informations de la page Steam récupérées pour le jeu 81252
# 2024-08-01 19:39:22,558 - INFO - Traitement du game_id : 81253
# 2024-08-01 19:39:22,779 - WARNING - Pas de données pour le jeu 81253
# 2024-08-01 19:39:24,322 - INFO - Traitement du game_id : 81254
# 2024-08-01 19:39:24,556 - INFO - Détails récupérés pour le jeu 81254
# 2024-08-01 19:39:25,266 - INFO - Informations de la page Steam récupérées pour le jeu 81254
# 2024-08-01 19:39:26,440 - INFO - Traitement du game_id : 81255
# 2024-08-01 19:39:26,666 - INFO - Détails récupérés pour le jeu 81255
# 2024-08-01 19:39:27,389 - INFO - Informations de la page Steam récupérées pour le jeu 81255
# 2024-08-01 19:39:28,014 - INFO - Traitement du game_id : 81256
# 2024-08-01 19:39:28,247 - INFO - Détails récupérés pour le jeu 81256
# 2024-08-01 19:39:28,929 - INFO - Informations de la page Steam récupérées pour le jeu 81256
# 2024-08-01 19:39:29,479 - INFO - Traitement du game_id : 81257
# 2024-08-01 19:39:29,702 - INFO - Détails récupérés pour le jeu 81257
# 2024-08-01 19:39:30,497 - INFO - Informations de la page Steam récupérées pour le jeu 81257
# 2024-08-01 19:39:31,367 - INFO - Traitement du game_id : 81258
# 2024-08-01 19:39:31,735 - INFO - Détails récupérés pour le jeu 81258
# 2024-08-01 19:39:32,446 - INFO - Informations de la page Steam récupérées pour le jeu 81258
# 2024-08-01 19:39:33,145 - INFO - Traitement du game_id : 81259
# 2024-08-01 19:39:33,364 - INFO - Détails récupérés pour le jeu 81259
# 2024-08-01 19:39:34,248 - INFO - Informations de la page Steam récupérées pour le jeu 81259
# 2024-08-01 19:39:35,854 - INFO - Traitement du game_id : 81260
# 2024-08-01 19:39:36,069 - INFO - Détails récupérés pour le jeu 81260
# 2024-08-01 19:39:36,831 - INFO - Informations de la page Steam récupérées pour le jeu 81260
# 2024-08-01 19:39:37,980 - INFO - Traitement du game_id : 81261
# 2024-08-01 19:39:38,183 - WARNING - Pas de données pour le jeu 81261
# 2024-08-01 19:39:39,890 - INFO - Traitement du game_id : 81262
# 2024-08-01 19:39:40,105 - WARNING - Pas de données pour le jeu 81262
# 2024-08-01 19:39:41,140 - INFO - Traitement du game_id : 81263
# 2024-08-01 19:39:41,351 - INFO - Détails récupérés pour le jeu 81263
# 2024-08-01 19:39:42,106 - INFO - Informations de la page Steam récupérées pour le jeu 81263
# 2024-08-01 19:39:43,706 - INFO - Traitement du game_id : 81264
# 2024-08-01 19:39:43,926 - WARNING - Pas de données pour le jeu 81264
# 2024-08-01 19:39:45,356 - INFO - Traitement du game_id : 81265
# 2024-08-01 19:39:45,616 - INFO - Détails récupérés pour le jeu 81265
# 2024-08-01 19:39:46,489 - INFO - Informations de la page Steam récupérées pour le jeu 81265
# 2024-08-01 19:39:48,082 - INFO - Traitement du game_id : 81266
# 2024-08-01 19:39:48,298 - INFO - Détails récupérés pour le jeu 81266
# 2024-08-01 19:39:48,939 - INFO - Informations de la page Steam récupérées pour le jeu 81266
# 2024-08-01 19:39:49,692 - INFO - Traitement du game_id : 81267
# 2024-08-01 19:39:50,044 - INFO - Détails récupérés pour le jeu 81267
# 2024-08-01 19:39:50,802 - INFO - Informations de la page Steam récupérées pour le jeu 81267
# 2024-08-01 19:39:51,616 - INFO - Traitement du game_id : 81268
# 2024-08-01 19:39:51,846 - INFO - Détails récupérés pour le jeu 81268
# 2024-08-01 19:39:52,553 - INFO - Informations de la page Steam récupérées pour le jeu 81268
# 2024-08-01 19:39:54,109 - INFO - Traitement du game_id : 81269
# 2024-08-01 19:39:54,319 - INFO - Détails récupérés pour le jeu 81269
# 2024-08-01 19:39:54,962 - INFO - Informations de la page Steam récupérées pour le jeu 81269
# 2024-08-01 19:39:56,528 - INFO - Traitement du game_id : 81270
# 2024-08-01 19:39:56,866 - INFO - Détails récupérés pour le jeu 81270
# 2024-08-01 19:39:57,464 - INFO - Informations de la page Steam récupérées pour le jeu 81270
# 2024-08-01 19:39:58,467 - INFO - Traitement du game_id : 81271
# 2024-08-01 19:39:58,717 - INFO - Détails récupérés pour le jeu 81271
# 2024-08-01 19:39:59,486 - INFO - Informations de la page Steam récupérées pour le jeu 81271
# 2024-08-01 19:40:01,146 - INFO - Traitement du game_id : 81272
# 2024-08-01 19:40:01,369 - WARNING - Pas de données pour le jeu 81272
# 2024-08-01 19:40:02,141 - INFO - Traitement du game_id : 81273
# 2024-08-01 19:40:02,375 - WARNING - Pas de données pour le jeu 81273
# 2024-08-01 19:40:03,244 - INFO - Traitement du game_id : 81274
# 2024-08-01 19:40:03,485 - INFO - Détails récupérés pour le jeu 81274
# 2024-08-01 19:40:04,319 - INFO - Informations de la page Steam récupérées pour le jeu 81274
# 2024-08-01 19:40:05,752 - INFO - Traitement du game_id : 81275
# 2024-08-01 19:40:05,988 - INFO - Détails récupérés pour le jeu 81275
# 2024-08-01 19:40:06,663 - INFO - Informations de la page Steam récupérées pour le jeu 81275
# 2024-08-01 19:40:07,575 - INFO - Traitement du game_id : 81276
# 2024-08-01 19:40:08,155 - INFO - Détails récupérés pour le jeu 81276
# 2024-08-01 19:40:08,975 - INFO - Informations de la page Steam récupérées pour le jeu 81276
# 2024-08-01 19:40:10,048 - INFO - Traitement du game_id : 81277
# 2024-08-01 19:40:10,248 - WARNING - Pas de données pour le jeu 81277
# 2024-08-01 19:40:11,388 - INFO - Traitement du game_id : 81278
# 2024-08-01 19:40:11,656 - INFO - Détails récupérés pour le jeu 81278
# 2024-08-01 19:40:12,313 - INFO - Informations de la page Steam récupérées pour le jeu 81278
# 2024-08-01 19:40:13,414 - INFO - Traitement du game_id : 81279
# 2024-08-01 19:40:13,768 - INFO - Détails récupérés pour le jeu 81279
# 2024-08-01 19:40:14,367 - INFO - Informations de la page Steam récupérées pour le jeu 81279
# 2024-08-01 19:40:15,019 - INFO - Traitement du game_id : 81280
# 2024-08-01 19:40:15,490 - INFO - Détails récupérés pour le jeu 81280
# 2024-08-01 19:40:16,325 - INFO - Informations de la page Steam récupérées pour le jeu 81280
# 2024-08-01 19:40:16,889 - INFO - Traitement du game_id : 81281
# 2024-08-01 19:40:17,130 - INFO - Détails récupérés pour le jeu 81281
# 2024-08-01 19:40:17,849 - INFO - Informations de la page Steam récupérées pour le jeu 81281
# 2024-08-01 19:40:18,706 - INFO - Traitement du game_id : 81282
# 2024-08-01 19:40:18,944 - INFO - Détails récupérés pour le jeu 81282
# 2024-08-01 19:40:19,985 - INFO - Informations de la page Steam récupérées pour le jeu 81282
# 2024-08-01 19:40:20,860 - INFO - Traitement du game_id : 81283
# 2024-08-01 19:40:21,264 - WARNING - Pas de données pour le jeu 81283
# 2024-08-01 19:40:21,996 - INFO - Traitement du game_id : 81284
# 2024-08-01 19:40:22,195 - WARNING - Pas de données pour le jeu 81284
# 2024-08-01 19:40:23,320 - INFO - Traitement du game_id : 81285
# 2024-08-01 19:40:23,561 - INFO - Détails récupérés pour le jeu 81285
# 2024-08-01 19:40:24,396 - INFO - Informations de la page Steam récupérées pour le jeu 81285
# 2024-08-01 19:40:25,992 - INFO - Traitement du game_id : 81286
# 2024-08-01 19:40:26,217 - INFO - Détails récupérés pour le jeu 81286
# 2024-08-01 19:40:26,909 - INFO - Informations de la page Steam récupérées pour le jeu 81286
# 2024-08-01 19:40:27,818 - INFO - Mise à jour terminée avec succès
# 2024-08-01 19:40:27,821 - INFO - Fichier temporaire supprimé
