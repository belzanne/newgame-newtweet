# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random

# Fonction pour télécharger la base de données steam_games.db
def download_db(url, local_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    print(f"Échec du téléchargement de la base de données. Code de statut: {response.status_code}")
    return False

# Fonction pour obtenir les détails d'un jeu via l'API Steam
def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(steam_game_id)]['success']:
            return data[str(steam_game_id)]['data']
    return None

# Fonction pour obtenir les informations de la page Steam d'un jeu
def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Vérifier la présence de contenu généré par IA
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        
        # Recherche de la section "AI Generated Content Disclosure"
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        # Récupérer les tags
        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except Exception as e:
        print(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
        return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                print(f"Database is locked. Retrying in {delay} seconds...")
                time.sleep(delay)
                delay *= 2  # Augmenter le délai exponentiellement
            else:
                raise


def ensure_column_exists(cursor, table_name, column_name, column_type):
    """Vérifie si une colonne existe dans la table et l'ajoute si ce n'est pas le cas."""
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        print(f"Colonne '{column_name}' ajoutée à la table {table_name}")



# Fonction principale

def update_aug_steam_games():
    # Charger le dernier game_id traité
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
    except FileNotFoundError:
        last_processed_id = 12570  # Valeur par défaut si le fichier n'existe pas

    # Télécharger steam_games.db
    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            print("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            # Connexion aux bases de données
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            # Vérifier et ajouter la colonne 'type' si nécessaire
            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            # Récupérer les 500 prochains game_ids
            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 1000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                print(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    # Préparer les données pour l'insertion
                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    # Insérer ou mettre à jour les données
                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                # Mettre à jour le dernier game_id traité
                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                # Pause pour éviter de surcharger l'API
                time.sleep(random.uniform(0.5, 1.7))

            # Commit des changements
            conn_aug.commit()
            
        except Exception as e:
            print(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    # Supprimer le fichier temporaire
    os.unlink(temp_db.name)

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# Traitement du game_id : 33280
# Traitement du game_id : 33287
# Traitement du game_id : 33288
# Traitement du game_id : 33289
# Traitement du game_id : 33290
# Traitement du game_id : 33310
# Traitement du game_id : 33320
# Traitement du game_id : 33325
# Traitement du game_id : 33326
# Traitement du game_id : 33349
# Traitement du game_id : 33359
# Traitement du game_id : 33360
# Traitement du game_id : 33361
# Traitement du game_id : 33362
# Traitement du game_id : 33370
# Traitement du game_id : 33371
# Traitement du game_id : 33390
# Traitement du game_id : 33400
# Traitement du game_id : 33420
# Traitement du game_id : 33428
# Traitement du game_id : 33435
# Traitement du game_id : 33436
# Traitement du game_id : 33446
# Traitement du game_id : 33447
# Traitement du game_id : 33448
# Traitement du game_id : 33456
# Traitement du game_id : 33457
# Traitement du game_id : 33460
# Traitement du game_id : 33500
# Traitement du game_id : 33510
# Traitement du game_id : 33520
# Traitement du game_id : 33530
# Traitement du game_id : 33540
# Traitement du game_id : 33549
# Traitement du game_id : 33550
# Traitement du game_id : 33559
# Traitement du game_id : 33560
# Traitement du game_id : 33570
# Traitement du game_id : 33580
# Traitement du game_id : 33600
# Traitement du game_id : 33610
# Traitement du game_id : 33620
# Traitement du game_id : 33630
# Traitement du game_id : 33650
# Traitement du game_id : 33660
# Traitement du game_id : 33670
# Traitement du game_id : 33680
# Traitement du game_id : 33700
# Traitement du game_id : 33710
# Traitement du game_id : 33720
# Traitement du game_id : 33730
# Traitement du game_id : 33740
# Traitement du game_id : 33750
# Traitement du game_id : 33760
# Traitement du game_id : 33770
# Traitement du game_id : 33780
# Traitement du game_id : 33790
# Traitement du game_id : 33900
# Traitement du game_id : 33905
# Traitement du game_id : 33909
# Traitement du game_id : 33910
# Traitement du game_id : 33919
# Traitement du game_id : 33920
# Traitement du game_id : 33930
# Traitement du game_id : 33934
# Traitement du game_id : 33935
# Traitement du game_id : 33936
# Traitement du game_id : 33950
# Traitement du game_id : 33960
# Traitement du game_id : 33970
# Traitement du game_id : 33980
# Traitement du game_id : 33990
# Traitement du game_id : 34000
# Traitement du game_id : 34009
# Traitement du game_id : 34010
# Traitement du game_id : 34019
# Traitement du game_id : 34030
# Traitement du game_id : 34039
# Traitement du game_id : 34049
# Traitement du game_id : 34050
# Traitement du game_id : 34110
# Traitement du game_id : 34120
# Traitement du game_id : 34170
# Traitement du game_id : 34171
# Traitement du game_id : 34172
# Traitement du game_id : 34173
# Traitement du game_id : 34174
# Traitement du game_id : 34175
# Traitement du game_id : 34176
# Traitement du game_id : 34177
# Traitement du game_id : 34178
# Traitement du game_id : 34179
# Traitement du game_id : 34184
# Traitement du game_id : 34189
# Traitement du game_id : 34190
# Traitement du game_id : 34200
# Traitement du game_id : 34220
# Traitement du game_id : 34229
# Traitement du game_id : 34250
# Traitement du game_id : 34270
# Traitement du game_id : 34272
# Traitement du game_id : 34273
# Traitement du game_id : 34274
# Traitement du game_id : 34275
# Traitement du game_id : 34276
# Traitement du game_id : 34277
# Traitement du game_id : 34278
# Traitement du game_id : 34279
# Traitement du game_id : 34280
# Traitement du game_id : 34281
# Traitement du game_id : 34282
# Traitement du game_id : 34283
# Traitement du game_id : 34284
# Traitement du game_id : 34285
# Traitement du game_id : 34286
# Traitement du game_id : 34287
# Traitement du game_id : 34288
# Traitement du game_id : 34289
# Traitement du game_id : 34310
# Traitement du game_id : 34311
# Traitement du game_id : 34312
# Traitement du game_id : 34313
# Traitement du game_id : 34314
# Traitement du game_id : 34315
# Traitement du game_id : 34316
# Traitement du game_id : 34317
# Traitement du game_id : 34318
# Traitement du game_id : 34319
# Traitement du game_id : 34330
# Traitement du game_id : 34342
# Traitement du game_id : 34343
# Traitement du game_id : 34344
# Traitement du game_id : 34345
# Traitement du game_id : 34346
# Traitement du game_id : 34347
# Traitement du game_id : 34348
# Traitement du game_id : 34350
# Traitement du game_id : 34390
# Traitement du game_id : 34400
# Traitement du game_id : 34410
# Traitement du game_id : 34420
# Traitement du game_id : 34440
# Traitement du game_id : 34450
# Traitement du game_id : 34460
# Traitement du game_id : 34470
# Traitement du game_id : 34490
# Traitement du game_id : 34491
# Traitement du game_id : 34492
# Traitement du game_id : 34493
# Traitement du game_id : 34494
# Traitement du game_id : 34495
# Traitement du game_id : 34496
# Traitement du game_id : 34497
# Traitement du game_id : 34498
# Traitement du game_id : 34500
# Traitement du game_id : 34510
# Traitement du game_id : 34600
# Traitement du game_id : 34609
# Traitement du game_id : 34610
# Traitement du game_id : 34611
# Traitement du game_id : 34612
# Traitement du game_id : 34613
# Traitement du game_id : 34614
# Traitement du game_id : 34615
# Traitement du game_id : 34616
# Traitement du game_id : 34620
# Traitement du game_id : 34630
# Traitement du game_id : 34640
# Traitement du game_id : 34650
# Traitement du game_id : 34660
# Traitement du game_id : 34670
# Traitement du game_id : 34680
# Traitement du game_id : 34800
# Traitement du game_id : 34810
# Traitement du game_id : 34820
# Traitement du game_id : 34830
# Traitement du game_id : 34841
# Traitement du game_id : 34842
# Traitement du game_id : 34850
# Traitement du game_id : 34860
# Traitement du game_id : 34870
# Traitement du game_id : 34880
# Traitement du game_id : 34900
# Traitement du game_id : 34910
# Traitement du game_id : 34920
# Traitement du game_id : 34930
# Traitement du game_id : 35000
# Traitement du game_id : 35010
# Traitement du game_id : 35019
# Traitement du game_id : 35020
# Traitement du game_id : 35030
# Traitement du game_id : 35040
# Traitement du game_id : 35050
# Traitement du game_id : 35060
# Traitement du game_id : 35070
# Traitement du game_id : 35080
# Traitement du game_id : 35081
# Traitement du game_id : 35082
# Traitement du game_id : 35083
# Traitement du game_id : 35084
# Traitement du game_id : 35085
# Traitement du game_id : 35086
# Traitement du game_id : 35087
# Traitement du game_id : 35088
# Traitement du game_id : 35089
# Traitement du game_id : 35090
# Traitement du game_id : 35091
# Traitement du game_id : 35092
# Traitement du game_id : 35093
# Traitement du game_id : 35094
# Traitement du game_id : 35095
# Traitement du game_id : 35096
# Traitement du game_id : 35097
# Traitement du game_id : 35098
# Traitement du game_id : 35099
# Traitement du game_id : 35100
# Traitement du game_id : 35101
# Traitement du game_id : 35102
# Traitement du game_id : 35103
# Traitement du game_id : 35110
# Traitement du game_id : 35130
# Traitement du game_id : 35134
# Traitement du game_id : 35135
# Traitement du game_id : 35136
# Traitement du game_id : 35137
# Traitement du game_id : 35138
# Traitement du game_id : 35140
# Traitement du game_id : 35150
# Traitement du game_id : 35300
# Traitement du game_id : 35310
# Traitement du game_id : 35320
# Traitement du game_id : 35417
# Traitement du game_id : 35418
# Traitement du game_id : 35419
# Traitement du game_id : 35425
# Traitement du game_id : 35426
# Traitement du game_id : 35427
# Traitement du game_id : 35428
# Traitement du game_id : 35429
# Traitement du game_id : 35450
# Traitement du game_id : 35460
# Traitement du game_id : 35470
# Traitement du game_id : 35480
# Traitement du game_id : 35485
# Traitement du game_id : 35490
# Traitement du game_id : 35500
# Traitement du game_id : 35509
# Traitement du game_id : 35510
# Traitement du game_id : 35600
# Traitement du game_id : 35700
# Traitement du game_id : 35709
# Traitement du game_id : 35710
# Traitement du game_id : 35720
# Traitement du game_id : 35723
# Traitement du game_id : 35725
# Traitement du game_id : 35800
# Traitement du game_id : 36000
# Traitement du game_id : 36130
# Traitement du game_id : 36150
# Traitement du game_id : 36630
# Traitement du game_id : 36632
# Traitement du game_id : 36633
# Traitement du game_id : 36700
# Traitement du game_id : 36710
# Traitement du game_id : 36900
# Traitement du game_id : 36909
# Traitement du game_id : 36910
# Traitement du game_id : 36919
# Traitement du game_id : 36920
# Traitement du game_id : 36930
# Traitement du game_id : 37000
# Traitement du game_id : 37200
# Traitement du game_id : 37210
# Traitement du game_id : 37220
# Traitement du game_id : 37230
# Traitement du game_id : 37240
# Traitement du game_id : 37250
# Traitement du game_id : 37260
# Traitement du game_id : 37270
# Traitement du game_id : 37280
# Traitement du game_id : 37290
# Traitement du game_id : 37300
# Traitement du game_id : 37310
# Traitement du game_id : 37320
# Traitement du game_id : 37330
# Traitement du game_id : 37340
# Traitement du game_id : 37350
# Traitement du game_id : 37360
# Traitement du game_id : 37370
# Traitement du game_id : 37380
# Traitement du game_id : 37390
# Traitement du game_id : 37400
# Traitement du game_id : 37410
# Traitement du game_id : 37420
# Traitement du game_id : 37500
# Traitement du game_id : 37510
# Traitement du game_id : 37600
# Traitement du game_id : 37708
# Traitement du game_id : 37709
# Traitement du game_id : 37800
# Traitement du game_id : 37810
# Traitement du game_id : 37900
# Traitement du game_id : 37910
# Traitement du game_id : 37920
# Traitement du game_id : 37930
# Traitement du game_id : 37940
# Traitement du game_id : 37950
# Traitement du game_id : 37960
# Traitement du game_id : 37970
# Traitement du game_id : 37980
# Traitement du game_id : 37990
# Traitement du game_id : 38000
# Traitement du game_id : 38010
# Traitement du game_id : 38020
# Traitement du game_id : 38030
# Traitement du game_id : 38040
# Traitement du game_id : 38050
# Traitement du game_id : 38060
# Traitement du game_id : 38070
# Traitement du game_id : 38080
# Traitement du game_id : 38090
# Traitement du game_id : 38100
# Traitement du game_id : 38110
# Traitement du game_id : 38120
# Traitement du game_id : 38130
# Traitement du game_id : 38140
# Traitement du game_id : 38150
# Traitement du game_id : 38160
# Traitement du game_id : 38170
# Traitement du game_id : 38180
# Traitement du game_id : 38185
# Traitement du game_id : 38190
# Traitement du game_id : 38200
# Traitement du game_id : 38209
# Traitement du game_id : 38210
# Traitement du game_id : 38220
# Traitement du game_id : 38229
# Traitement du game_id : 38230
# Traitement du game_id : 38240
# Traitement du game_id : 38400
# Traitement du game_id : 38410
# Traitement du game_id : 38420
# Traitement du game_id : 38430
# Traitement du game_id : 38440
# Traitement du game_id : 38450
# Traitement du game_id : 38460
# Traitement du game_id : 38480
# Traitement du game_id : 38490
# Traitement du game_id : 38530
# Traitement du game_id : 38600
# Traitement du game_id : 38700
# Traitement du game_id : 38710
# Traitement du game_id : 38720
# Traitement du game_id : 38730
# Traitement du game_id : 38740
# Traitement du game_id : 38743
# Traitement du game_id : 38750
# Traitement du game_id : 38800
# Traitement du game_id : 38810
# Traitement du game_id : 38820
# Traitement du game_id : 38830
# Traitement du game_id : 38900
# Traitement du game_id : 38910
# Traitement du game_id : 38920
# Traitement du game_id : 38921
# Traitement du game_id : 38922
# Traitement du game_id : 38923
# Traitement du game_id : 38924
# Traitement du game_id : 38925
# Traitement du game_id : 38926
# Traitement du game_id : 38927
# Traitement du game_id : 39000
# Traitement du game_id : 39100
# Traitement du game_id : 39110
# Traitement du game_id : 39120
# Traitement du game_id : 39122
# Traitement du game_id : 39123
# Traitement du game_id : 39124
# Traitement du game_id : 39125
# Traitement du game_id : 39126
# Traitement du game_id : 39127
# Traitement du game_id : 39128
# Traitement du game_id : 39129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 191
#     188     os.unlink(temp_db.name)
#     190 if __name__ == "__main__":
# --> 191     update_aug_steam_games()
#
# Cell In[11], line 133, in update_aug_steam_games()
#     131 game_id = game_id[0]
#     132 print(f"Traitement du game_id : {game_id}")
# --> 133 game_data = get_game_details(game_id)
#     134 if game_data:
#     135     steam_page_info = get_steam_page_info(game_id)
#
# Cell In[11], line 26, in get_game_details(steam_game_id)
#      24 def get_game_details(steam_game_id):
#      25     url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
# ---> 26     response = requests.get(url)
#      27     if response.status_code == 200:
#      28         data = response.json()
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/newgame-newtweet-icRyx73a-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import sqlite3
import requests
import json
import time
import os
from bs4 import BeautifulSoup
from datetime import datetime
import tempfile
import re
import random
import logging

# Configuration du logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def download_db(url, local_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(local_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        logging.info(f"Base de données téléchargée avec succès: {local_path}")
        return True
    except requests.RequestException as e:
        logging.error(f"Échec du téléchargement de la base de données: {e}")
        return False

def get_game_details(steam_game_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={steam_game_id}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        if data[str(steam_game_id)]['success']:
            logging.info(f"Détails récupérés pour le jeu {steam_game_id}")
            return data[str(steam_game_id)]['data']
        else:
            logging.warning(f"Pas de données pour le jeu {steam_game_id}")
    except requests.RequestException as e:
        logging.error(f"Erreur lors de la récupération des détails pour le jeu {steam_game_id}: {e}")
    except json.JSONDecodeError as e:
        logging.error(f"Erreur de décodage JSON pour le jeu {steam_game_id}: {e}")
    return None

def get_steam_page_info(app_id):
    url = f"https://store.steampowered.com/app/{app_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        ai_disclosure = soup.find(string=re.compile("AI GENERATED CONTENT DISCLOSURE", re.IGNORECASE))
        ai_section = soup.find('h2', string='AI Generated Content Disclosure')
        ai_generated = bool(ai_section)
        ai_content = None
        if ai_generated:
            ai_paragraph = ai_section.find_next('i')
            if ai_paragraph:
                ai_content = ai_paragraph.text.strip()

        tag_elements = soup.find_all('a', class_='app_tag')
        tags = [tag.text.strip() for tag in tag_elements]
        
        logging.info(f"Informations de la page Steam récupérées pour le jeu {app_id}")
        return {
            'ai_generated': bool(ai_disclosure),
            'ai_content': ai_content,
            'tags': tags,
        }
    except requests.RequestException as e:
        logging.error(f"Erreur lors du scraping pour le jeu {app_id}: {e}")
    except Exception as e:
        logging.error(f"Erreur inattendue lors du scraping pour le jeu {app_id}: {e}")
    return None

def execute_with_retry(cursor, sql, params=None, max_attempts=5, delay=1):
    for attempt in range(max_attempts):
        try:
            if params:
                cursor.execute(sql, params)
            else:
                cursor.execute(sql)
            return
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e) and attempt < max_attempts - 1:
                logging.warning(f"Base de données verrouillée. Nouvelle tentative dans {delay} secondes...")
                time.sleep(delay)
                delay *= 2
            else:
                raise

def ensure_column_exists(cursor, table_name, column_name, column_type):
    cursor.execute(f"PRAGMA table_info({table_name})")
    columns = [column[1] for column in cursor.fetchall()]
    if column_name not in columns:
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_type}")
        logging.info(f"Colonne '{column_name}' ajoutée à la table {table_name}")

def update_aug_steam_games():
    try:
        with open('last_processed_game_id.txt', 'r') as f:
            last_processed_id = int(f.read().strip())
        logging.info(f"Dernier game_id traité: {last_processed_id}")
    except FileNotFoundError:
        last_processed_id = 12570
        logging.info(f"Fichier last_processed_game_id.txt non trouvé. Utilisation de la valeur par défaut: {last_processed_id}")

    db_url = f"https://raw.githubusercontent.com/{os.getenv('PAT_GITHUB_USERNAME')}/steampage-creation-date/main/steam_games.db"
    with tempfile.NamedTemporaryFile(delete=False, suffix='.db') as temp_db:
        if not download_db(db_url, temp_db.name):
            logging.error("Échec du téléchargement de steam_games.db")
            return

        conn_steam = None
        conn_aug = None
        try:
            conn_steam = sqlite3.connect(temp_db.name)
            conn_aug = sqlite3.connect('aug_steam_games.db', timeout=20)
            cursor_steam = conn_steam.cursor()
            cursor_aug = conn_aug.cursor()

            ensure_column_exists(cursor_aug, 'aug_steam_games', 'type', 'TEXT')

            execute_with_retry(cursor_steam, "SELECT steam_game_id FROM games WHERE steam_game_id > ? ORDER BY steam_game_id LIMIT 9000", (last_processed_id,))
            game_ids = cursor_steam.fetchall()

            for game_id in game_ids:
                game_id = game_id[0]
                logging.info(f"Traitement du game_id : {game_id}")
                game_data = get_game_details(game_id)
                if game_data:
                    steam_page_info = get_steam_page_info(game_id)

                    add_date = int(time.time())
                    game_type = game_data.get('type', 'Unknown')
                    dev = ', '.join(game_data.get('developers', []))
                    publisher = ', '.join(game_data.get('publishers', []))
                    tags = ', '.join(steam_page_info['tags']) if steam_page_info else ''
                    release_date = game_data.get('release_date', {}).get('date', '')
                    description = game_data.get('short_description', '')
                    ai_generated = 'Yes' if steam_page_info and steam_page_info['ai_generated'] else 'No'
                    ai_content = steam_page_info['ai_content'] if steam_page_info and steam_page_info['ai_generated'] else None
                    content_descriptors = game_data.get('content_descriptors', {})
                    content_descriptors_ids = content_descriptors.get('ids', [])
                    content_descriptors_str = ', '.join(map(str, content_descriptors_ids))
                    supported_languages = game_data.get('supported_languages', '')
                    free = 'Yes' if game_data.get('is_free', False) else 'No'
                    dlc = 'Yes' if game_data.get('type', '') == 'dlc' else 'No'

                    execute_with_retry(cursor_aug, '''
                    INSERT OR REPLACE INTO aug_steam_games
                    (game_id, add_date, type, dev, publisher, tags, release_date, description, ai_generated, ai_content, 
                    content_descriptors, supported_languages, free, dlc)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (game_id, add_date, game_type, dev, publisher, tags, release_date, description, ai_generated, ai_content,
                          content_descriptors_str, supported_languages, free, dlc))

                with open('last_processed_game_id.txt', 'w') as f:
                    f.write(str(game_id))

                time.sleep(random.uniform(0.5, 1.7))

            conn_aug.commit()
            logging.info("Mise à jour terminée avec succès")
            
        except Exception as e:
            logging.error(f"Une erreur est survenue : {e}")
            if conn_aug:
                conn_aug.rollback()
        finally:
            if cursor_steam:
                cursor_steam.close()
            if cursor_aug:
                cursor_aug.close()
            if conn_steam:
                conn_steam.close()
            if conn_aug:
                conn_aug.close()
    
    os.unlink(temp_db.name)
    logging.info("Fichier temporaire supprimé")

if __name__ == "__main__":
    update_aug_steam_games()
# Out:
# 2024-08-01 21:21:49,883 - INFO - Dernier game_id traité: 210936
# 2024-08-01 21:21:50,635 - INFO - Base de données téléchargée avec succès: /var/folders/b5/ckj362xj7ng_xqbjrqp077qh0000gn/T/tmpafkab22i.db
# 2024-08-01 21:21:50,642 - INFO - Traitement du game_id : 210937
# 2024-08-01 21:21:51,092 - INFO - Détails récupérés pour le jeu 210937
# 2024-08-01 21:21:51,679 - INFO - Informations de la page Steam récupérées pour le jeu 210937
# 2024-08-01 21:21:52,470 - INFO - Traitement du game_id : 210938
# 2024-08-01 21:21:52,782 - INFO - Détails récupérés pour le jeu 210938
# 2024-08-01 21:21:53,260 - INFO - Informations de la page Steam récupérées pour le jeu 210938
# 2024-08-01 21:21:53,786 - INFO - Traitement du game_id : 210939
# 2024-08-01 21:21:54,032 - WARNING - Pas de données pour le jeu 210939
# 2024-08-01 21:21:54,632 - INFO - Traitement du game_id : 210942
# 2024-08-01 21:21:54,859 - WARNING - Pas de données pour le jeu 210942
# 2024-08-01 21:21:55,837 - INFO - Traitement du game_id : 210944
# 2024-08-01 21:21:56,071 - INFO - Détails récupérés pour le jeu 210944
# 2024-08-01 21:21:56,555 - INFO - Informations de la page Steam récupérées pour le jeu 210944
# 2024-08-01 21:21:57,976 - INFO - Traitement du game_id : 210945
# 2024-08-01 21:21:58,208 - INFO - Détails récupérés pour le jeu 210945
# 2024-08-01 21:21:58,723 - INFO - Informations de la page Steam récupérées pour le jeu 210945
# 2024-08-01 21:21:59,522 - INFO - Traitement du game_id : 210950
# 2024-08-01 21:21:59,818 - INFO - Détails récupérés pour le jeu 210950
# 2024-08-01 21:22:00,612 - INFO - Informations de la page Steam récupérées pour le jeu 210950
# 2024-08-01 21:22:01,762 - INFO - Traitement du game_id : 210970
# 2024-08-01 21:22:02,154 - INFO - Détails récupérés pour le jeu 210970
# 2024-08-01 21:22:02,619 - INFO - Informations de la page Steam récupérées pour le jeu 210970
# 2024-08-01 21:22:04,120 - INFO - Traitement du game_id : 210990
# 2024-08-01 21:22:04,342 - WARNING - Pas de données pour le jeu 210990
# 2024-08-01 21:22:05,316 - INFO - Traitement du game_id : 210999
# 2024-08-01 21:22:05,629 - WARNING - Pas de données pour le jeu 210999
# 2024-08-01 21:22:06,354 - INFO - Traitement du game_id : 211000
# 2024-08-01 21:22:06,587 - WARNING - Pas de données pour le jeu 211000
# 2024-08-01 21:22:07,423 - INFO - Traitement du game_id : 211001
# 2024-08-01 21:22:07,666 - WARNING - Pas de données pour le jeu 211001
# 2024-08-01 21:22:08,925 - INFO - Traitement du game_id : 211010
# 2024-08-01 21:22:09,190 - INFO - Détails récupérés pour le jeu 211010
# 2024-08-01 21:22:10,176 - INFO - Informations de la page Steam récupérées pour le jeu 211010
# 2024-08-01 21:22:10,939 - INFO - Traitement du game_id : 211050
# 2024-08-01 21:22:11,251 - INFO - Détails récupérés pour le jeu 211050
# 2024-08-01 21:22:11,863 - INFO - Informations de la page Steam récupérées pour le jeu 211050
# 2024-08-01 21:22:13,268 - INFO - Traitement du game_id : 211070
# 2024-08-01 21:22:13,524 - WARNING - Pas de données pour le jeu 211070
# 2024-08-01 21:22:14,041 - INFO - Traitement du game_id : 211090
# 2024-08-01 21:22:14,269 - WARNING - Pas de données pour le jeu 211090
# 2024-08-01 21:22:15,625 - INFO - Traitement du game_id : 211120
# 2024-08-01 21:22:15,976 - INFO - Détails récupérés pour le jeu 211120
# 2024-08-01 21:22:16,571 - INFO - Informations de la page Steam récupérées pour le jeu 211120
# 2024-08-01 21:22:17,891 - INFO - Traitement du game_id : 211140
# 2024-08-01 21:22:18,116 - INFO - Détails récupérés pour le jeu 211140
# 2024-08-01 21:22:19,009 - INFO - Informations de la page Steam récupérées pour le jeu 211140
# 2024-08-01 21:22:19,657 - INFO - Traitement du game_id : 211160
# 2024-08-01 21:22:19,903 - INFO - Détails récupérés pour le jeu 211160
# 2024-08-01 21:22:20,377 - INFO - Informations de la page Steam récupérées pour le jeu 211160
# 2024-08-01 21:22:21,058 - INFO - Traitement du game_id : 211180
# 2024-08-01 21:22:21,383 - INFO - Détails récupérés pour le jeu 211180
# 2024-08-01 21:22:21,997 - INFO - Informations de la page Steam récupérées pour le jeu 211180
# 2024-08-01 21:22:23,673 - INFO - Traitement du game_id : 211200
# 2024-08-01 21:22:24,025 - INFO - Détails récupérés pour le jeu 211200
# 2024-08-01 21:22:24,876 - INFO - Informations de la page Steam récupérées pour le jeu 211200
# 2024-08-01 21:22:25,419 - INFO - Traitement du game_id : 211201
# 2024-08-01 21:22:25,654 - INFO - Détails récupérés pour le jeu 211201
# 2024-08-01 21:22:26,523 - INFO - Informations de la page Steam récupérées pour le jeu 211201
# 2024-08-01 21:22:27,304 - INFO - Traitement du game_id : 211202
# 2024-08-01 21:22:27,545 - INFO - Détails récupérés pour le jeu 211202
# 2024-08-01 21:22:28,232 - INFO - Informations de la page Steam récupérées pour le jeu 211202
# 2024-08-01 21:22:29,292 - INFO - Traitement du game_id : 211203
# 2024-08-01 21:22:29,677 - INFO - Détails récupérés pour le jeu 211203
# 2024-08-01 21:22:30,334 - INFO - Informations de la page Steam récupérées pour le jeu 211203
# 2024-08-01 21:22:31,217 - INFO - Traitement du game_id : 211204
# 2024-08-01 21:22:31,469 - INFO - Détails récupérés pour le jeu 211204
# 2024-08-01 21:22:32,152 - INFO - Informations de la page Steam récupérées pour le jeu 211204
# 2024-08-01 21:22:33,018 - INFO - Traitement du game_id : 211205
# 2024-08-01 21:22:33,252 - INFO - Détails récupérés pour le jeu 211205
# 2024-08-01 21:22:34,006 - INFO - Informations de la page Steam récupérées pour le jeu 211205
# 2024-08-01 21:22:34,830 - INFO - Traitement du game_id : 211206
# 2024-08-01 21:22:35,099 - INFO - Détails récupérés pour le jeu 211206
# 2024-08-01 21:22:35,870 - INFO - Informations de la page Steam récupérées pour le jeu 211206
# 2024-08-01 21:22:36,799 - INFO - Traitement du game_id : 211207
# 2024-08-01 21:22:37,172 - INFO - Détails récupérés pour le jeu 211207
# 2024-08-01 21:22:37,878 - INFO - Informations de la page Steam récupérées pour le jeu 211207
# 2024-08-01 21:22:39,479 - INFO - Traitement du game_id : 211208
# 2024-08-01 21:22:39,725 - INFO - Détails récupérés pour le jeu 211208
# 2024-08-01 21:22:40,197 - INFO - Informations de la page Steam récupérées pour le jeu 211208
# 2024-08-01 21:22:41,681 - INFO - Traitement du game_id : 211209
# 2024-08-01 21:22:41,900 - INFO - Détails récupérés pour le jeu 211209
# 2024-08-01 21:22:42,443 - INFO - Informations de la page Steam récupérées pour le jeu 211209
# 2024-08-01 21:22:43,224 - INFO - Traitement du game_id : 211260
# 2024-08-01 21:22:43,695 - INFO - Détails récupérés pour le jeu 211260
# 2024-08-01 21:22:44,111 - INFO - Informations de la page Steam récupérées pour le jeu 211260
# 2024-08-01 21:22:44,767 - INFO - Traitement du game_id : 211262
# 2024-08-01 21:22:45,036 - INFO - Détails récupérés pour le jeu 211262
# 2024-08-01 21:22:45,576 - INFO - Informations de la page Steam récupérées pour le jeu 211262
# 2024-08-01 21:22:46,535 - INFO - Traitement du game_id : 211280
# 2024-08-01 21:22:46,880 - INFO - Détails récupérés pour le jeu 211280
# 2024-08-01 21:22:47,675 - INFO - Informations de la page Steam récupérées pour le jeu 211280
# 2024-08-01 21:22:48,862 - INFO - Traitement du game_id : 211340
# 2024-08-01 21:22:49,128 - INFO - Détails récupérés pour le jeu 211340
# 2024-08-01 21:22:49,755 - INFO - Informations de la page Steam récupérées pour le jeu 211340
# 2024-08-01 21:22:50,884 - INFO - Traitement du game_id : 211360
# 2024-08-01 21:22:51,205 - INFO - Détails récupérés pour le jeu 211360
# 2024-08-01 21:22:51,857 - INFO - Informations de la page Steam récupérées pour le jeu 211360
# 2024-08-01 21:22:53,104 - INFO - Traitement du game_id : 211380
# 2024-08-01 21:22:53,331 - WARNING - Pas de données pour le jeu 211380
# 2024-08-01 21:22:54,779 - INFO - Traitement du game_id : 211400
# 2024-08-01 21:22:55,049 - INFO - Détails récupérés pour le jeu 211400
# 2024-08-01 21:22:55,538 - INFO - Informations de la page Steam récupérées pour le jeu 211400
# 2024-08-01 21:22:56,203 - INFO - Traitement du game_id : 211419
# 2024-08-01 21:22:56,589 - INFO - Détails récupérés pour le jeu 211419
# 2024-08-01 21:22:57,225 - INFO - Informations de la page Steam récupérées pour le jeu 211419
# 2024-08-01 21:22:58,315 - INFO - Traitement du game_id : 211440
# 2024-08-01 21:22:58,561 - INFO - Détails récupérés pour le jeu 211440
# 2024-08-01 21:22:59,157 - INFO - Informations de la page Steam récupérées pour le jeu 211440
# 2024-08-01 21:23:00,081 - INFO - Traitement du game_id : 211500
# 2024-08-01 21:23:00,407 - INFO - Détails récupérés pour le jeu 211500
# 2024-08-01 21:23:00,869 - INFO - Informations de la page Steam récupérées pour le jeu 211500
# 2024-08-01 21:23:01,434 - INFO - Traitement du game_id : 211580
# 2024-08-01 21:23:01,700 - INFO - Détails récupérés pour le jeu 211580
# 2024-08-01 21:23:02,479 - INFO - Informations de la page Steam récupérées pour le jeu 211580
# 2024-08-01 21:23:03,878 - INFO - Traitement du game_id : 211600
# 2024-08-01 21:23:04,117 - INFO - Détails récupérés pour le jeu 211600
# 2024-08-01 21:23:04,711 - INFO - Informations de la page Steam récupérées pour le jeu 211600
# 2024-08-01 21:23:05,928 - INFO - Traitement du game_id : 211670
# 2024-08-01 21:23:06,299 - INFO - Détails récupérés pour le jeu 211670
# 2024-08-01 21:23:07,260 - INFO - Informations de la page Steam récupérées pour le jeu 211670
# 2024-08-01 21:23:08,389 - INFO - Traitement du game_id : 211691
# 2024-08-01 21:23:08,759 - INFO - Détails récupérés pour le jeu 211691
# 2024-08-01 21:23:10,083 - INFO - Informations de la page Steam récupérées pour le jeu 211691
# 2024-08-01 21:23:11,494 - INFO - Traitement du game_id : 211692
# 2024-08-01 21:23:11,820 - INFO - Détails récupérés pour le jeu 211692
# 2024-08-01 21:23:13,110 - INFO - Informations de la page Steam récupérées pour le jeu 211692
# 2024-08-01 21:23:14,433 - INFO - Traitement du game_id : 211693
# 2024-08-01 21:23:14,775 - WARNING - Pas de données pour le jeu 211693
# 2024-08-01 21:23:16,021 - INFO - Traitement du game_id : 211720
# 2024-08-01 21:23:16,332 - INFO - Détails récupérés pour le jeu 211720
# 2024-08-01 21:23:16,868 - INFO - Informations de la page Steam récupérées pour le jeu 211720
# 2024-08-01 21:23:18,483 - INFO - Traitement du game_id : 211740
# 2024-08-01 21:23:18,731 - INFO - Détails récupérés pour le jeu 211740
# 2024-08-01 21:23:19,213 - INFO - Informations de la page Steam récupérées pour le jeu 211740
# 2024-08-01 21:23:20,130 - INFO - Traitement du game_id : 211780
# 2024-08-01 21:23:20,367 - INFO - Détails récupérés pour le jeu 211780
# 2024-08-01 21:23:20,840 - INFO - Informations de la page Steam récupérées pour le jeu 211780
# 2024-08-01 21:23:22,369 - INFO - Traitement du game_id : 211800
# 2024-08-01 21:23:22,643 - INFO - Détails récupérés pour le jeu 211800
# 2024-08-01 21:23:23,148 - INFO - Informations de la page Steam récupérées pour le jeu 211800
# 2024-08-01 21:23:23,866 - INFO - Traitement du game_id : 211820
# 2024-08-01 21:23:24,146 - INFO - Détails récupérés pour le jeu 211820
# 2024-08-01 21:23:24,564 - INFO - Informations de la page Steam récupérées pour le jeu 211820
# 2024-08-01 21:23:25,777 - INFO - Traitement du game_id : 211880
# 2024-08-01 21:23:25,978 - WARNING - Pas de données pour le jeu 211880
# 2024-08-01 21:23:26,625 - INFO - Traitement du game_id : 211900
# 2024-08-01 21:23:26,872 - INFO - Détails récupérés pour le jeu 211900
# 2024-08-01 21:23:27,577 - INFO - Informations de la page Steam récupérées pour le jeu 211900
# 2024-08-01 21:23:28,999 - INFO - Traitement du game_id : 211940
# 2024-08-01 21:23:29,397 - WARNING - Pas de données pour le jeu 211940
# 2024-08-01 21:23:30,824 - INFO - Traitement du game_id : 211954
# 2024-08-01 21:23:31,056 - WARNING - Pas de données pour le jeu 211954
# 2024-08-01 21:23:32,374 - INFO - Traitement du game_id : 211970
# 2024-08-01 21:23:32,840 - INFO - Détails récupérés pour le jeu 211970
# 2024-08-01 21:23:33,354 - INFO - Informations de la page Steam récupérées pour le jeu 211970
# 2024-08-01 21:23:34,700 - INFO - Traitement du game_id : 211990
# 2024-08-01 21:23:34,945 - INFO - Détails récupérés pour le jeu 211990
# 2024-08-01 21:23:35,512 - INFO - Informations de la page Steam récupérées pour le jeu 211990
# 2024-08-01 21:23:37,198 - INFO - Traitement du game_id : 211991
# 2024-08-01 21:23:37,432 - WARNING - Pas de données pour le jeu 211991
# 2024-08-01 21:23:38,815 - INFO - Traitement du game_id : 211992
# 2024-08-01 21:23:39,042 - INFO - Détails récupérés pour le jeu 211992
# 2024-08-01 21:23:39,409 - INFO - Informations de la page Steam récupérées pour le jeu 211992
# 2024-08-01 21:23:40,554 - INFO - Traitement du game_id : 211994
# 2024-08-01 21:23:40,789 - INFO - Détails récupérés pour le jeu 211994
# 2024-08-01 21:23:41,137 - INFO - Informations de la page Steam récupérées pour le jeu 211994
# 2024-08-01 21:23:41,777 - INFO - Traitement du game_id : 212010
# 2024-08-01 21:23:42,056 - INFO - Détails récupérés pour le jeu 212010
# 2024-08-01 21:23:42,716 - INFO - Informations de la page Steam récupérées pour le jeu 212010
# 2024-08-01 21:23:44,146 - INFO - Traitement du game_id : 212030
# 2024-08-01 21:23:44,643 - INFO - Détails récupérés pour le jeu 212030
# 2024-08-01 21:23:45,268 - INFO - Informations de la page Steam récupérées pour le jeu 212030
# 2024-08-01 21:23:46,234 - INFO - Traitement du game_id : 212041
# 2024-08-01 21:23:46,465 - INFO - Détails récupérés pour le jeu 212041
# 2024-08-01 21:23:47,020 - INFO - Informations de la page Steam récupérées pour le jeu 212041
# 2024-08-01 21:23:47,714 - INFO - Traitement du game_id : 212050
# 2024-08-01 21:23:47,979 - INFO - Détails récupérés pour le jeu 212050
# 2024-08-01 21:23:48,363 - INFO - Informations de la page Steam récupérées pour le jeu 212050
# 2024-08-01 21:23:49,499 - INFO - Traitement du game_id : 212070
# 2024-08-01 21:23:49,848 - INFO - Détails récupérés pour le jeu 212070
# 2024-08-01 21:23:50,516 - INFO - Informations de la page Steam récupérées pour le jeu 212070
# 2024-08-01 21:23:51,751 - INFO - Traitement du game_id : 212090
# 2024-08-01 21:23:51,966 - WARNING - Pas de données pour le jeu 212090
# 2024-08-01 21:23:52,491 - INFO - Traitement du game_id : 212110
# 2024-08-01 21:23:52,767 - INFO - Détails récupérés pour le jeu 212110
# 2024-08-01 21:23:53,368 - INFO - Informations de la page Steam récupérées pour le jeu 212110
# 2024-08-01 21:23:54,599 - INFO - Traitement du game_id : 212140
# 2024-08-01 21:23:55,020 - INFO - Détails récupérés pour le jeu 212140
# 2024-08-01 21:23:55,747 - INFO - Informations de la page Steam récupérées pour le jeu 212140
# 2024-08-01 21:23:56,371 - INFO - Traitement du game_id : 212160
# 2024-08-01 21:23:56,638 - INFO - Détails récupérés pour le jeu 212160
# 2024-08-01 21:23:57,092 - INFO - Informations de la page Steam récupérées pour le jeu 212160
# 2024-08-01 21:23:58,178 - INFO - Traitement du game_id : 212170
# 2024-08-01 21:23:58,407 - WARNING - Pas de données pour le jeu 212170
# 2024-08-01 21:23:59,405 - INFO - Traitement du game_id : 212171
# 2024-08-01 21:23:59,629 - WARNING - Pas de données pour le jeu 212171
# 2024-08-01 21:24:00,755 - INFO - Traitement du game_id : 212172
# 2024-08-01 21:24:00,963 - WARNING - Pas de données pour le jeu 212172
# 2024-08-01 21:24:02,241 - INFO - Traitement du game_id : 212180
# 2024-08-01 21:24:02,445 - WARNING - Pas de données pour le jeu 212180
# 2024-08-01 21:24:03,476 - INFO - Traitement du game_id : 212200
# 2024-08-01 21:24:03,677 - WARNING - Pas de données pour le jeu 212200
# 2024-08-01 21:24:05,117 - INFO - Traitement du game_id : 212211
# 2024-08-01 21:24:05,373 - WARNING - Pas de données pour le jeu 212211
# 2024-08-01 21:24:06,666 - INFO - Traitement du game_id : 212220
# 2024-08-01 21:24:06,877 - WARNING - Pas de données pour le jeu 212220
# 2024-08-01 21:24:08,390 - INFO - Traitement du game_id : 212240
# 2024-08-01 21:24:08,604 - WARNING - Pas de données pour le jeu 212240
# 2024-08-01 21:24:09,872 - INFO - Traitement du game_id : 212301
# 2024-08-01 21:24:10,191 - INFO - Détails récupérés pour le jeu 212301
# 2024-08-01 21:24:10,589 - INFO - Informations de la page Steam récupérées pour le jeu 212301
# 2024-08-01 21:24:11,127 - INFO - Traitement du game_id : 212330
# 2024-08-01 21:24:11,385 - WARNING - Pas de données pour le jeu 212330
# 2024-08-01 21:24:12,216 - INFO - Traitement du game_id : 212350
# 2024-08-01 21:24:12,479 - INFO - Détails récupérés pour le jeu 212350
# 2024-08-01 21:24:13,290 - INFO - Informations de la page Steam récupérées pour le jeu 212350
# 2024-08-01 21:24:14,521 - INFO - Traitement du game_id : 212370
# 2024-08-01 21:24:14,731 - WARNING - Pas de données pour le jeu 212370
# 2024-08-01 21:24:15,798 - INFO - Traitement du game_id : 212390
# 2024-08-01 21:24:16,028 - INFO - Détails récupérés pour le jeu 212390
# 2024-08-01 21:24:16,572 - INFO - Informations de la page Steam récupérées pour le jeu 212390
# 2024-08-01 21:24:17,350 - INFO - Traitement du game_id : 212410
# 2024-08-01 21:24:17,560 - WARNING - Pas de données pour le jeu 212410
# 2024-08-01 21:24:18,956 - INFO - Traitement du game_id : 212432
# 2024-08-01 21:24:19,183 - WARNING - Pas de données pour le jeu 212432
# 2024-08-01 21:24:20,000 - INFO - Traitement du game_id : 212433
# 2024-08-01 21:24:20,365 - WARNING - Pas de données pour le jeu 212433
# 2024-08-01 21:24:21,793 - INFO - Traitement du game_id : 212434
# 2024-08-01 21:24:22,002 - WARNING - Pas de données pour le jeu 212434
# 2024-08-01 21:24:23,196 - INFO - Traitement du game_id : 212435
# 2024-08-01 21:24:23,413 - WARNING - Pas de données pour le jeu 212435
# 2024-08-01 21:24:24,909 - INFO - Traitement du game_id : 212436
# 2024-08-01 21:24:25,280 - WARNING - Pas de données pour le jeu 212436
# 2024-08-01 21:24:25,963 - INFO - Traitement du game_id : 212437
# 2024-08-01 21:24:26,330 - WARNING - Pas de données pour le jeu 212437
# 2024-08-01 21:24:27,832 - INFO - Traitement du game_id : 212438
# 2024-08-01 21:24:28,043 - WARNING - Pas de données pour le jeu 212438
# 2024-08-01 21:24:28,820 - INFO - Traitement du game_id : 212439
# 2024-08-01 21:24:29,045 - WARNING - Pas de données pour le jeu 212439
# 2024-08-01 21:24:30,131 - INFO - Traitement du game_id : 212440
# 2024-08-01 21:24:30,367 - WARNING - Pas de données pour le jeu 212440
# 2024-08-01 21:24:31,709 - INFO - Traitement du game_id : 212441
# 2024-08-01 21:24:31,913 - WARNING - Pas de données pour le jeu 212441
# 2024-08-01 21:24:33,095 - INFO - Traitement du game_id : 212442
# 2024-08-01 21:24:33,290 - WARNING - Pas de données pour le jeu 212442
# 2024-08-01 21:24:34,983 - INFO - Traitement du game_id : 212443
# 2024-08-01 21:24:35,187 - WARNING - Pas de données pour le jeu 212443
# 2024-08-01 21:24:36,752 - INFO - Traitement du game_id : 212444
# 2024-08-01 21:24:36,957 - WARNING - Pas de données pour le jeu 212444
# 2024-08-01 21:24:38,511 - INFO - Traitement du game_id : 212445
# 2024-08-01 21:24:38,741 - WARNING - Pas de données pour le jeu 212445
# 2024-08-01 21:24:40,094 - INFO - Traitement du game_id : 212446
# 2024-08-01 21:24:40,348 - WARNING - Pas de données pour le jeu 212446
# 2024-08-01 21:24:42,040 - INFO - Traitement du game_id : 212447
# 2024-08-01 21:24:42,282 - WARNING - Pas de données pour le jeu 212447
# 2024-08-01 21:24:43,674 - INFO - Traitement du game_id : 212448
# 2024-08-01 21:24:43,927 - WARNING - Pas de données pour le jeu 212448
# 2024-08-01 21:24:44,874 - INFO - Traitement du game_id : 212449
# 2024-08-01 21:24:45,082 - WARNING - Pas de données pour le jeu 212449
# 2024-08-01 21:24:46,586 - INFO - Traitement du game_id : 212450
# 2024-08-01 21:24:46,820 - WARNING - Pas de données pour le jeu 212450
# 2024-08-01 21:24:47,757 - INFO - Traitement du game_id : 212480
# 2024-08-01 21:24:47,952 - INFO - Détails récupérés pour le jeu 212480
# 2024-08-01 21:24:48,559 - INFO - Informations de la page Steam récupérées pour le jeu 212480
# 2024-08-01 21:24:49,556 - INFO - Traitement du game_id : 212500
# 2024-08-01 21:24:49,865 - INFO - Détails récupérés pour le jeu 212500
# 2024-08-01 21:24:50,334 - INFO - Informations de la page Steam récupérées pour le jeu 212500
# 2024-08-01 21:24:51,182 - INFO - Traitement du game_id : 212541
# 2024-08-01 21:24:51,399 - WARNING - Pas de données pour le jeu 212541
# 2024-08-01 21:24:52,195 - INFO - Traitement du game_id : 212542
# 2024-08-01 21:24:52,413 - WARNING - Pas de données pour le jeu 212542
# 2024-08-01 21:24:52,968 - INFO - Traitement du game_id : 212560
# 2024-08-01 21:24:53,188 - INFO - Détails récupérés pour le jeu 212560
# 2024-08-01 21:24:53,680 - INFO - Informations de la page Steam récupérées pour le jeu 212560
# 2024-08-01 21:24:55,307 - INFO - Traitement du game_id : 212580
# 2024-08-01 21:24:55,604 - WARNING - Pas de données pour le jeu 212580
# 2024-08-01 21:24:57,088 - INFO - Traitement du game_id : 212601
# 2024-08-01 21:24:57,293 - WARNING - Pas de données pour le jeu 212601
# 2024-08-01 21:24:57,860 - INFO - Traitement du game_id : 212602
# 2024-08-01 21:24:58,088 - WARNING - Pas de données pour le jeu 212602
# 2024-08-01 21:24:58,927 - INFO - Traitement du game_id : 212603
# 2024-08-01 21:24:59,156 - WARNING - Pas de données pour le jeu 212603
# 2024-08-01 21:25:00,786 - INFO - Traitement du game_id : 212604
# 2024-08-01 21:25:01,283 - WARNING - Pas de données pour le jeu 212604
# 2024-08-01 21:25:02,664 - INFO - Traitement du game_id : 212630
# 2024-08-01 21:25:02,930 - INFO - Détails récupérés pour le jeu 212630
# 2024-08-01 21:25:03,573 - INFO - Informations de la page Steam récupérées pour le jeu 212630
# 2024-08-01 21:25:04,802 - INFO - Traitement du game_id : 212675
# 2024-08-01 21:25:05,163 - WARNING - Pas de données pour le jeu 212675
# 2024-08-01 21:25:05,709 - INFO - Traitement du game_id : 212676
# 2024-08-01 21:25:05,935 - WARNING - Pas de données pour le jeu 212676
# 2024-08-01 21:25:07,343 - INFO - Traitement du game_id : 212677
# 2024-08-01 21:25:07,559 - WARNING - Pas de données pour le jeu 212677
# 2024-08-01 21:25:09,152 - INFO - Traitement du game_id : 212680
# 2024-08-01 21:25:09,379 - INFO - Détails récupérés pour le jeu 212680
# 2024-08-01 21:25:09,893 - INFO - Informations de la page Steam récupérées pour le jeu 212680
# 2024-08-01 21:25:11,515 - INFO - Traitement du game_id : 212700
# 2024-08-01 21:25:11,870 - INFO - Détails récupérés pour le jeu 212700
# 2024-08-01 21:25:12,558 - INFO - Informations de la page Steam récupérées pour le jeu 212700
# 2024-08-01 21:25:14,115 - INFO - Traitement du game_id : 212710
# 2024-08-01 21:25:14,677 - INFO - Détails récupérés pour le jeu 212710
# 2024-08-01 21:25:16,399 - INFO - Informations de la page Steam récupérées pour le jeu 212710
# 2024-08-01 21:25:17,105 - INFO - Traitement du game_id : 212720
# 2024-08-01 21:25:17,349 - WARNING - Pas de données pour le jeu 212720
# 2024-08-01 21:25:18,916 - INFO - Traitement du game_id : 212780
# 2024-08-01 21:25:19,163 - INFO - Détails récupérés pour le jeu 212780
# 2024-08-01 21:25:20,019 - INFO - Informations de la page Steam récupérées pour le jeu 212780
# 2024-08-01 21:25:21,424 - INFO - Traitement du game_id : 212800
# 2024-08-01 21:25:21,665 - INFO - Détails récupérés pour le jeu 212800
# 2024-08-01 21:25:22,143 - INFO - Informations de la page Steam récupérées pour le jeu 212800
# 2024-08-01 21:25:22,673 - INFO - Traitement du game_id : 212840
# 2024-08-01 21:25:23,141 - INFO - Détails récupérés pour le jeu 212840
# 2024-08-01 21:25:23,953 - INFO - Informations de la page Steam récupérées pour le jeu 212840
# 2024-08-01 21:25:25,647 - INFO - Traitement du game_id : 212860
# 2024-08-01 21:25:25,882 - INFO - Détails récupérés pour le jeu 212860
# 2024-08-01 21:25:26,525 - INFO - Informations de la page Steam récupérées pour le jeu 212860
# 2024-08-01 21:25:27,838 - INFO - Traitement du game_id : 212890
# 2024-08-01 21:25:28,081 - INFO - Détails récupérés pour le jeu 212890
# 2024-08-01 21:25:28,610 - INFO - Informations de la page Steam récupérées pour le jeu 212890
# 2024-08-01 21:25:29,364 - INFO - Traitement du game_id : 212891
# 2024-08-01 21:25:29,576 - WARNING - Pas de données pour le jeu 212891
# 2024-08-01 21:25:30,551 - INFO - Traitement du game_id : 212892
# 2024-08-01 21:25:30,888 - WARNING - Pas de données pour le jeu 212892
# 2024-08-01 21:25:31,700 - INFO - Traitement du game_id : 212893
# 2024-08-01 21:25:31,972 - INFO - Détails récupérés pour le jeu 212893
# 2024-08-01 21:25:32,432 - INFO - Informations de la page Steam récupérées pour le jeu 212893
# 2024-08-01 21:25:33,761 - INFO - Traitement du game_id : 212894
# 2024-08-01 21:25:34,594 - INFO - Détails récupérés pour le jeu 212894
# 2024-08-01 21:25:35,193 - INFO - Informations de la page Steam récupérées pour le jeu 212894
# 2024-08-01 21:25:35,790 - INFO - Traitement du game_id : 212910
# 2024-08-01 21:25:36,054 - INFO - Détails récupérés pour le jeu 212910
# 2024-08-01 21:25:36,943 - INFO - Informations de la page Steam récupérées pour le jeu 212910
# 2024-08-01 21:25:38,441 - INFO - Traitement du game_id : 213030
# 2024-08-01 21:25:38,746 - INFO - Détails récupérés pour le jeu 213030
# 2024-08-01 21:25:39,468 - INFO - Informations de la page Steam récupérées pour le jeu 213030
# 2024-08-01 21:25:40,898 - INFO - Traitement du game_id : 213040
# 2024-08-01 21:25:41,209 - WARNING - Pas de données pour le jeu 213040
# 2024-08-01 21:25:42,838 - INFO - Traitement du game_id : 213050
# 2024-08-01 21:25:43,043 - WARNING - Pas de données pour le jeu 213050
# 2024-08-01 21:25:44,605 - INFO - Traitement du game_id : 213151
# 2024-08-01 21:25:44,915 - WARNING - Pas de données pour le jeu 213151
# 2024-08-01 21:25:46,576 - INFO - Traitement du game_id : 213152
# 2024-08-01 21:25:46,801 - WARNING - Pas de données pour le jeu 213152
# 2024-08-01 21:25:48,117 - INFO - Traitement du game_id : 213174
# 2024-08-01 21:25:48,330 - WARNING - Pas de données pour le jeu 213174
# 2024-08-01 21:25:49,227 - INFO - Traitement du game_id : 213176
# 2024-08-01 21:25:49,583 - INFO - Détails récupérés pour le jeu 213176
# 2024-08-01 21:25:50,302 - INFO - Informations de la page Steam récupérées pour le jeu 213176
# 2024-08-01 21:25:51,501 - INFO - Traitement du game_id : 213178
# 2024-08-01 21:25:51,836 - WARNING - Pas de données pour le jeu 213178
# 2024-08-01 21:25:53,051 - INFO - Traitement du game_id : 213179
# 2024-08-01 21:25:53,259 - WARNING - Pas de données pour le jeu 213179
# 2024-08-01 21:25:54,069 - INFO - Traitement du game_id : 213194
# 2024-08-01 21:25:54,263 - WARNING - Pas de données pour le jeu 213194
# 2024-08-01 21:25:55,128 - INFO - Traitement du game_id : 213196
# 2024-08-01 21:25:55,331 - WARNING - Pas de données pour le jeu 213196
# 2024-08-01 21:25:56,044 - INFO - Traitement du game_id : 213210
# 2024-08-01 21:25:56,276 - INFO - Détails récupérés pour le jeu 213210
# 2024-08-01 21:25:56,987 - INFO - Informations de la page Steam récupérées pour le jeu 213210
# 2024-08-01 21:25:57,588 - INFO - Traitement du game_id : 213230
# 2024-08-01 21:25:57,796 - INFO - Détails récupérés pour le jeu 213230
# 2024-08-01 21:25:58,352 - INFO - Informations de la page Steam récupérées pour le jeu 213230
# 2024-08-01 21:25:59,235 - INFO - Traitement du game_id : 213231
# 2024-08-01 21:25:59,438 - WARNING - Pas de données pour le jeu 213231
# 2024-08-01 21:25:59,949 - INFO - Traitement du game_id : 213250
# 2024-08-01 21:26:00,144 - INFO - Détails récupérés pour le jeu 213250
# 2024-08-01 21:26:00,730 - INFO - Informations de la page Steam récupérées pour le jeu 213250
# 2024-08-01 21:26:01,796 - INFO - Traitement du game_id : 213311
# 2024-08-01 21:26:02,118 - INFO - Détails récupérés pour le jeu 213311
# 2024-08-01 21:26:02,861 - INFO - Informations de la page Steam récupérées pour le jeu 213311
# 2024-08-01 21:26:03,860 - INFO - Traitement du game_id : 213312
# 2024-08-01 21:26:04,094 - INFO - Détails récupérés pour le jeu 213312
# 2024-08-01 21:26:04,866 - INFO - Informations de la page Steam récupérées pour le jeu 213312
# 2024-08-01 21:26:05,949 - INFO - Traitement du game_id : 213330
# 2024-08-01 21:26:06,252 - INFO - Détails récupérés pour le jeu 213330
# 2024-08-01 21:26:06,710 - INFO - Informations de la page Steam récupérées pour le jeu 213330
# 2024-08-01 21:26:07,276 - INFO - Traitement du game_id : 213350
# 2024-08-01 21:26:07,543 - INFO - Détails récupérés pour le jeu 213350
# 2024-08-01 21:26:08,158 - INFO - Informations de la page Steam récupérées pour le jeu 213350
# 2024-08-01 21:26:09,135 - INFO - Traitement du game_id : 213390
# 2024-08-01 21:26:09,363 - INFO - Détails récupérés pour le jeu 213390
# 2024-08-01 21:26:10,023 - INFO - Informations de la page Steam récupérées pour le jeu 213390
# 2024-08-01 21:26:11,317 - INFO - Traitement du game_id : 213410
# 2024-08-01 21:26:11,560 - WARNING - Pas de données pour le jeu 213410
# 2024-08-01 21:26:13,234 - INFO - Traitement du game_id : 213430
# 2024-08-01 21:26:13,481 - WARNING - Pas de données pour le jeu 213430
# 2024-08-01 21:26:14,160 - INFO - Traitement du game_id : 213450
# 2024-08-01 21:26:14,532 - INFO - Détails récupérés pour le jeu 213450
# 2024-08-01 21:26:15,360 - INFO - Informations de la page Steam récupérées pour le jeu 213450
# 2024-08-01 21:26:16,681 - INFO - Traitement du game_id : 213470
# 2024-08-01 21:26:16,891 - WARNING - Pas de données pour le jeu 213470
# 2024-08-01 21:26:17,897 - INFO - Traitement du game_id : 213490
# 2024-08-01 21:26:18,120 - INFO - Détails récupérés pour le jeu 213490
# 2024-08-01 21:26:18,599 - INFO - Informations de la page Steam récupérées pour le jeu 213490
# 2024-08-01 21:26:19,555 - INFO - Traitement du game_id : 213530
# 2024-08-01 21:26:19,788 - WARNING - Pas de données pour le jeu 213530
# 2024-08-01 21:26:20,992 - INFO - Traitement du game_id : 213550
# 2024-08-01 21:26:21,199 - WARNING - Pas de données pour le jeu 213550
# 2024-08-01 21:26:21,731 - INFO - Traitement du game_id : 213570
# 2024-08-01 21:26:21,938 - WARNING - Pas de données pour le jeu 213570
# 2024-08-01 21:26:22,461 - INFO - Traitement du game_id : 213590
# 2024-08-01 21:26:22,713 - WARNING - Pas de données pour le jeu 213590
# 2024-08-01 21:26:23,984 - INFO - Traitement du game_id : 213610
# 2024-08-01 21:26:24,170 - INFO - Détails récupérés pour le jeu 213610
# 2024-08-01 21:26:25,026 - INFO - Informations de la page Steam récupérées pour le jeu 213610
# 2024-08-01 21:26:26,205 - INFO - Traitement du game_id : 213630
# 2024-08-01 21:26:26,447 - WARNING - Pas de données pour le jeu 213630
# 2024-08-01 21:26:27,766 - INFO - Traitement du game_id : 213650
# 2024-08-01 21:26:28,063 - INFO - Détails récupérés pour le jeu 213650
# 2024-08-01 21:26:28,710 - INFO - Informations de la page Steam récupérées pour le jeu 213650
# 2024-08-01 21:26:30,013 - INFO - Traitement du game_id : 213661
# 2024-08-01 21:26:30,331 - INFO - Détails récupérés pour le jeu 213661
# 2024-08-01 21:26:30,783 - INFO - Informations de la page Steam récupérées pour le jeu 213661
# 2024-08-01 21:26:32,263 - INFO - Traitement du game_id : 213662
# 2024-08-01 21:26:32,509 - INFO - Détails récupérés pour le jeu 213662
# 2024-08-01 21:26:32,910 - INFO - Informations de la page Steam récupérées pour le jeu 213662
# 2024-08-01 21:26:33,551 - INFO - Traitement du game_id : 213663
# 2024-08-01 21:26:33,950 - INFO - Détails récupérés pour le jeu 213663
# 2024-08-01 21:26:34,292 - INFO - Informations de la page Steam récupérées pour le jeu 213663
# 2024-08-01 21:26:35,039 - INFO - Traitement du game_id : 213664
# 2024-08-01 21:26:35,292 - INFO - Détails récupérés pour le jeu 213664
# 2024-08-01 21:26:35,653 - INFO - Informations de la page Steam récupérées pour le jeu 213664
# 2024-08-01 21:26:37,149 - INFO - Traitement du game_id : 213665
# 2024-08-01 21:26:37,476 - INFO - Détails récupérés pour le jeu 213665
# 2024-08-01 21:26:37,846 - INFO - Informations de la page Steam récupérées pour le jeu 213665
# 2024-08-01 21:26:39,254 - INFO - Traitement du game_id : 213670
# 2024-08-01 21:26:39,485 - INFO - Détails récupérés pour le jeu 213670
# 2024-08-01 21:26:39,940 - INFO - Informations de la page Steam récupérées pour le jeu 213670
# 2024-08-01 21:26:40,732 - INFO - Traitement du game_id : 213780
# 2024-08-01 21:26:40,955 - INFO - Détails récupérés pour le jeu 213780
# 2024-08-01 21:26:41,503 - INFO - Informations de la page Steam récupérées pour le jeu 213780
# 2024-08-01 21:26:42,405 - INFO - Traitement du game_id : 213781
# 2024-08-01 21:26:42,671 - WARNING - Pas de données pour le jeu 213781
# 2024-08-01 21:26:43,205 - INFO - Traitement du game_id : 213870
# 2024-08-01 21:26:43,652 - INFO - Détails récupérés pour le jeu 213870
# 2024-08-01 21:26:44,521 - INFO - Informations de la page Steam récupérées pour le jeu 213870
# 2024-08-01 21:26:46,147 - INFO - Traitement du game_id : 213910
# 2024-08-01 21:26:46,396 - INFO - Détails récupérés pour le jeu 213910
# 2024-08-01 21:26:47,035 - INFO - Informations de la page Steam récupérées pour le jeu 213910
# 2024-08-01 21:26:48,367 - INFO - Traitement du game_id : 213930
# 2024-08-01 21:26:48,627 - INFO - Détails récupérés pour le jeu 213930
# 2024-08-01 21:26:49,092 - INFO - Informations de la page Steam récupérées pour le jeu 213930
# 2024-08-01 21:26:50,197 - INFO - Traitement du game_id : 214050
# 2024-08-01 21:26:50,403 - WARNING - Pas de données pour le jeu 214050
# 2024-08-01 21:26:51,695 - INFO - Traitement du game_id : 214070
# 2024-08-01 21:26:51,914 - INFO - Détails récupérés pour le jeu 214070
# 2024-08-01 21:26:52,956 - INFO - Informations de la page Steam récupérées pour le jeu 214070
# 2024-08-01 21:26:53,695 - INFO - Traitement du game_id : 214090
# 2024-08-01 21:26:53,918 - INFO - Détails récupérés pour le jeu 214090
# 2024-08-01 21:26:54,641 - INFO - Informations de la page Steam récupérées pour le jeu 214090
# 2024-08-01 21:26:55,870 - INFO - Traitement du game_id : 214100
# 2024-08-01 21:26:56,258 - INFO - Détails récupérés pour le jeu 214100
# 2024-08-01 21:26:56,788 - INFO - Informations de la page Steam récupérées pour le jeu 214100
# 2024-08-01 21:26:58,000 - INFO - Traitement du game_id : 214150
# 2024-08-01 21:26:58,278 - INFO - Détails récupérés pour le jeu 214150
# 2024-08-01 21:26:58,815 - INFO - Informations de la page Steam récupérées pour le jeu 214150
# 2024-08-01 21:26:59,589 - INFO - Traitement du game_id : 214170
# 2024-08-01 21:26:59,986 - INFO - Détails récupérés pour le jeu 214170
# 2024-08-01 21:27:00,580 - INFO - Informations de la page Steam récupérées pour le jeu 214170
# 2024-08-01 21:27:01,128 - INFO - Traitement du game_id : 214230
# 2024-08-01 21:27:01,375 - WARNING - Pas de données pour le jeu 214230
# 2024-08-01 21:27:02,841 - INFO - Traitement du game_id : 214250
# 2024-08-01 21:27:03,056 - INFO - Détails récupérés pour le jeu 214250
# 2024-08-01 21:27:03,589 - INFO - Informations de la page Steam récupérées pour le jeu 214250
# 2024-08-01 21:27:04,102 - INFO - Traitement du game_id : 214270
# 2024-08-01 21:27:04,407 - WARNING - Pas de données pour le jeu 214270
# 2024-08-01 21:27:06,070 - INFO - Traitement du game_id : 214291
# 2024-08-01 21:27:06,278 - WARNING - Pas de données pour le jeu 214291
# 2024-08-01 21:27:06,892 - INFO - Traitement du game_id : 214292
# 2024-08-01 21:27:07,165 - WARNING - Pas de données pour le jeu 214292
# 2024-08-01 21:27:08,555 - INFO - Traitement du game_id : 214310
# 2024-08-01 21:27:08,857 - INFO - Détails récupérés pour le jeu 214310
# 2024-08-01 21:27:09,854 - INFO - Informations de la page Steam récupérées pour le jeu 214310
# 2024-08-01 21:27:10,598 - INFO - Traitement du game_id : 214320
# 2024-08-01 21:27:10,809 - WARNING - Pas de données pour le jeu 214320
# 2024-08-01 21:27:11,592 - INFO - Traitement du game_id : 214330
# 2024-08-01 21:27:11,836 - INFO - Détails récupérés pour le jeu 214330
# 2024-08-01 21:27:12,499 - INFO - Informations de la page Steam récupérées pour le jeu 214330
# 2024-08-01 21:27:13,193 - INFO - Traitement du game_id : 214331
# 2024-08-01 21:27:13,431 - INFO - Détails récupérés pour le jeu 214331
# 2024-08-01 21:27:14,283 - INFO - Informations de la page Steam récupérées pour le jeu 214331
# 2024-08-01 21:27:14,895 - INFO - Traitement du game_id : 214340
# 2024-08-01 21:27:15,179 - INFO - Détails récupérés pour le jeu 214340
# 2024-08-01 21:27:15,659 - INFO - Informations de la page Steam récupérées pour le jeu 214340
# 2024-08-01 21:27:17,129 - INFO - Traitement du game_id : 214360
# 2024-08-01 21:27:17,380 - INFO - Détails récupérés pour le jeu 214360
# 2024-08-01 21:27:17,857 - INFO - Informations de la page Steam récupérées pour le jeu 214360
# 2024-08-01 21:27:18,846 - INFO - Traitement du game_id : 214400
# 2024-08-01 21:27:19,051 - WARNING - Pas de données pour le jeu 214400
# 2024-08-01 21:27:20,337 - INFO - Traitement du game_id : 214420
# 2024-08-01 21:27:20,643 - INFO - Détails récupérés pour le jeu 214420
# 2024-08-01 21:27:21,188 - INFO - Informations de la page Steam récupérées pour le jeu 214420
# 2024-08-01 21:27:21,820 - INFO - Traitement du game_id : 214490
# 2024-08-01 21:27:22,091 - INFO - Détails récupérés pour le jeu 214490
# 2024-08-01 21:27:22,584 - INFO - Informations de la page Steam récupérées pour le jeu 214490
# 2024-08-01 21:27:24,030 - INFO - Traitement du game_id : 214510
# 2024-08-01 21:27:24,313 - INFO - Détails récupérés pour le jeu 214510
# 2024-08-01 21:27:24,875 - INFO - Informations de la page Steam récupérées pour le jeu 214510
# 2024-08-01 21:27:25,728 - INFO - Traitement du game_id : 214530
# 2024-08-01 21:27:26,041 - INFO - Détails récupérés pour le jeu 214530
# 2024-08-01 21:27:26,539 - INFO - Informations de la page Steam récupérées pour le jeu 214530
# 2024-08-01 21:27:27,954 - INFO - Traitement du game_id : 214531
# 2024-08-01 21:27:28,157 - WARNING - Pas de données pour le jeu 214531
# 2024-08-01 21:27:29,706 - INFO - Traitement du game_id : 214550
# 2024-08-01 21:27:29,928 - INFO - Détails récupérés pour le jeu 214550
# 2024-08-01 21:27:30,674 - INFO - Informations de la page Steam récupérées pour le jeu 214550
# 2024-08-01 21:27:31,262 - INFO - Traitement du game_id : 214560
# 2024-08-01 21:27:31,527 - INFO - Détails récupérés pour le jeu 214560
# 2024-08-01 21:27:31,972 - INFO - Informations de la page Steam récupérées pour le jeu 214560
# 2024-08-01 21:27:32,754 - INFO - Traitement du game_id : 214570
# 2024-08-01 21:27:33,018 - INFO - Détails récupérés pour le jeu 214570
# 2024-08-01 21:27:33,843 - INFO - Informations de la page Steam récupérées pour le jeu 214570
# 2024-08-01 21:27:34,775 - INFO - Traitement du game_id : 214590
# 2024-08-01 21:27:35,030 - INFO - Détails récupérés pour le jeu 214590
# 2024-08-01 21:27:35,684 - INFO - Informations de la page Steam récupérées pour le jeu 214590
# 2024-08-01 21:27:36,533 - INFO - Traitement du game_id : 214630
# 2024-08-01 21:27:36,784 - INFO - Détails récupérés pour le jeu 214630
# 2024-08-01 21:27:37,338 - INFO - Informations de la page Steam récupérées pour le jeu 214630
# 2024-08-01 21:27:38,485 - INFO - Traitement du game_id : 214640
# 2024-08-01 21:27:38,948 - WARNING - Pas de données pour le jeu 214640
# 2024-08-01 21:27:40,299 - INFO - Traitement du game_id : 214643
# 2024-08-01 21:27:40,551 - INFO - Détails récupérés pour le jeu 214643
# 2024-08-01 21:27:41,185 - INFO - Informations de la page Steam récupérées pour le jeu 214643
# 2024-08-01 21:27:42,495 - INFO - Traitement du game_id : 214644
# 2024-08-01 21:27:42,715 - WARNING - Pas de données pour le jeu 214644
# 2024-08-01 21:27:43,276 - INFO - Traitement du game_id : 214645
# 2024-08-01 21:27:43,500 - WARNING - Pas de données pour le jeu 214645
# 2024-08-01 21:27:44,357 - INFO - Traitement du game_id : 214646
# 2024-08-01 21:27:44,567 - WARNING - Pas de données pour le jeu 214646
# 2024-08-01 21:27:46,125 - INFO - Traitement du game_id : 214647
# 2024-08-01 21:27:46,346 - WARNING - Pas de données pour le jeu 214647
# 2024-08-01 21:27:47,522 - INFO - Traitement du game_id : 214648
# 2024-08-01 21:27:47,728 - WARNING - Pas de données pour le jeu 214648
# 2024-08-01 21:27:48,653 - INFO - Traitement du game_id : 214649
# 2024-08-01 21:27:48,874 - INFO - Détails récupérés pour le jeu 214649
# 2024-08-01 21:27:49,366 - INFO - Informations de la page Steam récupérées pour le jeu 214649
# 2024-08-01 21:27:49,969 - INFO - Traitement du game_id : 214652
# 2024-08-01 21:27:50,177 - WARNING - Pas de données pour le jeu 214652
# 2024-08-01 21:27:51,688 - INFO - Traitement du game_id : 214653
# 2024-08-01 21:27:51,903 - WARNING - Pas de données pour le jeu 214653
# 2024-08-01 21:27:52,668 - INFO - Traitement du game_id : 214700
# 2024-08-01 21:27:53,025 - INFO - Détails récupérés pour le jeu 214700
# 2024-08-01 21:27:53,616 - INFO - Informations de la page Steam récupérées pour le jeu 214700
# 2024-08-01 21:27:54,661 - INFO - Traitement du game_id : 214710
# 2024-08-01 21:27:54,897 - INFO - Détails récupérés pour le jeu 214710
# 2024-08-01 21:27:55,794 - INFO - Informations de la page Steam récupérées pour le jeu 214710
# 2024-08-01 21:27:56,432 - INFO - Traitement du game_id : 214730
# 2024-08-01 21:27:56,732 - INFO - Détails récupérés pour le jeu 214730
# 2024-08-01 21:27:57,362 - INFO - Informations de la page Steam récupérées pour le jeu 214730
# 2024-08-01 21:27:58,172 - INFO - Traitement du game_id : 214770
# 2024-08-01 21:27:58,560 - INFO - Détails récupérés pour le jeu 214770
# 2024-08-01 21:27:59,399 - INFO - Informations de la page Steam récupérées pour le jeu 214770
# 2024-08-01 21:28:00,167 - INFO - Traitement du game_id : 214790
# 2024-08-01 21:28:00,458 - INFO - Détails récupérés pour le jeu 214790
# 2024-08-01 21:28:01,119 - INFO - Informations de la page Steam récupérées pour le jeu 214790
# 2024-08-01 21:28:02,420 - INFO - Traitement du game_id : 214810
# 2024-08-01 21:28:02,748 - INFO - Détails récupérés pour le jeu 214810
# 2024-08-01 21:28:03,432 - INFO - Informations de la page Steam récupérées pour le jeu 214810
# 2024-08-01 21:28:04,435 - INFO - Traitement du game_id : 214820
# 2024-08-01 21:28:04,670 - INFO - Détails récupérés pour le jeu 214820
# 2024-08-01 21:28:05,729 - INFO - Informations de la page Steam récupérées pour le jeu 214820
# 2024-08-01 21:28:06,350 - INFO - Traitement du game_id : 214830
# 2024-08-01 21:28:06,625 - INFO - Détails récupérés pour le jeu 214830
# 2024-08-01 21:28:07,315 - INFO - Informations de la page Steam récupérées pour le jeu 214830
# 2024-08-01 21:28:08,071 - INFO - Traitement du game_id : 214850
# 2024-08-01 21:28:08,281 - WARNING - Pas de données pour le jeu 214850
# 2024-08-01 21:28:09,553 - INFO - Traitement du game_id : 214870
# 2024-08-01 21:28:09,834 - INFO - Détails récupérés pour le jeu 214870
# 2024-08-01 21:28:10,559 - INFO - Informations de la page Steam récupérées pour le jeu 214870
# 2024-08-01 21:28:11,875 - INFO - Traitement du game_id : 214910
# 2024-08-01 21:28:12,123 - INFO - Détails récupérés pour le jeu 214910
# 2024-08-01 21:28:12,771 - INFO - Informations de la page Steam récupérées pour le jeu 214910
# 2024-08-01 21:28:13,500 - INFO - Traitement du game_id : 214929
# 2024-08-01 21:28:13,699 - WARNING - Pas de données pour le jeu 214929
# 2024-08-01 21:28:14,415 - INFO - Traitement du game_id : 214930
# 2024-08-01 21:28:14,646 - INFO - Détails récupérés pour le jeu 214930
# 2024-08-01 21:28:15,194 - INFO - Informations de la page Steam récupérées pour le jeu 214930
# 2024-08-01 21:28:16,225 - INFO - Traitement du game_id : 214931
# 2024-08-01 21:28:16,458 - INFO - Détails récupérés pour le jeu 214931
# 2024-08-01 21:28:16,937 - INFO - Informations de la page Steam récupérées pour le jeu 214931
# 2024-08-01 21:28:18,323 - INFO - Traitement du game_id : 214932
# 2024-08-01 21:28:18,607 - INFO - Détails récupérés pour le jeu 214932
# 2024-08-01 21:28:19,077 - INFO - Informations de la page Steam récupérées pour le jeu 214932
# 2024-08-01 21:28:19,654 - INFO - Traitement du game_id : 214933
# 2024-08-01 21:28:19,958 - INFO - Détails récupérés pour le jeu 214933
# 2024-08-01 21:28:20,638 - INFO - Informations de la page Steam récupérées pour le jeu 214933
# 2024-08-01 21:28:21,239 - INFO - Traitement du game_id : 214934
# 2024-08-01 21:28:21,454 - WARNING - Pas de données pour le jeu 214934
# 2024-08-01 21:28:22,447 - INFO - Traitement du game_id : 214935
# 2024-08-01 21:28:23,163 - WARNING - Pas de données pour le jeu 214935
# 2024-08-01 21:28:24,646 - INFO - Traitement du game_id : 214936
# 2024-08-01 21:28:24,856 - WARNING - Pas de données pour le jeu 214936
# 2024-08-01 21:28:26,106 - INFO - Traitement du game_id : 214937
# 2024-08-01 21:28:26,336 - WARNING - Pas de données pour le jeu 214937
# 2024-08-01 21:28:27,977 - INFO - Traitement du game_id : 214950
# 2024-08-01 21:28:28,339 - INFO - Détails récupérés pour le jeu 214950
# 2024-08-01 21:28:28,862 - INFO - Informations de la page Steam récupérées pour le jeu 214950
# 2024-08-01 21:28:29,993 - INFO - Traitement du game_id : 214970
# 2024-08-01 21:28:30,444 - INFO - Détails récupérés pour le jeu 214970
# 2024-08-01 21:28:30,964 - INFO - Informations de la page Steam récupérées pour le jeu 214970
# 2024-08-01 21:28:31,595 - INFO - Traitement du game_id : 214980
# 2024-08-01 21:28:31,836 - INFO - Détails récupérés pour le jeu 214980
# 2024-08-01 21:28:32,389 - INFO - Informations de la page Steam récupérées pour le jeu 214980
# 2024-08-01 21:28:33,304 - INFO - Traitement du game_id : 214981
# 2024-08-01 21:28:33,587 - INFO - Détails récupérés pour le jeu 214981
# 2024-08-01 21:28:34,218 - INFO - Informations de la page Steam récupérées pour le jeu 214981
# 2024-08-01 21:28:35,277 - INFO - Traitement du game_id : 214982
# 2024-08-01 21:28:35,505 - WARNING - Pas de données pour le jeu 214982
# 2024-08-01 21:28:36,726 - INFO - Traitement du game_id : 214983
# 2024-08-01 21:28:36,942 - WARNING - Pas de données pour le jeu 214983
# 2024-08-01 21:28:38,382 - INFO - Traitement du game_id : 214984
# 2024-08-01 21:28:38,612 - WARNING - Pas de données pour le jeu 214984
# 2024-08-01 21:28:39,408 - INFO - Traitement du game_id : 214985
# 2024-08-01 21:28:39,647 - WARNING - Pas de données pour le jeu 214985
# 2024-08-01 21:28:40,171 - INFO - Traitement du game_id : 214986
# 2024-08-01 21:28:40,417 - INFO - Détails récupérés pour le jeu 214986
# 2024-08-01 21:28:41,056 - INFO - Informations de la page Steam récupérées pour le jeu 214986
# 2024-08-01 21:28:42,742 - INFO - Traitement du game_id : 214987
# 2024-08-01 21:28:42,964 - INFO - Détails récupérés pour le jeu 214987
# 2024-08-01 21:28:43,430 - INFO - Informations de la page Steam récupérées pour le jeu 214987
# 2024-08-01 21:28:45,023 - INFO - Traitement du game_id : 214988
# 2024-08-01 21:28:45,297 - INFO - Détails récupérés pour le jeu 214988
# 2024-08-01 21:28:45,702 - INFO - Informations de la page Steam récupérées pour le jeu 214988
# 2024-08-01 21:28:46,931 - INFO - Traitement du game_id : 214990
# 2024-08-01 21:28:47,155 - INFO - Détails récupérés pour le jeu 214990
# 2024-08-01 21:28:47,689 - INFO - Informations de la page Steam récupérées pour le jeu 214990
# 2024-08-01 21:28:48,656 - INFO - Traitement du game_id : 214991
# 2024-08-01 21:28:48,883 - INFO - Détails récupérés pour le jeu 214991
# 2024-08-01 21:28:49,539 - INFO - Informations de la page Steam récupérées pour le jeu 214991
# 2024-08-01 21:28:50,628 - INFO - Traitement du game_id : 215000
# 2024-08-01 21:28:50,817 - INFO - Détails récupérés pour le jeu 215000
# 2024-08-01 21:28:51,493 - INFO - Informations de la page Steam récupérées pour le jeu 215000
# 2024-08-01 21:28:52,822 - INFO - Traitement du game_id : 215001
# 2024-08-01 21:28:53,000 - INFO - Détails récupérés pour le jeu 215001
# 2024-08-01 21:28:53,402 - INFO - Informations de la page Steam récupérées pour le jeu 215001
# 2024-08-01 21:28:54,452 - INFO - Traitement du game_id : 215002
# 2024-08-01 21:28:54,644 - INFO - Détails récupérés pour le jeu 215002
# 2024-08-01 21:28:55,064 - INFO - Informations de la page Steam récupérées pour le jeu 215002
# 2024-08-01 21:28:56,049 - INFO - Traitement du game_id : 215003
# 2024-08-01 21:28:56,247 - INFO - Détails récupérés pour le jeu 215003
# 2024-08-01 21:28:56,624 - INFO - Informations de la page Steam récupérées pour le jeu 215003
# 2024-08-01 21:28:57,534 - INFO - Traitement du game_id : 215004
# 2024-08-01 21:28:57,721 - INFO - Détails récupérés pour le jeu 215004
# 2024-08-01 21:28:58,180 - INFO - Informations de la page Steam récupérées pour le jeu 215004
# 2024-08-01 21:28:58,917 - INFO - Traitement du game_id : 215005
# 2024-08-01 21:28:59,108 - INFO - Détails récupérés pour le jeu 215005
# 2024-08-01 21:28:59,519 - INFO - Informations de la page Steam récupérées pour le jeu 215005
# 2024-08-01 21:29:01,049 - INFO - Traitement du game_id : 215020
# 2024-08-01 21:29:01,307 - INFO - Détails récupérés pour le jeu 215020
# 2024-08-01 21:29:02,080 - INFO - Informations de la page Steam récupérées pour le jeu 215020
# 2024-08-01 21:29:03,703 - INFO - Traitement du game_id : 215060
# 2024-08-01 21:29:03,994 - WARNING - Pas de données pour le jeu 215060
# 2024-08-01 21:29:04,874 - INFO - Traitement du game_id : 215080
# 2024-08-01 21:29:05,195 - INFO - Détails récupérés pour le jeu 215080
# 2024-08-01 21:29:05,739 - INFO - Informations de la page Steam récupérées pour le jeu 215080
# ...
# 2024-08-02 02:46:45,800 - INFO - Informations de la page Steam récupérées pour le jeu 354461
# 2024-08-02 02:46:47,126 - INFO - Traitement du game_id : 354462
# 2024-08-02 02:46:47,365 - INFO - Détails récupérés pour le jeu 354462
# 2024-08-02 02:46:47,894 - INFO - Informations de la page Steam récupérées pour le jeu 354462
# 2024-08-02 02:46:48,708 - INFO - Traitement du game_id : 354463
# 2024-08-02 02:46:48,960 - INFO - Détails récupérés pour le jeu 354463
# 2024-08-02 02:46:49,477 - INFO - Informations de la page Steam récupérées pour le jeu 354463
# 2024-08-02 02:46:51,164 - INFO - Traitement du game_id : 354464
# 2024-08-02 02:46:51,399 - INFO - Détails récupérés pour le jeu 354464
# 2024-08-02 02:46:51,816 - INFO - Informations de la page Steam récupérées pour le jeu 354464
# 2024-08-02 02:46:53,164 - INFO - Traitement du game_id : 354465
# 2024-08-02 02:46:53,497 - INFO - Détails récupérés pour le jeu 354465
# 2024-08-02 02:46:53,918 - INFO - Informations de la page Steam récupérées pour le jeu 354465
# 2024-08-02 02:46:55,490 - INFO - Traitement du game_id : 354466
# 2024-08-02 02:46:55,727 - INFO - Détails récupérés pour le jeu 354466
# 2024-08-02 02:46:56,134 - INFO - Informations de la page Steam récupérées pour le jeu 354466
# 2024-08-02 02:46:57,199 - INFO - Traitement du game_id : 354467
# 2024-08-02 02:46:57,434 - INFO - Détails récupérés pour le jeu 354467
# 2024-08-02 02:46:57,964 - INFO - Informations de la page Steam récupérées pour le jeu 354467
# 2024-08-02 02:46:59,134 - INFO - Traitement du game_id : 354468
# 2024-08-02 02:46:59,517 - INFO - Détails récupérés pour le jeu 354468
# 2024-08-02 02:47:00,179 - INFO - Informations de la page Steam récupérées pour le jeu 354468
# 2024-08-02 02:47:01,040 - INFO - Traitement du game_id : 354469
# 2024-08-02 02:47:01,272 - INFO - Détails récupérés pour le jeu 354469
# 2024-08-02 02:47:01,776 - INFO - Informations de la page Steam récupérées pour le jeu 354469
# 2024-08-02 02:47:03,211 - INFO - Traitement du game_id : 354500
# 2024-08-02 02:47:03,471 - INFO - Détails récupérés pour le jeu 354500
# 2024-08-02 02:47:03,942 - INFO - Informations de la page Steam récupérées pour le jeu 354500
# 2024-08-02 02:47:05,601 - INFO - Traitement du game_id : 354510
# 2024-08-02 02:47:05,832 - INFO - Détails récupérés pour le jeu 354510
# 2024-08-02 02:47:06,795 - INFO - Informations de la page Steam récupérées pour le jeu 354510
# 2024-08-02 02:47:07,825 - INFO - Traitement du game_id : 354520
# 2024-08-02 02:47:08,099 - INFO - Détails récupérés pour le jeu 354520
# 2024-08-02 02:47:08,882 - INFO - Informations de la page Steam récupérées pour le jeu 354520
# 2024-08-02 02:47:09,415 - INFO - Traitement du game_id : 354530
# 2024-08-02 02:47:09,661 - INFO - Détails récupérés pour le jeu 354530
# 2024-08-02 02:47:10,363 - INFO - Informations de la page Steam récupérées pour le jeu 354530
# 2024-08-02 02:47:11,847 - INFO - Traitement du game_id : 354540
# 2024-08-02 02:47:12,296 - INFO - Détails récupérés pour le jeu 354540
# 2024-08-02 02:47:13,185 - INFO - Informations de la page Steam récupérées pour le jeu 354540
# 2024-08-02 02:47:13,848 - INFO - Traitement du game_id : 354550
# 2024-08-02 02:47:14,067 - INFO - Détails récupérés pour le jeu 354550
# 2024-08-02 02:47:14,906 - INFO - Informations de la page Steam récupérées pour le jeu 354550
# 2024-08-02 02:47:15,447 - INFO - Traitement du game_id : 354560
# 2024-08-02 02:47:15,689 - INFO - Détails récupérés pour le jeu 354560
# 2024-08-02 02:47:16,405 - INFO - Informations de la page Steam récupérées pour le jeu 354560
# 2024-08-02 02:47:17,665 - INFO - Traitement du game_id : 354570
# 2024-08-02 02:47:18,076 - INFO - Détails récupérés pour le jeu 354570
# 2024-08-02 02:47:18,476 - INFO - Informations de la page Steam récupérées pour le jeu 354570
# 2024-08-02 02:47:19,428 - INFO - Traitement du game_id : 354600
# 2024-08-02 02:47:19,679 - INFO - Détails récupérés pour le jeu 354600
# 2024-08-02 02:47:20,449 - INFO - Informations de la page Steam récupérées pour le jeu 354600
# 2024-08-02 02:47:21,406 - INFO - Traitement du game_id : 354620
# 2024-08-02 02:47:21,633 - INFO - Détails récupérés pour le jeu 354620
# 2024-08-02 02:47:22,177 - INFO - Informations de la page Steam récupérées pour le jeu 354620
# 2024-08-02 02:47:23,087 - INFO - Traitement du game_id : 354680
# 2024-08-02 02:47:23,389 - INFO - Détails récupérés pour le jeu 354680
# 2024-08-02 02:47:24,140 - INFO - Informations de la page Steam récupérées pour le jeu 354680
# 2024-08-02 02:47:25,480 - INFO - Traitement du game_id : 354690
# 2024-08-02 02:47:25,816 - INFO - Détails récupérés pour le jeu 354690
# 2024-08-02 02:47:26,475 - INFO - Informations de la page Steam récupérées pour le jeu 354690
# 2024-08-02 02:47:27,390 - INFO - Traitement du game_id : 354700
# 2024-08-02 02:47:27,600 - WARNING - Pas de données pour le jeu 354700
# 2024-08-02 02:47:28,933 - INFO - Traitement du game_id : 354701
# 2024-08-02 02:47:29,136 - WARNING - Pas de données pour le jeu 354701
# 2024-08-02 02:47:29,866 - INFO - Traitement du game_id : 354702
# 2024-08-02 02:47:30,065 - WARNING - Pas de données pour le jeu 354702
# 2024-08-02 02:47:30,945 - INFO - Traitement du game_id : 354720
# 2024-08-02 02:47:31,174 - INFO - Détails récupérés pour le jeu 354720
# 2024-08-02 02:47:32,129 - INFO - Informations de la page Steam récupérées pour le jeu 354720
# 2024-08-02 02:47:33,397 - INFO - Traitement du game_id : 354730
# 2024-08-02 02:47:33,772 - INFO - Détails récupérés pour le jeu 354730
# 2024-08-02 02:47:34,258 - INFO - Informations de la page Steam récupérées pour le jeu 354730
# 2024-08-02 02:47:34,837 - INFO - Traitement du game_id : 354740
# 2024-08-02 02:47:35,154 - INFO - Détails récupérés pour le jeu 354740
# 2024-08-02 02:47:35,872 - INFO - Informations de la page Steam récupérées pour le jeu 354740
# 2024-08-02 02:47:36,860 - INFO - Traitement du game_id : 354770
# 2024-08-02 02:47:37,241 - INFO - Détails récupérés pour le jeu 354770
# 2024-08-02 02:47:38,077 - INFO - Informations de la page Steam récupérées pour le jeu 354770
# 2024-08-02 02:47:39,321 - INFO - Traitement du game_id : 354780
# 2024-08-02 02:47:39,700 - INFO - Détails récupérés pour le jeu 354780
# 2024-08-02 02:47:40,313 - INFO - Informations de la page Steam récupérées pour le jeu 354780
# 2024-08-02 02:47:41,646 - INFO - Traitement du game_id : 354810
# 2024-08-02 02:47:41,902 - INFO - Détails récupérés pour le jeu 354810
# 2024-08-02 02:47:42,446 - INFO - Informations de la page Steam récupérées pour le jeu 354810
# 2024-08-02 02:47:43,794 - INFO - Traitement du game_id : 354820
# 2024-08-02 02:47:44,021 - INFO - Détails récupérés pour le jeu 354820
# 2024-08-02 02:47:44,675 - INFO - Informations de la page Steam récupérées pour le jeu 354820
# 2024-08-02 02:47:45,388 - INFO - Traitement du game_id : 354830
# 2024-08-02 02:47:45,585 - WARNING - Pas de données pour le jeu 354830
# 2024-08-02 02:47:46,306 - INFO - Traitement du game_id : 354860
# 2024-08-02 02:47:46,730 - INFO - Détails récupérés pour le jeu 354860
# 2024-08-02 02:47:47,740 - INFO - Informations de la page Steam récupérées pour le jeu 354860
# 2024-08-02 02:47:49,174 - INFO - Traitement du game_id : 354890
# 2024-08-02 02:47:49,420 - INFO - Détails récupérés pour le jeu 354890
# 2024-08-02 02:47:49,822 - INFO - Informations de la page Steam récupérées pour le jeu 354890
# 2024-08-02 02:47:50,956 - INFO - Traitement du game_id : 354900
# 2024-08-02 02:47:51,195 - INFO - Détails récupérés pour le jeu 354900
# 2024-08-02 02:47:51,666 - INFO - Informations de la page Steam récupérées pour le jeu 354900
# 2024-08-02 02:47:52,872 - INFO - Traitement du game_id : 354920
# 2024-08-02 02:47:53,117 - INFO - Détails récupérés pour le jeu 354920
# 2024-08-02 02:47:53,842 - INFO - Informations de la page Steam récupérées pour le jeu 354920
# 2024-08-02 02:47:55,113 - INFO - Traitement du game_id : 354930
# 2024-08-02 02:47:55,364 - INFO - Détails récupérés pour le jeu 354930
# 2024-08-02 02:47:56,023 - INFO - Informations de la page Steam récupérées pour le jeu 354930
# 2024-08-02 02:47:56,885 - INFO - Traitement du game_id : 354940
# 2024-08-02 02:47:57,117 - INFO - Détails récupérés pour le jeu 354940
# 2024-08-02 02:47:57,557 - INFO - Informations de la page Steam récupérées pour le jeu 354940
# 2024-08-02 02:47:58,313 - INFO - Traitement du game_id : 354950
# 2024-08-02 02:47:58,619 - INFO - Détails récupérés pour le jeu 354950
# 2024-08-02 02:47:59,436 - INFO - Informations de la page Steam récupérées pour le jeu 354950
# 2024-08-02 02:48:00,338 - INFO - Traitement du game_id : 354960
# 2024-08-02 02:48:00,564 - INFO - Détails récupérés pour le jeu 354960
# 2024-08-02 02:48:01,550 - INFO - Informations de la page Steam récupérées pour le jeu 354960
# 2024-08-02 02:48:03,258 - INFO - Traitement du game_id : 354970
# 2024-08-02 02:48:03,517 - INFO - Détails récupérés pour le jeu 354970
# 2024-08-02 02:48:04,691 - INFO - Informations de la page Steam récupérées pour le jeu 354970
# 2024-08-02 02:48:05,257 - INFO - Traitement du game_id : 355010
# 2024-08-02 02:48:05,578 - INFO - Détails récupérés pour le jeu 355010
# 2024-08-02 02:48:06,255 - INFO - Informations de la page Steam récupérées pour le jeu 355010
# 2024-08-02 02:48:07,267 - INFO - Traitement du game_id : 355020
# 2024-08-02 02:48:07,517 - INFO - Détails récupérés pour le jeu 355020
# 2024-08-02 02:48:08,133 - INFO - Informations de la page Steam récupérées pour le jeu 355020
# 2024-08-02 02:48:09,779 - INFO - Traitement du game_id : 355030
# 2024-08-02 02:48:09,986 - WARNING - Pas de données pour le jeu 355030
# 2024-08-02 02:48:10,622 - INFO - Traitement du game_id : 355050
# 2024-08-02 02:48:10,855 - INFO - Détails récupérés pour le jeu 355050
# 2024-08-02 02:48:11,824 - INFO - Informations de la page Steam récupérées pour le jeu 355050
# 2024-08-02 02:48:12,562 - INFO - Traitement du game_id : 355060
# 2024-08-02 02:48:12,880 - INFO - Détails récupérés pour le jeu 355060
# 2024-08-02 02:48:13,666 - INFO - Informations de la page Steam récupérées pour le jeu 355060
# 2024-08-02 02:48:15,334 - INFO - Traitement du game_id : 355070
# 2024-08-02 02:48:15,563 - INFO - Détails récupérés pour le jeu 355070
# 2024-08-02 02:48:16,167 - INFO - Informations de la page Steam récupérées pour le jeu 355070
# 2024-08-02 02:48:17,847 - INFO - Traitement du game_id : 355080
# 2024-08-02 02:48:18,076 - INFO - Détails récupérés pour le jeu 355080
# 2024-08-02 02:48:18,863 - INFO - Informations de la page Steam récupérées pour le jeu 355080
# 2024-08-02 02:48:20,006 - INFO - Traitement du game_id : 355090
# 2024-08-02 02:48:20,375 - INFO - Détails récupérés pour le jeu 355090
# 2024-08-02 02:48:21,302 - INFO - Informations de la page Steam récupérées pour le jeu 355090
# 2024-08-02 02:48:22,727 - INFO - Traitement du game_id : 355100
# 2024-08-02 02:48:23,059 - INFO - Détails récupérés pour le jeu 355100
# 2024-08-02 02:48:23,776 - INFO - Informations de la page Steam récupérées pour le jeu 355100
# 2024-08-02 02:48:24,330 - INFO - Traitement du game_id : 355130
# 2024-08-02 02:48:24,591 - INFO - Détails récupérés pour le jeu 355130
# 2024-08-02 02:48:25,165 - INFO - Informations de la page Steam récupérées pour le jeu 355130
# 2024-08-02 02:48:26,115 - INFO - Traitement du game_id : 355140
# 2024-08-02 02:48:26,395 - INFO - Détails récupérés pour le jeu 355140
# 2024-08-02 02:48:26,933 - INFO - Informations de la page Steam récupérées pour le jeu 355140
# 2024-08-02 02:48:28,192 - INFO - Traitement du game_id : 355150
# 2024-08-02 02:48:28,436 - INFO - Détails récupérés pour le jeu 355150
# 2024-08-02 02:48:29,101 - INFO - Informations de la page Steam récupérées pour le jeu 355150
# 2024-08-02 02:48:30,010 - INFO - Traitement du game_id : 355170
# 2024-08-02 02:48:30,235 - INFO - Détails récupérés pour le jeu 355170
# 2024-08-02 02:48:31,119 - INFO - Informations de la page Steam récupérées pour le jeu 355170
# 2024-08-02 02:48:32,654 - INFO - Traitement du game_id : 355180
# 2024-08-02 02:48:32,891 - INFO - Détails récupérés pour le jeu 355180
# 2024-08-02 02:48:33,578 - INFO - Informations de la page Steam récupérées pour le jeu 355180
# 2024-08-02 02:48:34,790 - INFO - Traitement du game_id : 355190
# 2024-08-02 02:48:35,016 - INFO - Détails récupérés pour le jeu 355190
# 2024-08-02 02:48:35,611 - INFO - Informations de la page Steam récupérées pour le jeu 355190
# 2024-08-02 02:48:37,222 - INFO - Traitement du game_id : 355200
# 2024-08-02 02:48:37,446 - WARNING - Pas de données pour le jeu 355200
# 2024-08-02 02:48:38,652 - INFO - Traitement du game_id : 355201
# 2024-08-02 02:48:38,900 - WARNING - Pas de données pour le jeu 355201
# 2024-08-02 02:48:40,438 - INFO - Traitement du game_id : 355202
# 2024-08-02 02:48:40,895 - WARNING - Pas de données pour le jeu 355202
# 2024-08-02 02:48:41,870 - INFO - Traitement du game_id : 355203
# 2024-08-02 02:48:42,077 - WARNING - Pas de données pour le jeu 355203
# 2024-08-02 02:48:43,327 - INFO - Traitement du game_id : 355204
# 2024-08-02 02:48:43,587 - WARNING - Pas de données pour le jeu 355204
# 2024-08-02 02:48:44,965 - INFO - Traitement du game_id : 355205
# 2024-08-02 02:48:45,166 - WARNING - Pas de données pour le jeu 355205
# 2024-08-02 02:48:45,793 - INFO - Traitement du game_id : 355206
# 2024-08-02 02:48:45,999 - WARNING - Pas de données pour le jeu 355206
# 2024-08-02 02:48:47,108 - INFO - Traitement du game_id : 355207
# 2024-08-02 02:48:47,330 - WARNING - Pas de données pour le jeu 355207
# 2024-08-02 02:48:48,794 - INFO - Traitement du game_id : 355208
# 2024-08-02 02:48:48,994 - WARNING - Pas de données pour le jeu 355208
# 2024-08-02 02:48:49,555 - INFO - Traitement du game_id : 355209
# 2024-08-02 02:48:49,756 - WARNING - Pas de données pour le jeu 355209
# 2024-08-02 02:48:50,493 - INFO - Traitement du game_id : 355210
# 2024-08-02 02:48:50,703 - WARNING - Pas de données pour le jeu 355210
# 2024-08-02 02:48:51,478 - INFO - Traitement du game_id : 355230
# 2024-08-02 02:48:51,701 - INFO - Détails récupérés pour le jeu 355230
# 2024-08-02 02:48:52,370 - INFO - Informations de la page Steam récupérées pour le jeu 355230
# 2024-08-02 02:48:53,110 - INFO - Traitement du game_id : 355240
# 2024-08-02 02:48:53,430 - INFO - Détails récupérés pour le jeu 355240
# 2024-08-02 02:48:54,154 - INFO - Informations de la page Steam récupérées pour le jeu 355240
# 2024-08-02 02:48:55,391 - INFO - Traitement du game_id : 355250
# 2024-08-02 02:48:55,644 - INFO - Détails récupérés pour le jeu 355250
# 2024-08-02 02:48:56,185 - INFO - Informations de la page Steam récupérées pour le jeu 355250
# 2024-08-02 02:48:57,834 - INFO - Traitement du game_id : 355260
# 2024-08-02 02:48:58,083 - INFO - Détails récupérés pour le jeu 355260
# 2024-08-02 02:48:58,463 - INFO - Informations de la page Steam récupérées pour le jeu 355260
# 2024-08-02 02:48:59,757 - INFO - Traitement du game_id : 355262
# 2024-08-02 02:48:59,995 - INFO - Détails récupérés pour le jeu 355262
# 2024-08-02 02:49:00,465 - INFO - Informations de la page Steam récupérées pour le jeu 355262
# 2024-08-02 02:49:01,972 - INFO - Traitement du game_id : 355270
# 2024-08-02 02:49:02,249 - INFO - Détails récupérés pour le jeu 355270
# 2024-08-02 02:49:02,983 - INFO - Informations de la page Steam récupérées pour le jeu 355270
# 2024-08-02 02:49:03,757 - INFO - Traitement du game_id : 355280
# 2024-08-02 02:49:04,245 - INFO - Détails récupérés pour le jeu 355280
# 2024-08-02 02:49:05,027 - INFO - Informations de la page Steam récupérées pour le jeu 355280
# 2024-08-02 02:49:06,212 - INFO - Traitement du game_id : 355290
# 2024-08-02 02:49:06,474 - INFO - Détails récupérés pour le jeu 355290
# 2024-08-02 02:49:06,859 - INFO - Informations de la page Steam récupérées pour le jeu 355290
# 2024-08-02 02:49:07,963 - INFO - Traitement du game_id : 355300
# 2024-08-02 02:49:08,232 - INFO - Détails récupérés pour le jeu 355300
# 2024-08-02 02:49:08,673 - INFO - Informations de la page Steam récupérées pour le jeu 355300
# 2024-08-02 02:49:09,392 - INFO - Traitement du game_id : 355310
# 2024-08-02 02:49:09,647 - INFO - Détails récupérés pour le jeu 355310
# 2024-08-02 02:49:10,188 - INFO - Informations de la page Steam récupérées pour le jeu 355310
# 2024-08-02 02:49:11,238 - INFO - Mise à jour terminée avec succès
# 2024-08-02 02:49:11,240 - INFO - Fichier temporaire supprimé
